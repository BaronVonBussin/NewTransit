# %% [markdown]
# <a href="https://colab.research.google.com/github/BaronVonBussin/NewTransit/blob/main/fetch_ticker_metadata_20250110.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TICKER LOOKUP OF HIGH LEVEL DATA

# %% [markdown]
# Option 1:  Fetch tickers_list.csv and return info, exported to ticker_analysis_results.csv.

# %%
import yfinance as yf
import pandas as pd
from typing import List, Dict
import json

class TickerAnalyzer:
    def __init__(self):
        # Cache for index constituents
        self.dow30_tickers = self._get_dow30_tickers()
        self.sp500_tickers = self._get_sp500_tickers()
        self.sp100_tickers = self._get_sp100_tickers()
        self.nasdaq100_tickers = self._get_nasdaq100_tickers()
        self.top50_etfs = self._get_top50_etfs()

    def analyze_tickers(self, ticker_list: List[str]) -> Dict:
        """Analyze a list of tickers and return their information."""
        results = {}

        for ticker in ticker_list:
            try:
                ticker_obj = yf.Ticker(ticker)
                info = ticker_obj.info

                # Determine if it's an ETF or stock
                security_type = "ETF" if info.get('quoteType') == 'ETF' else "Stock"

                results[ticker] = {
                    'security_type': security_type,
                    'name': info.get('longName'),
                    'gics_sector': info.get('sector'),
                    'sub_industry': info.get('industry'),
                    'exchange': info.get('exchange'),
                    'market_cap': info.get('marketCap'),
                    'avg_volume': info.get('averageVolume'),
                    'is_dow30': ticker in self.dow30_tickers,
                    'is_sp500': ticker in self.sp500_tickers,
                    'is_sp100': ticker in self.sp100_tickers,
                    'is_nasdaq100': ticker in self.nasdaq100_tickers,
                    'is_top50_etf': ticker in self.top50_etfs,
                    'dividend_yield': info.get('dividendYield'),

                    # Additional popular datapoints
                    'pe_ratio': info.get('forwardPE'),
                    'beta': info.get('beta'),
                    '52_week_high': info.get('fiftyTwoWeekHigh'),
                    '52_week_low': info.get('fiftyTwoWeekLow'),
                    'analyst_rating': info.get('recommendationMean'),
                    'price_to_book': info.get('priceToBook'),
                    'profit_margins': info.get('profitMargins')
                }

            except Exception as e:
                results[ticker] = f"Error analyzing ticker: {str(e)}"

        return results

    def _get_dow30_tickers(self) -> List[str]:
        """Fetch current Dow 30 constituents."""
        # You might want to implement this using a reliable source
        # For now, returning a static list
        return ["AAPL", "MSFT", "JPM"]  # Example - needs to be updated

    def _get_sp500_tickers(self) -> List[str]:
        """Fetch current S&P 500 constituents."""
        # Implementation needed
        return []

    def _get_sp100_tickers(self) -> List[str]:
        """Fetch current S&P 100 constituents."""
        # Implementation needed
        return []

    def _get_nasdaq100_tickers(self) -> List[str]:
        """Fetch current NASDAQ 100 constituents."""
        # Implementation needed
        return []

    def _get_top50_etfs(self) -> List[str]:
        """Return list of top 50 ETFs by AUM."""
        # This list should be regularly updated based on current AUM
        # Example list of some of the largest ETFs - needs to be completed and maintained
        top_etfs = [
            "SPY",   # SPDR S&P 500 ETF Trust
            "IVV",   # iShares Core S&P 500 ETF
            "VOO",   # Vanguard S&P 500 ETF
            "VTI",   # Vanguard Total Stock Market ETF
            "QQQ",   # Invesco QQQ Trust
            "BND",   # Vanguard Total Bond Market ETF
            "VEA",   # Vanguard FTSE Developed Markets ETF
            "IEFA",  # iShares Core MSCI EAFE ETF
            "AGG",   # iShares Core U.S. Aggregate Bond ETF
            "VWO"    # Vanguard FTSE Emerging Markets ETF
            # ... Add remaining ETFs
        ]
        return top_etfs

def read_ticker_list(file_path: str) -> List[str]:
    """Read ticker list from file."""
    with open(file_path, 'r') as f:
        # Assuming one ticker per line
        return [line.strip() for line in f if line.strip()]

def main():
    # Read tickers from file
    try:
        tickers = read_ticker_list('/content/tickers_list.csv')
    except Exception as e:
        print(f"Error reading ticker file: {str(e)}")
        return

    # Analyze tickers
    analyzer = TickerAnalyzer()
    results = analyzer.analyze_tickers(tickers)

    # Output results
    print(json.dumps(results, indent=2))

    # Optionally save to CSV
    df = pd.DataFrame.from_dict(results, orient='index')
    df.to_csv('ticker_analysis_results.csv')

if __name__ == "__main__":
    main()
# Out:
# ERROR:yfinance:404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ABMD?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ABMD&crumb=UIZDKdv788j
# {
#   "AAL": {
#     "security_type": "Stock",
#     "name": "American Airlines Group Inc.",
#     "gics_sector": "Industrials",
#     "sub_industry": "Airlines",
#     "exchange": "NMS",
#     "market_cap": 11565505536,
#     "avg_volume": 26763665,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": 7.089342,
#     "beta": 1.399,
#     "52_week_high": 18.2,
#     "52_week_low": 9.07,
#     "analyst_rating": 2.3913,
#     "price_to_book": null,
#     "profit_margins": 0.00513
#   },
#   "AAP": {
#     "security_type": "Stock",
#     "name": "Advance Auto Parts, Inc.",
#     "gics_sector": "Consumer Cyclical",
#     "sub_industry": "Specialty Retail",
#     "exchange": "NYQ",
#     "market_cap": 2719711744,
#     "avg_volume": 2467862,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.024300002,
#     "pe_ratio": 29.194132,
#     "beta": 1.194,
#     "52_week_high": 88.56,
#     "52_week_low": 35.59,
#     "analyst_rating": 2.96552,
#     "price_to_book": 1.0753424,
#     "profit_margins": -0.0010800001
#   },
#   "AAPL": {
#     "security_type": "Stock",
#     "name": "Apple Inc.",
#     "gics_sector": "Technology",
#     "sub_industry": "Consumer Electronics",
#     "exchange": "NMS",
#     "market_cap": 3668604616704,
#     "avg_volume": 44577334,
#     "is_dow30": true,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0041,
#     "pe_ratio": 29.224627,
#     "beta": 1.24,
#     "52_week_high": 260.1,
#     "52_week_low": 164.08,
#     "analyst_rating": 1.89362,
#     "price_to_book": 64.427925,
#     "profit_margins": 0.23971
#   },
#   "ABBV": {
#     "security_type": "Stock",
#     "name": "AbbVie Inc.",
#     "gics_sector": "Healthcare",
#     "sub_industry": "Drug Manufacturers - General",
#     "exchange": "NYQ",
#     "market_cap": 315434500096,
#     "avg_volume": 6307808,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0368,
#     "pe_ratio": 14.673254,
#     "beta": 0.613,
#     "52_week_high": 207.32,
#     "52_week_low": 153.58,
#     "analyst_rating": 1.89655,
#     "price_to_book": 52.300026,
#     "profit_margins": 0.09222999
#   },
#   "ABMD": {
#     "security_type": "Stock",
#     "name": null,
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": null,
#     "market_cap": null,
#     "avg_volume": null,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": null,
#     "52_week_low": null,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "ACN": {
#     "security_type": "Stock",
#     "name": "Accenture plc",
#     "gics_sector": "Technology",
#     "sub_industry": "Information Technology Services",
#     "exchange": "NYQ",
#     "market_cap": 223752962048,
#     "avg_volume": 2456055,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.017,
#     "pe_ratio": 25.621248,
#     "beta": 1.245,
#     "52_week_high": 387.51,
#     "52_week_low": 278.69,
#     "analyst_rating": 1.84615,
#     "price_to_book": 7.9070334,
#     "profit_margins": 0.111940004
#   },
#   "ADBE": {
#     "security_type": "Stock",
#     "name": "Adobe Inc.",
#     "gics_sector": "Technology",
#     "sub_industry": "Software - Infrastructure",
#     "exchange": "NMS",
#     "market_cap": 184699109376,
#     "avg_volume": 3547801,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": 18.197945,
#     "beta": 1.299,
#     "52_week_high": 638.25,
#     "52_week_low": 415.51,
#     "analyst_rating": 1.97436,
#     "price_to_book": 12.83708,
#     "profit_margins": 0.25588
#   },
#   "ADI": {
#     "security_type": "Stock",
#     "name": "Analog Devices, Inc.",
#     "gics_sector": "Technology",
#     "sub_industry": "Semiconductors",
#     "exchange": "NMS",
#     "market_cap": 109403709440,
#     "avg_volume": 2969167,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0165,
#     "pe_ratio": 24.596777,
#     "beta": 1.078,
#     "52_week_high": 244.14,
#     "52_week_low": 182.57,
#     "analyst_rating": 1.9375,
#     "price_to_book": 3.1101768,
#     "profit_margins": 0.17068
#   },
#   "ADP": {
#     "security_type": "Stock",
#     "name": "Automatic Data Processing, Inc.",
#     "gics_sector": "Technology",
#     "sub_industry": "Software - Application",
#     "exchange": "NMS",
#     "market_cap": 118932627456,
#     "avg_volume": 1688452,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0211,
#     "pe_ratio": 26.84209,
#     "beta": 0.795,
#     "52_week_high": 309.63,
#     "52_week_low": 231.27,
#     "analyst_rating": null,
#     "price_to_book": 22.249409,
#     "profit_margins": 0.19715
#   },
#   "ADSK": {
#     "security_type": "Stock",
#     "name": "Autodesk, Inc.",
#     "gics_sector": "Technology",
#     "sub_industry": "Software - Application",
#     "exchange": "NMS",
#     "market_cap": 63870398464,
#     "avg_volume": 1433154,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": 32.059963,
#     "beta": 1.474,
#     "52_week_high": 326.62,
#     "52_week_low": 195.32,
#     "analyst_rating": 1.90323,
#     "price_to_book": 34.191277,
#     "profit_margins": 0.18208
#   },
#   "AEP": {
#     "security_type": "Stock",
#     "name": "American Electric Power Company, Inc.",
#     "gics_sector": "Utilities",
#     "sub_industry": "Utilities - Regulated Electric",
#     "exchange": "NMS",
#     "market_cap": 49134448640,
#     "avg_volume": 2773018,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0403,
#     "pe_ratio": 15.738414,
#     "beta": 0.539,
#     "52_week_high": 105.18,
#     "52_week_low": 75.22,
#     "analyst_rating": 2.90909,
#     "price_to_book": 1.8456061,
#     "profit_margins": 0.13464
#   },
#   "AIG": {
#     "security_type": "Stock",
#     "name": "American International Group, Inc.",
#     "gics_sector": "Financial Services",
#     "sub_industry": "Insurance - Diversified",
#     "exchange": "NYQ",
#     "market_cap": 44555821056,
#     "avg_volume": 3994052,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0224,
#     "pe_ratio": 10.849375,
#     "beta": 1.069,
#     "52_week_high": 80.83,
#     "52_week_low": 66.06,
#     "analyst_rating": 2.27778,
#     "price_to_book": 0.99960816,
#     "profit_margins": -0.04876
#   },
#   "ALGN": {
#     "security_type": "Stock",
#     "name": "Align Technology, Inc.",
#     "gics_sector": "Healthcare",
#     "sub_industry": "Medical Instruments & Supplies",
#     "exchange": "NMS",
#     "market_cap": 16078039040,
#     "avg_volume": 813337,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": 20.99489,
#     "beta": 1.65,
#     "52_week_high": 335.4,
#     "52_week_low": 196.09,
#     "analyst_rating": 2.05882,
#     "price_to_book": 4.081915,
#     "profit_margins": 0.111490004
#   },
#   "ALK": {
#     "security_type": "Stock",
#     "name": "Alaska Air Group, Inc.",
#     "gics_sector": "Industrials",
#     "sub_industry": "Airlines",
#     "exchange": "NYQ",
#     "market_cap": 8415184384,
#     "avg_volume": 2525924,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": 11.000281,
#     "beta": 1.593,
#     "52_week_high": 67.73,
#     "52_week_low": 32.62,
#     "analyst_rating": 1.5625,
#     "price_to_book": 1.8666929,
#     "profit_margins": 0.02994
#   },
#   "AMAT": {
#     "security_type": "Stock",
#     "name": "Applied Materials, Inc.",
#     "gics_sector": "Technology",
#     "sub_industry": "Semiconductor Equipment & Materials",
#     "exchange": "NMS",
#     "market_cap": 144014114816,
#     "avg_volume": 6789368,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0086,
#     "pe_ratio": 16.883076,
#     "beta": 1.551,
#     "52_week_high": 255.89,
#     "52_week_low": 149.84,
#     "analyst_rating": 1.89474,
#     "price_to_book": 7.744716,
#     "profit_margins": 0.27743
#   },
#   "AMD": {
#     "security_type": "Stock",
#     "name": "Advanced Micro Devices, Inc.",
#     "gics_sector": "Technology",
#     "sub_industry": "Semiconductors",
#     "exchange": "NMS",
#     "market_cap": 197723160576,
#     "avg_volume": 36377350,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": 23.731613,
#     "beta": 1.706,
#     "52_week_high": 227.3,
#     "52_week_low": 117.9,
#     "analyst_rating": 1.63265,
#     "price_to_book": 3.4701374,
#     "profit_margins": 0.07516
#   },
#   "AMGN": {
#     "security_type": "Stock",
#     "name": "Amgen Inc.",
#     "gics_sector": "Healthcare",
#     "sub_industry": "Drug Manufacturers - General",
#     "exchange": "NMS",
#     "market_cap": 142021591040,
#     "avg_volume": 3396927,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.036,
#     "pe_ratio": 12.728625,
#     "beta": 0.599,
#     "52_week_high": 346.85,
#     "52_week_low": 253.3,
#     "analyst_rating": 2.40625,
#     "price_to_book": 18.866753,
#     "profit_margins": 0.13002
#   },
#   "AMZN": {
#     "security_type": "Stock",
#     "name": "Amazon.com, Inc.",
#     "gics_sector": "Consumer Cyclical",
#     "sub_industry": "Internet Retail",
#     "exchange": "NMS",
#     "market_cap": 2335697010688,
#     "avg_volume": 37597363,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": 35.986923,
#     "beta": 1.146,
#     "52_week_high": 233.0,
#     "52_week_low": 149.91,
#     "analyst_rating": 1.40299,
#     "price_to_book": 9.009531,
#     "profit_margins": 0.080419995
#   },
#   "AXP": {
#     "security_type": "Stock",
#     "name": "American Express Company",
#     "gics_sector": "Financial Services",
#     "sub_industry": "Credit Services",
#     "exchange": "NYQ",
#     "market_cap": 213341175808,
#     "avg_volume": 2529327,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0092,
#     "pe_ratio": 19.948135,
#     "beta": 1.214,
#     "52_week_high": 307.82,
#     "52_week_low": 177.81,
#     "analyst_rating": 2.67857,
#     "price_to_book": 7.177051,
#     "profit_margins": 0.16698
#   },
#   "BA": {
#     "security_type": "Stock",
#     "name": "The Boeing Company",
#     "gics_sector": "Industrials",
#     "sub_industry": "Aerospace & Defense",
#     "exchange": "NYQ",
#     "market_cap": 128506707968,
#     "avg_volume": 13583814,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": 245.835,
#     "beta": 1.572,
#     "52_week_high": 222.07,
#     "52_week_low": 137.03,
#     "analyst_rating": 2.10714,
#     "price_to_book": null,
#     "profit_margins": -0.10880999
#   },
#   "BABA": {
#     "security_type": "Stock",
#     "name": "Alibaba Group Holding Limited",
#     "gics_sector": "Consumer Cyclical",
#     "sub_industry": "Internet Retail",
#     "exchange": "NYQ",
#     "market_cap": 199116095488,
#     "avg_volume": 14810377,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0221,
#     "pe_ratio": 1.1784316,
#     "beta": 0.349,
#     "52_week_high": 117.82,
#     "52_week_low": 66.63,
#     "analyst_rating": 1.52381,
#     "price_to_book": 0.2064493,
#     "profit_margins": 0.07383
#   },
#   "BAC": {
#     "security_type": "Stock",
#     "name": "Bank of America Corporation",
#     "gics_sector": "Financial Services",
#     "sub_industry": "Banks - Diversified",
#     "exchange": "NYQ",
#     "market_cap": 354563784704,
#     "avg_volume": 34354554,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0225,
#     "pe_ratio": 12.464866,
#     "beta": 1.325,
#     "52_week_high": 48.08,
#     "52_week_low": 31.27,
#     "analyst_rating": 1.78261,
#     "price_to_book": 1.3064375,
#     "profit_margins": 0.24952
#   },
#   "BIIB": {
#     "security_type": "Stock",
#     "name": "Biogen Inc.",
#     "gics_sector": "Healthcare",
#     "sub_industry": "Drug Manufacturers - General",
#     "exchange": "NMS",
#     "market_cap": 21967140864,
#     "avg_volume": 1503337,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": 9.121934,
#     "beta": -0.061,
#     "52_week_high": 252.17,
#     "52_week_low": 145.07,
#     "analyst_rating": 2.08824,
#     "price_to_book": 1.3426495,
#     "profit_margins": 0.16812
#   },
#   "BK": {
#     "security_type": "Stock",
#     "name": "The Bank of New York Mellon Corporation",
#     "gics_sector": "Financial Services",
#     "sub_industry": "Banks - Diversified",
#     "exchange": "NYQ",
#     "market_cap": 56675729408,
#     "avg_volume": 3791070,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0241,
#     "pe_ratio": 11.782453,
#     "beta": 1.06,
#     "52_week_high": 82.72,
#     "52_week_low": 52.64,
#     "analyst_rating": 2.11111,
#     "price_to_book": 1.5053784,
#     "profit_margins": 0.20038
#   },
#   "BLK": {
#     "security_type": "Stock",
#     "name": "BlackRock, Inc.",
#     "gics_sector": "Financial Services",
#     "sub_industry": "Asset Management",
#     "exchange": "NYQ",
#     "market_cap": 152726192128,
#     "avg_volume": 665463,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0207,
#     "pe_ratio": 20.565378,
#     "beta": 1.311,
#     "52_week_high": 1082.45,
#     "52_week_low": 745.55,
#     "analyst_rating": 1.72222,
#     "price_to_book": 3.5430822,
#     "profit_margins": 0.31372
#   },
#   "BMY": {
#     "security_type": "Stock",
#     "name": "Bristol-Myers Squibb Company",
#     "gics_sector": "Healthcare",
#     "sub_industry": "Drug Manufacturers - General",
#     "exchange": "NYQ",
#     "market_cap": 115220905984,
#     "avg_volume": 10575998,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0437,
#     "pe_ratio": 8.059048,
#     "beta": 0.441,
#     "52_week_high": 61.08,
#     "52_week_low": 39.35,
#     "analyst_rating": 2.61538,
#     "price_to_book": 6.720691,
#     "profit_margins": -0.15301
#   },
#   "C": {
#     "security_type": "Stock",
#     "name": "Citigroup Inc.",
#     "gics_sector": "Financial Services",
#     "sub_industry": "Banks - Diversified",
#     "exchange": "NYQ",
#     "market_cap": 138553720832,
#     "avg_volume": 13949993,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0306,
#     "pe_ratio": 9.942875,
#     "beta": 1.426,
#     "52_week_high": 74.29,
#     "52_week_low": 50.51,
#     "analyst_rating": 1.80952,
#     "price_to_book": 0.7188908,
#     "profit_margins": 0.11524
#   },
#   "CAT": {
#     "security_type": "Stock",
#     "name": "Caterpillar Inc.",
#     "gics_sector": "Industrials",
#     "sub_industry": "Farm & Heavy Construction Machinery",
#     "exchange": "NYQ",
#     "market_cap": 174325317632,
#     "avg_volume": 2052259,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0156,
#     "pe_ratio": 16.292767,
#     "beta": 1.095,
#     "52_week_high": 418.5,
#     "52_week_low": 276.94,
#     "analyst_rating": 2.69231,
#     "price_to_book": 8.987206,
#     "profit_margins": 0.1626
#   },
#   "CCL": {
#     "security_type": "Stock",
#     "name": "Carnival Corporation & plc",
#     "gics_sector": "Consumer Cyclical",
#     "sub_industry": "Travel Services",
#     "exchange": "NYQ",
#     "market_cap": 31627440128,
#     "avg_volume": 21618116,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": 11.873953,
#     "beta": 2.668,
#     "52_week_high": 27.17,
#     "52_week_low": 13.78,
#     "analyst_rating": 1.7931,
#     "price_to_book": 3.5637436,
#     "profit_margins": 0.063930005
#   },
#   "CMCSA": {
#     "security_type": "Stock",
#     "name": "Comcast Corporation",
#     "gics_sector": "Communication Services",
#     "sub_industry": "Telecom Services",
#     "exchange": "NMS",
#     "market_cap": 142232485888,
#     "avg_volume": 19874454,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0334,
#     "pe_ratio": 8.498641,
#     "beta": 1.004,
#     "52_week_high": 47.11,
#     "52_week_low": 36.24,
#     "analyst_rating": 2.06667,
#     "price_to_book": 1.6616002,
#     "profit_margins": 0.11924
#   },
#   "COP": {
#     "security_type": "Stock",
#     "name": "ConocoPhillips",
#     "gics_sector": "Energy",
#     "sub_industry": "Oil & Gas E&P",
#     "exchange": "NYQ",
#     "market_cap": 131451576320,
#     "avg_volume": 6696008,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0307,
#     "pe_ratio": 12.111706,
#     "beta": 1.22,
#     "52_week_high": 135.18,
#     "52_week_low": 94.23,
#     "analyst_rating": 1.71429,
#     "price_to_book": 2.3447163,
#     "profit_margins": 0.17472
#   },
#   "COST": {
#     "security_type": "Stock",
#     "name": "Costco Wholesale Corporation",
#     "gics_sector": "Consumer Defensive",
#     "sub_industry": "Discount Stores",
#     "exchange": "NMS",
#     "market_cap": 411658616832,
#     "avg_volume": 1880354,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0047,
#     "pe_ratio": 46.404,
#     "beta": 0.789,
#     "52_week_high": 1008.25,
#     "52_week_low": 675.96,
#     "analyst_rating": 1.97368,
#     "price_to_book": 17.396452,
#     "profit_margins": 0.02895
#   },
#   "CRM": {
#     "security_type": "Stock",
#     "name": "Salesforce, Inc.",
#     "gics_sector": "Technology",
#     "sub_industry": "Software - Application",
#     "exchange": "NYQ",
#     "market_cap": 312843304960,
#     "avg_volume": 5829111,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0047999998,
#     "pe_ratio": 29.112846,
#     "beta": 1.288,
#     "52_week_high": 369.0,
#     "52_week_low": 212.0,
#     "analyst_rating": 1.86275,
#     "price_to_book": 5.321764,
#     "profit_margins": 0.15445
#   },
#   "CSCO": {
#     "security_type": "Stock",
#     "name": "Cisco Systems, Inc.",
#     "gics_sector": "Technology",
#     "sub_industry": "Communication Equipment",
#     "exchange": "NMS",
#     "market_cap": 235779391488,
#     "avg_volume": 19087449,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.027,
#     "pe_ratio": 15.0417595,
#     "beta": null,
#     "52_week_high": 60.23,
#     "52_week_low": 44.5,
#     "analyst_rating": 2.32143,
#     "price_to_book": 5.2167788,
#     "profit_margins": 0.17731
#   },
#   "CVE": {
#     "security_type": "Stock",
#     "name": "Cenovus Energy Inc.",
#     "gics_sector": "Energy",
#     "sub_industry": "Oil & Gas Integrated",
#     "exchange": "NYQ",
#     "market_cap": 28045969408,
#     "avg_volume": 7537173,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0327,
#     "pe_ratio": 10.035983,
#     "beta": 2.623,
#     "52_week_high": 21.9,
#     "52_week_low": 14.2,
#     "analyst_rating": 1.5,
#     "price_to_book": 0.9653263,
#     "profit_margins": 0.06717
#   },
#   "CVS": {
#     "security_type": "Stock",
#     "name": "CVS Health Corporation",
#     "gics_sector": "Healthcare",
#     "sub_industry": "Healthcare Plans",
#     "exchange": "NYQ",
#     "market_cap": 57899442176,
#     "avg_volume": 13723800,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.057800002,
#     "pe_ratio": 6.798981,
#     "beta": 0.543,
#     "52_week_high": 80.75,
#     "52_week_low": 43.56,
#     "analyst_rating": 1.92857,
#     "price_to_book": 0.77231675,
#     "profit_margins": 0.013660001
#   },
#   "CVX": {
#     "security_type": "Stock",
#     "name": "Chevron Corporation",
#     "gics_sector": "Energy",
#     "sub_industry": "Oil & Gas Integrated",
#     "exchange": "NYQ",
#     "market_cap": 267972870144,
#     "avg_volume": 7792640,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0434,
#     "pe_ratio": 13.141673,
#     "beta": 1.078,
#     "52_week_high": 167.11,
#     "52_week_low": 135.37,
#     "analyst_rating": 1.96,
#     "price_to_book": 1.7291962,
#     "profit_margins": 0.087019995
#   },
#   "DAL": {
#     "security_type": "Stock",
#     "name": "Delta Air Lines, Inc.",
#     "gics_sector": "Industrials",
#     "sub_industry": "Airlines",
#     "exchange": "NYQ",
#     "market_cap": 39633158144,
#     "avg_volume": 7865227,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0098,
#     "pe_ratio": 8.253379,
#     "beta": 1.341,
#     "52_week_high": 67.5,
#     "52_week_low": 36.34,
#     "analyst_rating": 1.3913,
#     "price_to_book": 2.8856,
#     "profit_margins": 0.07712
#   },
#   "DE": {
#     "security_type": "Stock",
#     "name": "Deere & Company",
#     "gics_sector": "Industrials",
#     "sub_industry": "Farm & Heavy Construction Machinery",
#     "exchange": "NYQ",
#     "market_cap": 111345754112,
#     "avg_volume": 1189062,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0145000005,
#     "pe_ratio": 18.028627,
#     "beta": 0.935,
#     "52_week_high": 469.39,
#     "52_week_low": 340.2,
#     "analyst_rating": 2.25,
#     "price_to_book": 4.864102,
#     "profit_margins": 0.14698
#   },
#   "DELL": {
#     "security_type": "Stock",
#     "name": "Dell Technologies Inc.",
#     "gics_sector": "Technology",
#     "sub_industry": "Computer Hardware",
#     "exchange": "NYQ",
#     "market_cap": 83571761152,
#     "avg_volume": 7446168,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0126,
#     "pe_ratio": 12.6937275,
#     "beta": 0.954,
#     "52_week_high": 179.7,
#     "52_week_low": 76.9,
#     "analyst_rating": 1.64,
#     "price_to_book": null,
#     "profit_margins": 0.04325
#   },
#   "DHR": {
#     "security_type": "Stock",
#     "name": "Danaher Corporation",
#     "gics_sector": "Healthcare",
#     "sub_industry": "Diagnostics & Research",
#     "exchange": "NYQ",
#     "market_cap": 171966447616,
#     "avg_volume": 3050422,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0045,
#     "pe_ratio": 28.67238,
#     "beta": 0.881,
#     "52_week_high": 281.7,
#     "52_week_low": 222.53,
#     "analyst_rating": 1.53571,
#     "price_to_book": 3.3518696,
#     "profit_margins": 0.16393
#   },
#   "DIS": {
#     "security_type": "Stock",
#     "name": "The Walt Disney Company",
#     "gics_sector": "Communication Services",
#     "sub_industry": "Entertainment",
#     "exchange": "NYQ",
#     "market_cap": 198768787456,
#     "avg_volume": 9196483,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0082,
#     "pe_ratio": 18.026096,
#     "beta": 1.398,
#     "52_week_high": 123.74,
#     "52_week_low": 83.91,
#     "analyst_rating": 1.96875,
#     "price_to_book": 1.9809057,
#     "profit_margins": 0.053049996
#   },
#   "DKNG": {
#     "security_type": "Stock",
#     "name": "DraftKings Inc.",
#     "gics_sector": "Consumer Cyclical",
#     "sub_industry": "Gambling",
#     "exchange": "NMS",
#     "market_cap": 18700533760,
#     "avg_volume": 8530973,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": 26.51337,
#     "beta": 1.819,
#     "52_week_high": 49.57,
#     "52_week_low": 28.69,
#     "analyst_rating": 1.63889,
#     "price_to_book": 17.360796,
#     "profit_margins": -0.090550005
#   },
#   "DOW": {
#     "security_type": "Stock",
#     "name": "Dow Inc.",
#     "gics_sector": "Basic Materials",
#     "sub_industry": "Chemicals",
#     "exchange": "NYQ",
#     "market_cap": 27247581184,
#     "avg_volume": 7240200,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0719,
#     "pe_ratio": 12.136255,
#     "beta": 1.222,
#     "52_week_high": 60.69,
#     "52_week_low": 38.33,
#     "analyst_rating": 2.57143,
#     "price_to_book": 1.4880519,
#     "profit_margins": 0.02464
#   },
#   "DVN": {
#     "security_type": "Stock",
#     "name": "Devon Energy Corporation",
#     "gics_sector": "Energy",
#     "sub_industry": "Oil & Gas E&P",
#     "exchange": "NYQ",
#     "market_cap": 23090034688,
#     "avg_volume": 9780731,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.041300002,
#     "pe_ratio": 7.4587126,
#     "beta": 2.071,
#     "52_week_high": 55.09,
#     "52_week_low": 30.39,
#     "analyst_rating": 2.03226,
#     "price_to_book": 1.6199651,
#     "profit_margins": 0.23429
#   },
#   "EBAY": {
#     "security_type": "Stock",
#     "name": "eBay Inc.",
#     "gics_sector": "Consumer Cyclical",
#     "sub_industry": "Internet Retail",
#     "exchange": "NMS",
#     "market_cap": 33242601472,
#     "avg_volume": 4640796,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0156,
#     "pe_ratio": 13.300803,
#     "beta": 1.337,
#     "52_week_high": 71.52,
#     "52_week_low": 40.16,
#     "analyst_rating": 2.61765,
#     "price_to_book": 6.171632,
#     "profit_margins": 0.19677
#   },
#   "EMR": {
#     "security_type": "Stock",
#     "name": "Emerson Electric Co.",
#     "gics_sector": "Industrials",
#     "sub_industry": "Specialty Industrial Machinery",
#     "exchange": "NYQ",
#     "market_cap": 68514582528,
#     "avg_volume": 2849301,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0175,
#     "pe_ratio": 18.477985,
#     "beta": 1.292,
#     "52_week_high": 134.85,
#     "52_week_low": 91.65,
#     "analyst_rating": 1.75,
#     "price_to_book": 3.1703782,
#     "profit_margins": 0.11251
#   },
#   "EXC": {
#     "security_type": "Stock",
#     "name": "Exelon Corporation",
#     "gics_sector": "Utilities",
#     "sub_industry": "Utilities - Regulated Electric",
#     "exchange": "NMS",
#     "market_cap": 38374457344,
#     "avg_volume": 6355222,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0398,
#     "pe_ratio": 14.514731,
#     "beta": 0.61,
#     "52_week_high": 41.19,
#     "52_week_low": 33.35,
#     "analyst_rating": 2.55,
#     "price_to_book": 1.4414585,
#     "profit_margins": 0.106000006
#   },
#   "F": {
#     "security_type": "Stock",
#     "name": "Ford Motor Company",
#     "gics_sector": "Consumer Cyclical",
#     "sub_industry": "Auto Manufacturers",
#     "exchange": "NYQ",
#     "market_cap": 38709583872,
#     "avg_volume": 56946496,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0616,
#     "pe_ratio": 5.4140286,
#     "beta": 1.636,
#     "52_week_high": 14.85,
#     "52_week_low": 9.49,
#     "analyst_rating": 2.88,
#     "price_to_book": 0.8735426,
#     "profit_margins": 0.01931
#   },
#   "FCX": {
#     "security_type": "Stock",
#     "name": "Freeport-McMoRan Inc.",
#     "gics_sector": "Basic Materials",
#     "sub_industry": "Copper",
#     "exchange": "NYQ",
#     "market_cap": 57103601664,
#     "avg_volume": 11105352,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0150999995,
#     "pe_ratio": 19.665384,
#     "beta": 1.91,
#     "52_week_high": 55.24,
#     "52_week_low": 36.26,
#     "analyst_rating": 2.13043,
#     "price_to_book": 3.2541764,
#     "profit_margins": 0.07812
#   },
#   "FDX": {
#     "security_type": "Stock",
#     "name": "FedEx Corporation",
#     "gics_sector": "Industrials",
#     "sub_industry": "Integrated Freight & Logistics",
#     "exchange": "NYQ",
#     "market_cap": 66209939456,
#     "avg_volume": 1642268,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.02,
#     "pe_ratio": 12.091223,
#     "beta": 1.177,
#     "52_week_high": 313.84,
#     "52_week_low": 234.45,
#     "analyst_rating": 1.90323,
#     "price_to_book": 2.4348764,
#     "profit_margins": 0.0462
#   },
#   "GD": {
#     "security_type": "Stock",
#     "name": "General Dynamics Corporation",
#     "gics_sector": "Industrials",
#     "sub_industry": "Aerospace & Defense",
#     "exchange": "NYQ",
#     "market_cap": 71896145920,
#     "avg_volume": 1411627,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0217,
#     "pe_ratio": 16.369797,
#     "beta": 0.614,
#     "52_week_high": 316.9,
#     "52_week_low": 247.36,
#     "analyst_rating": 2.08,
#     "price_to_book": 3.1245668,
#     "profit_margins": 0.07903
#   },
#   "GE": {
#     "security_type": "Stock",
#     "name": "GE Aerospace",
#     "gics_sector": "Industrials",
#     "sub_industry": "Aerospace & Defense",
#     "exchange": "NYQ",
#     "market_cap": 187117125632,
#     "avg_volume": 4860154,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0064999997,
#     "pe_ratio": 32.813675,
#     "beta": 1.188,
#     "52_week_high": 194.8,
#     "52_week_low": 100.7103,
#     "analyst_rating": 1.33333,
#     "price_to_book": 9.913986,
#     "profit_margins": 0.08926
#   },
#   "GILD": {
#     "security_type": "Stock",
#     "name": "Gilead Sciences, Inc.",
#     "gics_sector": "Healthcare",
#     "sub_industry": "Drug Manufacturers - General",
#     "exchange": "NMS",
#     "market_cap": 111092506624,
#     "avg_volume": 6518178,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0346,
#     "pe_ratio": 11.785611,
#     "beta": 0.192,
#     "52_week_high": 98.9,
#     "52_week_low": 62.07,
#     "analyst_rating": 1.96429,
#     "price_to_book": 6.0120053,
#     "profit_margins": 0.00445
#   },
#   "GM": {
#     "security_type": "Stock",
#     "name": "General Motors Company",
#     "gics_sector": "Consumer Cyclical",
#     "sub_industry": "Auto Manufacturers",
#     "exchange": "NYQ",
#     "market_cap": 56079601664,
#     "avg_volume": 11727009,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0094,
#     "pe_ratio": 4.832575,
#     "beta": 1.414,
#     "52_week_high": 61.24,
#     "52_week_low": 34.32,
#     "analyst_rating": 2.17241,
#     "price_to_book": 0.79086936,
#     "profit_margins": 0.06058
#   },
#   "GOLD": {
#     "security_type": "Stock",
#     "name": "Barrick Gold Corporation",
#     "gics_sector": "Basic Materials",
#     "sub_industry": "Gold",
#     "exchange": "NYQ",
#     "market_cap": 28115841024,
#     "avg_volume": 20956201,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0253,
#     "pe_ratio": 8.604206,
#     "beta": 0.48,
#     "52_week_high": 21.35,
#     "52_week_low": 13.76,
#     "analyst_rating": 1.90909,
#     "price_to_book": 1.1618866,
#     "profit_margins": 0.13189
#   },
#   "GOOG": {
#     "security_type": "Stock",
#     "name": "Alphabet Inc.",
#     "gics_sector": "Communication Services",
#     "sub_industry": "Internet Content & Information",
#     "exchange": "NMS",
#     "market_cap": 2382116683776,
#     "avg_volume": 18999857,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0041,
#     "pe_ratio": 21.791088,
#     "beta": 1.034,
#     "52_week_high": 202.88,
#     "52_week_low": 131.55,
#     "analyst_rating": 1.59677,
#     "price_to_book": 7.6285477,
#     "profit_margins": 0.27738002
#   },
#   "GOOGL": {
#     "security_type": "Stock",
#     "name": "Alphabet Inc.",
#     "gics_sector": "Communication Services",
#     "sub_industry": "Internet Content & Information",
#     "exchange": "NMS",
#     "market_cap": 2382113275904,
#     "avg_volume": 27765770,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0041,
#     "pe_ratio": 21.63049,
#     "beta": 1.034,
#     "52_week_high": 201.42,
#     "52_week_low": 130.67,
#     "analyst_rating": 1.59677,
#     "price_to_book": 7.572326,
#     "profit_margins": 0.27738002
#   },
#   "GS": {
#     "security_type": "Stock",
#     "name": "The Goldman Sachs Group, Inc.",
#     "gics_sector": "Financial Services",
#     "sub_industry": "Capital Markets",
#     "exchange": "NYQ",
#     "market_cap": 182074097664,
#     "avg_volume": 2098608,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0207,
#     "pe_ratio": 13.341541,
#     "beta": 1.342,
#     "52_week_high": 612.73,
#     "52_week_low": 372.07,
#     "analyst_rating": 2.17391,
#     "price_to_book": 1.7704535,
#     "profit_margins": 0.24648
#   },
#   "HAL": {
#     "security_type": "Stock",
#     "name": "Halliburton Company",
#     "gics_sector": "Energy",
#     "sub_industry": "Oil & Gas Equipment & Services",
#     "exchange": "NYQ",
#     "market_cap": 23745910784,
#     "avg_volume": 9189968,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0252,
#     "pe_ratio": 8.776943,
#     "beta": 1.905,
#     "52_week_high": 41.56,
#     "52_week_low": 25.51,
#     "analyst_rating": 1.73333,
#     "price_to_book": 2.3049374,
#     "profit_margins": 0.11038999
#   },
#   "HD": {
#     "security_type": "Stock",
#     "name": "The Home Depot, Inc.",
#     "gics_sector": "Consumer Cyclical",
#     "sub_industry": "Home Improvement Retail",
#     "exchange": "NYQ",
#     "market_cap": 384630161408,
#     "avg_volume": 3210744,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0232,
#     "pe_ratio": 24.59712,
#     "beta": 1.011,
#     "52_week_high": 439.37,
#     "52_week_low": 323.77,
#     "analyst_rating": 1.925,
#     "price_to_book": 66.31272,
#     "profit_margins": 0.0945
#   },
#   "HON": {
#     "security_type": "Stock",
#     "name": "Honeywell International Inc.",
#     "gics_sector": "Industrials",
#     "sub_industry": "Conglomerates",
#     "exchange": "NMS",
#     "market_cap": 143164882944,
#     "avg_volume": 4343147,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.020499999,
#     "pe_ratio": 20.041965,
#     "beta": 1.025,
#     "52_week_high": 242.77,
#     "52_week_low": 189.66,
#     "analyst_rating": 2.26923,
#     "price_to_book": 8.22512,
#     "profit_margins": 0.15015
#   },
#   "HOOD": {
#     "security_type": "Stock",
#     "name": "Robinhood Markets, Inc.",
#     "gics_sector": "Financial Services",
#     "sub_industry": "Capital Markets",
#     "exchange": "NMS",
#     "market_cap": 36075061248,
#     "avg_volume": 21879768,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": 29.06571,
#     "beta": 1.839,
#     "52_week_high": 43.83,
#     "52_week_low": 10.38,
#     "analyst_rating": 1.94118,
#     "price_to_book": 5.003065,
#     "profit_margins": 0.21802
#   },
#   "IBM": {
#     "security_type": "Stock",
#     "name": "International Business Machines Corporation",
#     "gics_sector": "Technology",
#     "sub_industry": "Information Technology Services",
#     "exchange": "NYQ",
#     "market_cap": 206362263552,
#     "avg_volume": 4106375,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0299,
#     "pe_ratio": 20.76717,
#     "beta": 0.71,
#     "52_week_high": 239.35,
#     "52_week_low": 162.35,
#     "analyst_rating": 2.73684,
#     "price_to_book": 8.440998,
#     "profit_margins": 0.10222
#   },
#   "INTC": {
#     "security_type": "Stock",
#     "name": "Intel Corporation",
#     "gics_sector": "Technology",
#     "sub_industry": "Semiconductors",
#     "exchange": "NMS",
#     "market_cap": 85742436352,
#     "avg_volume": 69365242,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0224,
#     "pe_ratio": 20.37595,
#     "beta": 1.026,
#     "52_week_high": 50.3,
#     "52_week_low": 18.51,
#     "analyst_rating": 3.0,
#     "price_to_book": 0.86064327,
#     "profit_margins": -0.29423
#   },
#   "JNJ": {
#     "security_type": "Stock",
#     "name": "Johnson & Johnson",
#     "gics_sector": "Healthcare",
#     "sub_industry": "Drug Manufacturers - General",
#     "exchange": "NYQ",
#     "market_cap": 342532128768,
#     "avg_volume": 7615709,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0349,
#     "pe_ratio": 13.371517,
#     "beta": 0.518,
#     "52_week_high": 168.85,
#     "52_week_low": 141.44,
#     "analyst_rating": 2.26087,
#     "price_to_book": 4.881623,
#     "profit_margins": 0.16744
#   },
#   "JPM": {
#     "security_type": "Stock",
#     "name": "JPMorgan Chase & Co.",
#     "gics_sector": "Financial Services",
#     "sub_industry": "Banks - Diversified",
#     "exchange": "NYQ",
#     "market_cap": 684493635584,
#     "avg_volume": 8770636,
#     "is_dow30": true,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.020599999,
#     "pe_ratio": 14.014719,
#     "beta": 1.091,
#     "52_week_high": 254.31,
#     "52_week_low": 164.3,
#     "analyst_rating": 2.26087,
#     "price_to_book": 2.11142,
#     "profit_margins": 0.33163
#   },
#   "KHC": {
#     "security_type": "Stock",
#     "name": "The Kraft Heinz Company",
#     "gics_sector": "Consumer Defensive",
#     "sub_industry": "Packaged Foods",
#     "exchange": "NMS",
#     "market_cap": 35863982080,
#     "avg_volume": 9510459,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0539,
#     "pe_ratio": 9.681863,
#     "beta": 0.475,
#     "52_week_high": 38.96,
#     "52_week_low": 29.23,
#     "analyst_rating": 2.45455,
#     "price_to_book": 0.7419823,
#     "profit_margins": 0.05243
#   },
#   "KO": {
#     "security_type": "Stock",
#     "name": "The Coca-Cola Company",
#     "gics_sector": "Consumer Defensive",
#     "sub_industry": "Beverages - Non-Alcoholic",
#     "exchange": "NYQ",
#     "market_cap": 265834332160,
#     "avg_volume": 16393844,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.031400003,
#     "pe_ratio": 20.782675,
#     "beta": 0.62,
#     "52_week_high": 73.53,
#     "52_week_low": 57.93,
#     "analyst_rating": 1.8,
#     "price_to_book": 10.029254,
#     "profit_margins": 0.2245
#   },
#   "LCID": {
#     "security_type": "Stock",
#     "name": "Lucid Group, Inc.",
#     "gics_sector": "Consumer Cyclical",
#     "sub_industry": "Auto Manufacturers",
#     "exchange": "NMS",
#     "market_cap": 8974835712,
#     "avg_volume": 83281018,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": -3.353703,
#     "beta": 1.122,
#     "52_week_high": 4.43,
#     "52_week_low": 1.93,
#     "analyst_rating": 3.25,
#     "price_to_book": 2.5958188,
#     "profit_margins": null
#   },
#   "LIN": {
#     "security_type": "Stock",
#     "name": "Linde plc",
#     "gics_sector": "Basic Materials",
#     "sub_industry": "Specialty Chemicals",
#     "exchange": "NMS",
#     "market_cap": 199991132160,
#     "avg_volume": 2067798,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.013200001,
#     "pe_ratio": 24.831224,
#     "beta": 0.949,
#     "52_week_high": 487.49,
#     "52_week_low": 396.07,
#     "analyst_rating": 1.96429,
#     "price_to_book": 5.1053257,
#     "profit_margins": 0.19328
#   },
#   "LLY": {
#     "security_type": "Stock",
#     "name": "Eli Lilly and Company",
#     "gics_sector": "Healthcare",
#     "sub_industry": "Drug Manufacturers - General",
#     "exchange": "NYQ",
#     "market_cap": 707959521280,
#     "avg_volume": 3829045,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0076,
#     "pe_ratio": 34.804237,
#     "beta": 0.43,
#     "52_week_high": 972.53,
#     "52_week_low": 612.7,
#     "analyst_rating": 1.75,
#     "price_to_book": 49.74534,
#     "profit_margins": 0.20482999
#   },
#   "LMT": {
#     "security_type": "Stock",
#     "name": "Lockheed Martin Corporation",
#     "gics_sector": "Industrials",
#     "sub_industry": "Aerospace & Defense",
#     "exchange": "NYQ",
#     "market_cap": 111133868032,
#     "avg_volume": 1203359,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.028199999,
#     "pe_ratio": 16.85748,
#     "beta": 0.481,
#     "52_week_high": 618.95,
#     "52_week_low": 413.92,
#     "analyst_rating": 2.34783,
#     "price_to_book": 15.368101,
#     "profit_margins": 0.09363
#   },
#   "LOW": {
#     "security_type": "Stock",
#     "name": "Lowe's Companies, Inc.",
#     "gics_sector": "Consumer Cyclical",
#     "sub_industry": "Home Improvement Retail",
#     "exchange": "NYQ",
#     "market_cap": 139406426112,
#     "avg_volume": 2328104,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.016900001,
#     "pe_ratio": 19.489109,
#     "beta": 1.098,
#     "52_week_high": 287.01,
#     "52_week_low": 209.55,
#     "analyst_rating": 2.10526,
#     "price_to_book": null,
#     "profit_margins": 0.08248
#   },
#   "MA": {
#     "security_type": "Stock",
#     "name": "Mastercard Incorporated",
#     "gics_sector": "Financial Services",
#     "sub_industry": "Credit Services",
#     "exchange": "NYQ",
#     "market_cap": 473967951872,
#     "avg_volume": 2544063,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0058999998,
#     "pe_ratio": 31.536303,
#     "beta": 1.101,
#     "52_week_high": 537.7,
#     "52_week_low": 425.48,
#     "analyst_rating": 1.66667,
#     "price_to_book": 63.855576,
#     "profit_margins": 0.45262
#   },
#   "MCD": {
#     "security_type": "Stock",
#     "name": "McDonald's Corporation",
#     "gics_sector": "Consumer Cyclical",
#     "sub_industry": "Restaurants",
#     "exchange": "NYQ",
#     "market_cap": 205598277632,
#     "avg_volume": 3586493,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0247,
#     "pe_ratio": 22.795422,
#     "beta": 0.735,
#     "52_week_high": 317.9,
#     "52_week_low": 243.53,
#     "analyst_rating": 2.02778,
#     "price_to_book": null,
#     "profit_margins": 0.3179
#   },
#   "MDLZ": {
#     "security_type": "Stock",
#     "name": "Mondelez International, Inc.",
#     "gics_sector": "Consumer Defensive",
#     "sub_industry": "Confectioners",
#     "exchange": "NMS",
#     "market_cap": 77944807424,
#     "avg_volume": 8056836,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0323,
#     "pe_ratio": 17.308548,
#     "beta": 0.561,
#     "52_week_high": 77.2,
#     "52_week_low": 57.67,
#     "analyst_rating": 1.73077,
#     "price_to_book": 2.7983677,
#     "profit_margins": 0.10556
#   },
#   "MDT": {
#     "security_type": "Stock",
#     "name": "Medtronic plc",
#     "gics_sector": "Healthcare",
#     "sub_industry": "Medical Devices",
#     "exchange": "NYQ",
#     "market_cap": 106019741696,
#     "avg_volume": 6110478,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.032,
#     "pe_ratio": 14.158455,
#     "beta": 0.853,
#     "52_week_high": 92.68,
#     "52_week_low": 75.96,
#     "analyst_rating": 2.25,
#     "price_to_book": 2.1591978,
#     "profit_margins": 0.12055001
#   },
#   "MET": {
#     "security_type": "Stock",
#     "name": "MetLife, Inc.",
#     "gics_sector": "Financial Services",
#     "sub_industry": "Insurance - Life",
#     "exchange": "NYQ",
#     "market_cap": 57346220032,
#     "avg_volume": 3206449,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.026300002,
#     "pe_ratio": 8.580907,
#     "beta": 1.039,
#     "52_week_high": 89.05,
#     "52_week_low": 64.61,
#     "analyst_rating": 1.8,
#     "price_to_book": 1.8600786,
#     "profit_margins": 0.052729998
#   },
#   "META": {
#     "security_type": "Stock",
#     "name": "Meta Platforms, Inc.",
#     "gics_sector": "Communication Services",
#     "sub_industry": "Internet Content & Information",
#     "exchange": "NMS",
#     "market_cap": 1541756420096,
#     "avg_volume": 12181527,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0033000002,
#     "pe_ratio": 24.018023,
#     "beta": 1.215,
#     "52_week_high": 638.4,
#     "52_week_low": 358.61,
#     "analyst_rating": 1.5,
#     "price_to_book": 9.368883,
#     "profit_margins": 0.35549998
#   },
#   "MMC": {
#     "security_type": "Stock",
#     "name": "Marsh & McLennan Companies, Inc.",
#     "gics_sector": "Financial Services",
#     "sub_industry": "Insurance Brokers",
#     "exchange": "NYQ",
#     "market_cap": 103798636544,
#     "avg_volume": 1813893,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0154,
#     "pe_ratio": 22.239456,
#     "beta": 0.937,
#     "52_week_high": 235.5,
#     "52_week_low": 188.31,
#     "analyst_rating": 2.7,
#     "price_to_book": 7.581791,
# ...
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 47.44,
#     "52_week_low": 37.48,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "XLF": {
#     "security_type": "ETF",
#     "name": "The Financial Select Sector SPDR Fund",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 40913847,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 51.62,
#     "52_week_low": 36.95,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "SOXL": {
#     "security_type": "ETF",
#     "name": "Direxion Daily Semiconductor Bull 3X Shares",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 75619554,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 70.08,
#     "52_week_low": 23.5,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "IWM": {
#     "security_type": "ETF",
#     "name": "iShares Russell 2000 ETF",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 26521042,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 244.98,
#     "52_week_low": 187.53,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "UPRO": {
#     "security_type": "ETF",
#     "name": "ProShares UltraPro S&P500",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 3814527,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 100.06,
#     "52_week_low": 52.5,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "SMH": {
#     "security_type": "ETF",
#     "name": "VanEck Semiconductor ETF",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "NGM",
#     "market_cap": null,
#     "avg_volume": 5646778,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 283.07,
#     "52_week_low": 171.49,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "SH": {
#     "security_type": "ETF",
#     "name": "ProShares Short S&P500",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 4996488,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 52.72,
#     "52_week_low": 11.24,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "GLD": {
#     "security_type": "ETF",
#     "name": "SPDR Gold Shares",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 6409852,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 257.71,
#     "52_week_low": 183.78,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "XLE": {
#     "security_type": "ETF",
#     "name": "The Energy Select Sector SPDR Fund",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 12431416,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 98.97,
#     "52_week_low": 78.98,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "VOO": {
#     "security_type": "ETF",
#     "name": "Vanguard S&P 500 ETF",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 5742660,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": true,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 559.96,
#     "52_week_low": 431.81,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "PSQ": {
#     "security_type": "ETF",
#     "name": "ProShares Short QQQ",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 3692826,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 48.3,
#     "52_week_low": 35.96,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "EFA": {
#     "security_type": "ETF",
#     "name": "iShares MSCI EAFE ETF",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 11862344,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 84.56,
#     "52_week_low": 72.58,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "FAS": {
#     "security_type": "ETF",
#     "name": "Direxion Daily Financial Bull 3X Shares",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 618611,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 184.88,
#     "52_week_low": 77.68,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "GDX": {
#     "security_type": "ETF",
#     "name": "VanEck Gold Miners ETF",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 20237037,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 44.22,
#     "52_week_low": 25.67,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "XLK": {
#     "security_type": "ETF",
#     "name": "The Technology Select Sector SPDR Fund",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 4233893,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 241.88,
#     "52_week_low": 189.69,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "SPXL": {
#     "security_type": "ETF",
#     "name": "Direxion Daily S&P500 Bull 3X Shares",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 3238849,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 190.34,
#     "52_week_low": 99.72,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "TLT": {
#     "security_type": "ETF",
#     "name": "iShares 20+ Year Treasury Bond ETF",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "NGM",
#     "market_cap": null,
#     "avg_volume": 40169286,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": -4301.5,
#     "beta": null,
#     "52_week_high": 101.64,
#     "52_week_low": 85.34,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "RWM": {
#     "security_type": "ETF",
#     "name": "ProShares Short Russell2000",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 5930272,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 22.62,
#     "52_week_low": 17.14,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "USO": {
#     "security_type": "ETF",
#     "name": "United States Oil Fund, LP",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 2933601,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 83.41,
#     "52_week_low": 66.02,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "ARKK": {
#     "security_type": "ETF",
#     "name": "ARK Innovation ETF",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 8534462,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 63.44,
#     "52_week_low": 36.85,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "VTI": {
#     "security_type": "ETF",
#     "name": "Vanguard Total Stock Market Index Fund ETF Shares",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 2967477,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": true,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 302.95,
#     "52_week_low": 233.43,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "IVV": {
#     "security_type": "ETF",
#     "name": "iShares Core S&P 500 ETF",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 6256347,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": true,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 612.09,
#     "52_week_low": 472.11,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "UVXY": {
#     "security_type": "ETF",
#     "name": "ProShares Ultra VIX Short-Term Futures ETF",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "BTS",
#     "market_cap": null,
#     "avg_volume": 12206745,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 65.87,
#     "52_week_low": 18.34,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "XLV": {
#     "security_type": "ETF",
#     "name": "The Health Care Select Sector SPDR Fund",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 7377280,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 159.64,
#     "52_week_low": 135.95,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "FXI": {
#     "security_type": "ETF",
#     "name": "iShares China Large-Cap ETF",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 47581263,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 37.5,
#     "52_week_low": 20.86,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "XLY": {
#     "security_type": "ETF",
#     "name": "The Consumer Discretionary Select Sector SPDR Fund",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 3050531,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 240.28,
#     "52_week_low": 166.48,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "XLI": {
#     "security_type": "ETF",
#     "name": "The Industrial Select Sector SPDR Fund",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 7596190,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 144.51,
#     "52_week_low": 109.95,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "XLU": {
#     "security_type": "ETF",
#     "name": "The Utilities Select Sector SPDR Fund",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 9839531,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 83.41,
#     "52_week_low": 59.14,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "XLP": {
#     "security_type": "ETF",
#     "name": "The Consumer Staples Select Sector SPDR Fund",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 8933881,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 84.53,
#     "52_week_low": 71.56,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   },
#   "XLB": {
#     "security_type": "ETF",
#     "name": "The Materials Select Sector SPDR Fund",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 4760626,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 97.87,
#     "52_week_low": 80.74,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null
#   }
# }

# %% [markdown]
# Option 2:  Formulates list from Dow 30, S&P 100, S&P 500, top 50 ETFs (AUM), an treasury rates.

# %%
# !pip install tenacity  # For retry logic
# Out:
# Requirement already satisfied: tenacity in /usr/local/lib/python3.10/dist-packages (9.0.0)

# %%
import yfinance as yf
import pandas as pd
from typing import List, Dict, Set
import json

class TickerAnalyzer:
    # Treasury rate symbols
    TREASURY_TICKERS = {
        "^IRX": "13-Week Treasury Bill",
        "^FVX": "5-Year Treasury Note",
        "^TNX": "10-Year Treasury Note",
        "^TYX": "30-Year Treasury Bond"
    }

    def __init__(self):
        # Initialize index constituent caches
        self.dow30_tickers = self._get_dow30_tickers()
        self.sp500_tickers = self._get_sp500_tickers()
        self.sp100_tickers = self._get_sp100_tickers()
        self.nasdaq100_tickers = self._get_nasdaq100_tickers()
        self.top50_etfs = self._get_top50_etfs()

        # Build consolidated ticker list
        self.all_tickers = self._build_consolidated_list()

        # Get current treasury rates
        self.treasury_rates = self._get_treasury_rates()

    def _build_consolidated_list(self) -> Set[str]:
        """Build consolidated list of all unique tickers to analyze."""
        all_tickers = set()

        # Add all index constituents
        all_tickers.update(self.dow30_tickers)
        all_tickers.update(self.sp500_tickers)
        all_tickers.update(self.sp100_tickers)
        all_tickers.update(self.nasdaq100_tickers)

        # Add top ETFs
        all_tickers.update(self.top50_etfs)

        return all_tickers

    def _get_treasury_rates(self) -> Dict[str, float]:
        """Fetch current treasury rates."""
        rates = {}
        for symbol, name in self.TREASURY_TICKERS.items():
            try:
                ticker = yf.Ticker(symbol)
                current_rate = ticker.info.get('regularMarketPrice', None)
                rates[name] = current_rate
            except Exception as e:
                rates[name] = f"Error: {str(e)}"
        return rates

    def analyze_tickers(self) -> Dict:
        """Analyze all tickers in the consolidated list."""
        results = {}

        for ticker in self.all_tickers:
            try:
                ticker_obj = yf.Ticker(ticker)
                info = ticker_obj.info

                # Determine if it's an ETF or stock
                security_type = "ETF" if info.get('quoteType') == 'ETF' else "Stock"

                results[ticker] = {
                    'security_type': security_type,
                    'name': info.get('longName'),
                    'gics_sector': info.get('sector'),
                    'sub_industry': info.get('industry'),
                    'exchange': info.get('exchange'),
                    'market_cap': info.get('marketCap'),
                    'avg_volume': info.get('averageVolume'),
                    'is_dow30': ticker in self.dow30_tickers,
                    'is_sp500': ticker in self.sp500_tickers,
                    'is_sp100': ticker in self.sp100_tickers,
                    'is_nasdaq100': ticker in self.nasdaq100_tickers,
                    'is_top50_etf': ticker in self.top50_etfs,
                    'dividend_yield': info.get('dividendYield'),

                    # Additional datapoints
                    'pe_ratio': info.get('forwardPE'),
                    'beta': info.get('beta'),
                    '52_week_high': info.get('fiftyTwoWeekHigh'),
                    '52_week_low': info.get('fiftyTwoWeekLow'),
                    'analyst_rating': info.get('recommendationMean'),
                    'price_to_book': info.get('priceToBook'),
                    'profit_margins': info.get('profitMargins'),

                    # ETF specific fields (will be None for stocks)
                    'expense_ratio': info.get('expense_ratio'),
                    'fund_family': info.get('fund_family'),
                    'fund_aum': info.get('totalAssets'),
                    'etf_category': info.get('category')
                }

            except Exception as e:
                results[ticker] = f"Error analyzing ticker: {str(e)}"

        # Add treasury rates section
        results['TREASURY_RATES'] = self.treasury_rates

        return results

    def _get_dow30_tickers(self) -> List[str]:
        """Fetch current Dow 30 constituents."""
        # Implementation needed - example list
        return ["AAPL", "MSFT", "JPM"]  # Example - needs to be updated

    def _get_sp500_tickers(self) -> List[str]:
        """Fetch current S&P 500 constituents."""
        # Implementation needed
        return []

    def _get_sp100_tickers(self) -> List[str]:
        """Fetch current S&P 100 constituents."""
        # Implementation needed
        return []

    def _get_nasdaq100_tickers(self) -> List[str]:
        """Fetch current NASDAQ 100 constituents."""
        # Implementation needed
        return []

    def _get_top50_etfs(self) -> List[str]:
        """Return list of top 50 ETFs by AUM."""
        return [
            "SPY",   # SPDR S&P 500 ETF Trust
            "IVV",   # iShares Core S&P 500 ETF
            "VOO",   # Vanguard S&P 500 ETF
            "VTI",   # Vanguard Total Stock Market ETF
            "QQQ",   # Invesco QQQ Trust
            "BND",   # Vanguard Total Bond Market ETF
            "VEA",   # Vanguard FTSE Developed Markets ETF
            "IEFA",  # iShares Core MSCI EAFE ETF
            "AGG",   # iShares Core U.S. Aggregate Bond ETF
            "VWO",   # Vanguard FTSE Emerging Markets ETF
            # ... Add remaining ETFs
        ]

def main():
    # Create analyzer and run analysis
    analyzer = TickerAnalyzer()
    results = analyzer.analyze_tickers()

    # Output results
    print("\nTreasury Rates:")
    print(json.dumps(results['TREASURY_RATES'], indent=2))

    print("\nSecurity Analysis:")
    print(json.dumps({k: v for k, v in results.items() if k != 'TREASURY_RATES'}, indent=2))

    # Save to CSV
    df = pd.DataFrame.from_dict({k: v for k, v in results.items() if k != 'TREASURY_RATES'}, orient='index')
    df.to_csv('ticker_analysis_results.csv')

    # Save treasury rates separately
    df_treasury = pd.DataFrame.from_dict(results['TREASURY_RATES'], orient='index', columns=['Rate'])
    df_treasury.to_csv('treasury_rates.csv')

if __name__ == "__main__":
    main()
# Out:
# Treasury Rates:
# {
#   "13-Week Treasury Bill": null,
#   "5-Year Treasury Note": null,
#   "10-Year Treasury Note": null,
#   "30-Year Treasury Bond": null
# }
#
# Security Analysis:
# {
#   "IVV": {
#     "security_type": "ETF",
#     "name": "iShares Core S&P 500 ETF",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 6256347,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": true,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 612.09,
#     "52_week_low": 472.11,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": 585743400960,
#     "etf_category": "Large Blend"
#   },
#   "VWO": {
#     "security_type": "ETF",
#     "name": "Vanguard Emerging Markets Stock Index Fund",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 7636867,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": true,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 49.57,
#     "52_week_low": 38.83,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": 108964061184,
#     "etf_category": "Diversified Emerging Mkts"
#   },
#   "BND": {
#     "security_type": "ETF",
#     "name": "Vanguard Total Bond Market Index Fund",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "NGM",
#     "market_cap": null,
#     "avg_volume": 6420926,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": true,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 75.67,
#     "52_week_low": 70.37,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": 342038380544,
#     "etf_category": "Intermediate Core Bond"
#   },
#   "MSFT": {
#     "security_type": "Stock",
#     "name": "Microsoft Corporation",
#     "gics_sector": "Technology",
#     "sub_industry": "Software - Infrastructure",
#     "exchange": "NMS",
#     "market_cap": 3156552712192,
#     "avg_volume": 20865454,
#     "is_dow30": true,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0078,
#     "pe_ratio": 28.282543,
#     "beta": 0.904,
#     "52_week_high": 468.35,
#     "52_week_low": 384.65,
#     "analyst_rating": 1.42105,
#     "price_to_book": 10.9725275,
#     "profit_margins": 0.35608003,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "IEFA": {
#     "security_type": "ETF",
#     "name": "iShares Core MSCI EAFE ETF",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "BTS",
#     "market_cap": null,
#     "avg_volume": 8617450,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": true,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 78.83,
#     "52_week_low": 67.64,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": 117813043200,
#     "etf_category": "Foreign Large Blend"
#   },
#   "SPY": {
#     "security_type": "ETF",
#     "name": "SPDR S&P 500 ETF Trust",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 46179218,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": true,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 609.07,
#     "52_week_low": 469.87,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": 623795240960,
#     "etf_category": "Large Blend"
#   },
#   "AGG": {
#     "security_type": "ETF",
#     "name": "iShares Core U.S. Aggregate Bond ETF",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 8932290,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": true,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 102.04,
#     "52_week_low": 94.85,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": 119716577280,
#     "etf_category": "Intermediate Core Bond"
#   },
#   "JPM": {
#     "security_type": "Stock",
#     "name": "JPMorgan Chase & Co.",
#     "gics_sector": "Financial Services",
#     "sub_industry": "Banks - Diversified",
#     "exchange": "NYQ",
#     "market_cap": 684493635584,
#     "avg_volume": 8770636,
#     "is_dow30": true,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.020599999,
#     "pe_ratio": 14.014719,
#     "beta": 1.091,
#     "52_week_high": 254.31,
#     "52_week_low": 164.3,
#     "analyst_rating": 2.26087,
#     "price_to_book": 2.11142,
#     "profit_margins": 0.33163,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "QQQ": {
#     "security_type": "ETF",
#     "name": "Invesco QQQ Trust",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "NGM",
#     "market_cap": null,
#     "avg_volume": 29472918,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": true,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 539.15,
#     "52_week_low": 402.92,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": 318905516032,
#     "etf_category": "Large Growth"
#   },
#   "AAPL": {
#     "security_type": "Stock",
#     "name": "Apple Inc.",
#     "gics_sector": "Technology",
#     "sub_industry": "Consumer Electronics",
#     "exchange": "NMS",
#     "market_cap": 3668604616704,
#     "avg_volume": 44577334,
#     "is_dow30": true,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0041,
#     "pe_ratio": 29.224627,
#     "beta": 1.24,
#     "52_week_high": 260.1,
#     "52_week_low": 164.08,
#     "analyst_rating": 1.89362,
#     "price_to_book": 64.427925,
#     "profit_margins": 0.23971,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "VOO": {
#     "security_type": "ETF",
#     "name": "Vanguard S&P 500 ETF",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 5742660,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": true,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 559.96,
#     "52_week_low": 431.81,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": 1349436178432,
#     "etf_category": "Large Blend"
#   },
#   "VEA": {
#     "security_type": "ETF",
#     "name": "Vanguard FTSE Developed Markets Index Fund ETF Shares",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 11044642,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": true,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 53.4,
#     "52_week_low": 45.91,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": 191386025984,
#     "etf_category": "Foreign Large Blend"
#   },
#   "VTI": {
#     "security_type": "ETF",
#     "name": "Vanguard Total Stock Market Index Fund ETF Shares",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 2967477,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": true,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 302.95,
#     "52_week_low": 233.43,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": 1777875943424,
#     "etf_category": "Large Blend"
#   }
# }

# %%
import yfinance as yf
import pandas as pd
from typing import List, Dict, Set
import json
from datetime import datetime

class TickerAnalyzer:
    # Treasury rate symbols
    TREASURY_TICKERS = {
        "^IRX": "13-Week Treasury Bill",
        "^FVX": "5-Year Treasury Note",
        "^TNX": "10-Year Treasury Note",
        "^TYX": "30-Year Treasury Bond"
    }

    # Last update date for constituent lists
    LAST_UPDATED = "2024-01-10"  # Update this date when constituent lists change

    def __init__(self):
        # Initialize index constituent caches
        self.dow30_tickers = self._get_dow30_tickers()
        self.sp500_tickers = self._get_sp500_tickers()
        self.sp100_tickers = self._get_sp100_tickers()
        self.nasdaq100_tickers = self._get_nasdaq100_tickers()
        self.top50_etfs = self._get_top50_etfs()

        # Build consolidated ticker list
        self.all_tickers = self._build_consolidated_list()

        # Get current treasury rates
        self.treasury_rates = self._get_treasury_rates()

    def _build_consolidated_list(self) -> Set[str]:
        """Build consolidated list of all unique tickers to analyze."""
        all_tickers = set()

        # Add all index constituents
        all_tickers.update(self.dow30_tickers)
        all_tickers.update(self.sp500_tickers)
        all_tickers.update(self.sp100_tickers)
        all_tickers.update(self.nasdaq100_tickers)

        # Add top ETFs (extract just the tickers from the dictionaries)
        all_tickers.update(etf['ticker'] for etf in self.top50_etfs)

        return all_tickers

    def _get_treasury_rates(self) -> Dict[str, float]:
        """Fetch current treasury rates."""
        rates = {}
        for symbol, name in self.TREASURY_TICKERS.items():
            try:
                ticker = yf.Ticker(symbol)
                current_rate = ticker.info.get('regularMarketPrice', None)
                rates[name] = current_rate
            except Exception as e:
                rates[name] = f"Error: {str(e)}"
        return rates

    def analyze_tickers(self) -> Dict:
        """Analyze all tickers in the consolidated list."""
        results = {}

        for ticker in self.all_tickers:
            try:
                ticker_obj = yf.Ticker(ticker)
                info = ticker_obj.info

                # Determine if it's an ETF or stock
                security_type = "ETF" if info.get('quoteType') == 'ETF' else "Stock"

                results[ticker] = {
                    'security_type': security_type,
                    'name': info.get('longName'),
                    'gics_sector': info.get('sector'),
                    'sub_industry': info.get('industry'),
                    'exchange': info.get('exchange'),
                    'market_cap': info.get('marketCap'),
                    'avg_volume': info.get('averageVolume'),
                    'is_dow30': ticker in self.dow30_tickers,
                    'is_sp500': ticker in self.sp500_tickers,
                    'is_sp100': ticker in self.sp100_tickers,
                    'is_nasdaq100': ticker in self.nasdaq100_tickers,
                    'is_top50_etf': ticker in self.top50_etfs,
                    'dividend_yield': info.get('dividendYield'),

                    # Additional datapoints
                    'pe_ratio': info.get('forwardPE'),
                    'beta': info.get('beta'),
                    '52_week_high': info.get('fiftyTwoWeekHigh'),
                    '52_week_low': info.get('fiftyTwoWeekLow'),
                    'analyst_rating': info.get('recommendationMean'),
                    'price_to_book': info.get('priceToBook'),
                    'profit_margins': info.get('profitMargins'),

                    # ETF specific fields (will be None for stocks)
                    'expense_ratio': info.get('expense_ratio'),
                    'fund_family': info.get('fund_family'),
                    'fund_aum': info.get('totalAssets'),
                    'etf_category': info.get('category')
                }

            except Exception as e:
                results[ticker] = f"Error analyzing ticker: {str(e)}"

        # Add treasury rates section
        results['TREASURY_RATES'] = self.treasury_rates

        return results

    def _get_dow30_tickers(self) -> List[str]:
        """Current Dow 30 constituents."""
        return [
            "AAPL", "AMGN", "AXP", "BA", "CAT", "CRM", "CSCO", "CVX", "DIS", "DOW",
            "GS", "HD", "HON", "IBM", "INTC", "JNJ", "JPM", "KO", "MCD", "MMM",
            "MRK", "MSFT", "NKE", "PG", "TRV", "UNH", "V", "VZ", "WBA", "WMT"
        ]

    def _get_sp100_tickers(self) -> List[str]:
        """Current S&P 100 constituents."""
        return [
            "AAPL", "ABBV", "ABT", "ACN", "ADBE", "AIG", "AMD", "AMGN", "AMT", "AMZN",
            "AVGO", "AXP", "BA", "BAC", "BK", "BKNG", "BLK", "BMY", "BRK.B", "C",
            "CAT", "CHTR", "CL", "CMCSA", "COF", "COP", "COST", "CRM", "CSCO", "CVS",
            "CVX", "DE", "DHR", "DIS", "DOW", "DUK", "EMR", "EXC", "F", "FDX",
            "GD", "GE", "GILD", "GM", "GOOG", "GOOGL", "GS", "HD", "HON", "IBM",
            "INTC", "JNJ", "JPM", "KHC", "KO", "LIN", "LLY", "LMT", "LOW", "MA",
            "MCD", "MDLZ", "MDT", "MET", "META", "MMM", "MO", "MRK", "MS", "MSFT",
            "NEE", "NFLX", "NKE", "NVDA", "ORCL", "PEP", "PFE", "PG", "PM", "PYPL",
            "QCOM", "RTX", "SBUX", "SCHW", "SO", "SPG", "T", "TGT", "TMO", "TMUS",
            "TXN", "UNH", "UNP", "UPS", "USB", "V", "VZ", "WBA", "WFC", "WMT", "XOM"
        ]

    def _get_nasdaq100_tickers(self) -> List[str]:
        """Current NASDAQ 100 constituents."""
        return [
            "AAPL", "ABNB", "ADBE", "ADI", "ADP", "ADSK", "AEP", "ALGN", "AMAT", "AMD",
            "AMGN", "AMZN", "ANSS", "ASML", "AVGO", "AZN", "BIIB", "BKNG", "BKR", "CDNS",
            "CEG", "CHTR", "CMCSA", "COST", "CPRT", "CRWD", "CSCO", "CSGP", "CSX", "CTAS",
            "CTSH", "DDOG", "DLTR", "DOCU", "DXCM", "EA", "EBAY", "ENPH", "EXC", "FANG",
            "FAST", "FISV", "FTNT", "GILD", "GOOG", "GOOGL", "HON", "IDXX", "ILMN", "INTC",
            "INTU", "ISRG", "JD", "KDP", "KHC", "KLAC", "LCID", "LRCX", "LULU", "MAR",
            "MCHP", "MDLZ", "MELI", "META", "MNST", "MRNA", "MRVL", "MSFT", "MTCH", "MU",
            "NFLX", "NVDA", "NXPI", "ODFL", "ORLY", "PANW", "PAYX", "PCAR", "PDD", "PEP",
            "PYPL", "QCOM", "REGN", "ROST", "SBUX", "SGEN", "SIRI", "SNPS", "TEAM", "TMUS",
            "TSLA", "TXN", "VRSK", "VRTX", "WBA", "WDAY", "XEL", "ZM", "ZS"
        ]

    def _get_sp500_tickers(self) -> List[str]:
        """Current S&P 500 constituents."""
        return [
            "A", "AAL", "AAP", "AAPL", "ABBV", "ABC", "ABT", "ACGL", "ACN", "ADBE",
            "ADI", "ADM", "ADP", "ADSK", "AEE", "AEP", "AES", "AFL", "AIG", "AIZ",
            "AJG", "AKAM", "ALB", "ALGN", "ALK", "ALL", "ALLE", "AMAT", "AMCR", "AMD",
            "AME", "AMGN", "AMP", "AMT", "AMZN", "ANET", "ANSS", "AON", "AOS", "APA",
            "APD", "APH", "APTV", "ARE", "ATO", "ATVI", "AVB", "AVGO", "AVY", "AWK",
            "AXP", "AZO", "BA", "BAC", "BALL", "BAX", "BBWI", "BBY", "BDX", "BEN",
            "BF.B", "BIIB", "BIO", "BK", "BKNG", "BKR", "BLK", "BMY", "BR", "BRK.B",
            "BRO", "BSX", "BWA", "BXP", "C", "CAG", "CAH", "CARR", "CAT", "CB",
            "CBOE", "CBRE", "CCI", "CCL",             "CDNS", "CDW", "CE", "CEG", "CF",
            "CFG", "CHD", "CHRW", "CHTR", "CI", "CINF", "CL", "CLX", "CMA", "CMCSA",
            "CME", "CMG", "CMI", "CMS", "CNC", "CNP", "COF", "COO", "COP", "COST",
            "CPB", "CPRT", "CPT", "CRL", "CRM", "CSCO", "CSGP", "CSX", "CTAS", "CTLT",
            "CTRA", "CTSH", "CTVA", "CVS", "CVX", "CZR", "D", "DAL", "DD", "DE",
            "DFS", "DG", "DGX", "DHI", "DHR", "DIS", "DLR", "DLTR", "DOV", "DOW",
            "DPZ", "DRI", "DTE", "DUK", "DVA", "DVN", "DXC", "DXCM", "EA", "EBAY",
            "ECL", "ED", "EFX", "EG", "EIX", "EL", "ELV", "EMN", "EMR", "ENPH",
            "EOG", "EPAM", "EQIX", "EQR", "EQT", "ES", "ESS", "ETN", "ETR", "ETSY",
            "EVRG", "EW", "EXC", "EXPD", "EXPE", "EXR", "F", "FANG", "FAST", "FCX",
            "FDS", "FDX", "FE", "FFIV", "FI", "FICO", "FIS", "FITB", "FLT", "FMC",
            "FOX", "FOXA", "FRT", "FSLR", "FTNT", "FTV", "GD", "GE", "GEHC", "GEN",
            "GILD", "GIS", "GL", "GLW", "GM", "GNRC", "GOOG", "GOOGL", "GPC", "GPN",
            "GRMN", "GS", "GWW", "HAL", "HAS", "HBAN", "HCA", "HD", "HES", "HIG",
            "HII", "HLT", "HOLX", "HON", "HPE", "HPQ", "HRL", "HSIC", "HST", "HSY",
            "HTZ", "HUBB", "HUM", "HWM", "IBM", "ICE", "IDXX", "IEX", "IFF", "ILMN",
            "INCY", "INTC", "INTU", "INVH", "IP", "IPG", "IQV", "IR", "IRM", "ISRG",
            "IT", "ITW", "IVZ", "J", "JBHT", "JCI", "JKHY", "JNJ", "JNPR", "JPM",
            "K", "KDP", "KEY", "KEYS", "KHC", "KIM", "KLAC", "KMB", "KMI", "KMX",
            "KO", "KR", "L", "LDOS", "LEN", "LH", "LHX", "LIN", "LKQ", "LLY",
            "LMT", "LNC", "LNT", "LOW", "LRCX", "LULU", "LUV", "LVS", "LW", "LYB",
            "LYV", "MA", "MAA", "MAR", "MAS", "MCD", "MCHP", "MCK", "MCO", "MDLZ",
            "MDT", "MET", "META", "MGM", "MHK", "MKC", "MKTX", "MLM", "MMC", "MMM",
            "MNST", "MO", "MOH", "MOS", "MPC", "MPWR", "MRK", "MRNA", "MRO", "MS",
            "MSCI", "MSFT", "MSI", "MTB", "MTCH", "MTD", "MU", "NCLH", "NDAQ", "NDSN",
            "NEE", "NEM", "NFLX", "NI", "NKE", "NOC", "NOW", "NRG", "NSC", "NTAP",
            "NTRS", "NUE", "NVDA", "NVR", "NWS", "NWSA", "NXPI", "O", "ODFL", "OGN",
            "OKE", "OMC", "ON", "ORCL", "ORLY", "OTIS", "OXY", "PARA", "PAYC", "PAYX",
            "PCAR", "PCG", "PEG", "PEP", "PFE", "PFG", "PG", "PGR", "PH", "PHM",
            "PKG", "PKI", "PLD", "PM", "PNC", "PNR", "PNW", "POOL", "PPG", "PPL",
            "PRU", "PSA", "PSX",             "PTC", "PWR", "PYPL", "QCOM", "QRVO", "RCL",
            "REG", "REGN", "RF", "RHI", "RJF", "RL", "RMD", "ROK", "ROL", "ROP",
            "ROST", "RSG", "RTX", "RVTY", "SBAC", "SBUX", "SCHW", "SEDG", "SEE", "SHW",
            "SJM", "SLB", "SNA", "SNPS", "SO", "SPG", "SPGI", "SRE", "STE", "STT",
            "STX", "STZ", "SWK", "SWKS", "SYF", "SYK", "SYY", "T", "TAP", "TDG",
            "TDY", "TECH", "TEL", "TER", "TFC", "TFX", "TGT", "TJX", "TMO", "TMUS",
            "TPR", "TRGP", "TRMB", "TROW", "TRV", "TSCO", "TSLA", "TSN", "TT", "TTWO",
            "TXN", "TXT", "TYL", "UAL", "UDR", "UHS", "ULTA", "UNH", "UNP", "UPS",
            "URI", "USB", "V", "VFC", "VICI", "VLO", "VMC", "VRSK", "VRSN", "VRTX",
            "VTR", "VTRS", "VZ", "WAB", "WAT", "WBA", "WBD", "WDC", "WEC", "WELL",
            "WFC", "WHR", "WM", "WMB", "WMT", "WRB", "WRK", "WST", "WTW", "WY",
            "WYNN", "XEL", "XOM", "XRAY", "XYL", "YUM", "ZBH", "ZBRA", "ZION", "ZTS",
            # Recent Additions
            "JBHT", "PODD", "JHG", "MCK", "UBER", "KVUE", "BRO", "GWW"
        ]

    def _get_top50_etfs(self) -> List[Dict]:
        """Return list of top 50 ETFs by AUM with categorization."""
        return [
            {"ticker": "SPY", "category": "Equity-US-Large-Cap", "sub_category": "S&P 500 Tracking"},
            {"ticker": "IVV", "category": "Equity-US-Large-Cap", "sub_category": "S&P 500 Tracking"},
            {"ticker": "VOO", "category": "Equity-US-Large-Cap", "sub_category": "S&P 500 Tracking"},
            {"ticker": "VTI", "category": "Equity-US-Total-Market", "sub_category": "Broad Market"},
            {"ticker": "QQQ", "category": "Equity-US-Large-Cap", "sub_category": "NASDAQ 100 Tracking"},
            {"ticker": "VEA", "category": "Equity-International", "sub_category": "Developed Markets"},
            {"ticker": "BND", "category": "Fixed-Income", "sub_category": "Total Bond Market"},
            {"ticker": "IEFA", "category": "Equity-International", "sub_category": "Developed Markets"},
            {"ticker": "AGG", "category": "Fixed-Income", "sub_category": "Total Bond Market"},
            {"ticker": "VWO", "category": "Equity-International", "sub_category": "Emerging Markets"},
            {"ticker": "JEPI", "category": "Equity-US-Large-Cap", "sub_category": "Income Strategy"},
            {"ticker": "LQD", "category": "Fixed-Income", "sub_category": "Corporate Bond"},
            {"ticker": "VCIT", "category": "Fixed-Income", "sub_category": "Corporate Bond"},
            {"ticker": "IEMG", "category": "Equity-International", "sub_category": "Emerging Markets"},
            {"ticker": "VIG", "category": "Equity-US-Large-Cap", "sub_category": "Dividend Growth"},
            {"ticker": "VXUS", "category": "Equity-International", "sub_category": "Total Market"},
            {"ticker": "VUG", "category": "Equity-US-Large-Cap", "sub_category": "Growth"},
            {"ticker": "VO", "category": "Equity-US-Mid-Cap", "sub_category": "Blend"},
            {"ticker": "VYM", "category": "Equity-US-Large-Cap", "sub_category": "High Dividend"},
            {"ticker": "VCSH", "category": "Fixed-Income", "sub_category": "Short-Term Corporate"},
            {"ticker": "VTV", "category": "Equity-US-Large-Cap", "sub_category": "Value"},
            {"ticker": "BSV", "category": "Fixed-Income", "sub_category": "Short-Term Bond"},
            {"ticker": "VB", "category": "Equity-US-Small-Cap", "sub_category": "Blend"},
            {"ticker": "SCHD", "category": "Equity-US-Large-Cap", "sub_category": "Dividend"},
            {"ticker": "HYG", "category": "Fixed-Income", "sub_category": "High Yield Corporate"},
            {"ticker": "RSP", "category": "Equity-US-Large-Cap", "sub_category": "Equal Weight"},
            {"ticker": "GOVT", "category": "Fixed-Income", "sub_category": "Government"},
            {"ticker": "TIP", "category": "Fixed-Income", "sub_category": "TIPS"},
            {"ticker": "IWF", "category": "Equity-US-Large-Cap", "sub_category": "Growth"},
            {"ticker": "MUB", "category": "Fixed-Income", "sub_category": "Municipal"},
            {"ticker": "IJH", "category": "Equity-US-Mid-Cap", "sub_category": "Blend"},
            {"ticker": "IWM", "category": "Equity-US-Small-Cap", "sub_category": "Russell 2000"},
            {"ticker": "DVY", "category": "Equity-US-Large-Cap", "sub_category": "Dividend"},
            {"ticker": "XLF", "category": "Equity-US-Sector", "sub_category": "Financials"},
            {"ticker": "XLK", "category": "Equity-US-Sector", "sub_category": "Technology"},
            {"ticker": "XLE", "category": "Equity-US-Sector", "sub_category": "Energy"},
            {"ticker": "USMV", "category": "Equity-US-Large-Cap", "sub_category": "Min Volatility"},
            {"ticker": "DGRO", "category": "Equity-US-Large-Cap", "sub_category": "Dividend Growth"},
            {"ticker": "XLV", "category": "Equity-US-Sector", "sub_category": "Healthcare"},
            {"ticker": "VGT", "category": "Equity-US-Sector", "sub_category": "Technology"},
            {"ticker": "SDY", "category": "Equity-US-Large-Cap", "sub_category": "Dividend"},
            {"ticker": "IWD", "category": "Equity-US-Large-Cap", "sub_category": "Value"},
            {"ticker": "GLD", "category": "Commodities", "sub_category": "Gold"},
            {"ticker": "XLI", "category": "Equity-US-Sector", "sub_category": "Industrials"},
            {"ticker": "VTIP", "category": "Fixed-Income", "sub_category": "Short-Term TIPS"},
            {"ticker": "VNQ", "category": "Real-Estate", "sub_category": "US REIT"},
            {"ticker": "XLP", "category": "Equity-US-Sector", "sub_category": "Consumer Staples"},
            {"ticker": "QUAL", "category": "Equity-US-Large-Cap", "sub_category": "Quality Factor"},
            {"ticker": "IVW", "category": "Equity-US-Large-Cap", "sub_category": "Growth"},
            {"ticker": "XLU", "category": "Equity-US-Sector", "sub_category": "Utilities"}
        ]

def main():
    # Create analyzer and run analysis
    analyzer = TickerAnalyzer()
    results = analyzer.analyze_tickers()

    # Add metadata about the analysis
    metadata = {
        'constituent_lists_last_updated': TickerAnalyzer.LAST_UPDATED,
        'analysis_run_date': datetime.now().strftime('%Y-%m-%d'),
        'total_tickers_analyzed': len(results) - 1,  # Subtract 1 for TREASURY_RATES
        'indices_included': ['S&P 500', 'Dow 30', 'S&P 100', 'NASDAQ 100', 'Top 50 ETFs'],
        'treasury_rates_included': list(TickerAnalyzer.TREASURY_TICKERS.values())
    }

    # Output results
    print("\nAnalysis Metadata:")
    print(json.dumps(metadata, indent=2))

    print("\nTreasury Rates:")
    print(json.dumps(results['TREASURY_RATES'], indent=2))

    print("\nSecurity Analysis:")
    print(json.dumps({k: v for k, v in results.items() if k != 'TREASURY_RATES'}, indent=2))

    # Save to CSV with metadata
    df = pd.DataFrame.from_dict({k: v for k, v in results.items() if k != 'TREASURY_RATES'}, orient='index')

    # Add metadata as additional rows at the top of the CSV
    with open('ticker_analysis_results.csv', 'w') as f:
        f.write('# Analysis Metadata\n')
        for key, value in metadata.items():
            f.write(f'# {key}: {value}\n')
        f.write('#\n')  # Empty line after metadata

    # Append the main data
    df.to_csv('ticker_analysis_results.csv', mode='a')

    # Save treasury rates separately
    df_treasury = pd.DataFrame.from_dict(results['TREASURY_RATES'], orient='index', columns=['Rate'])
    df_treasury.to_csv('treasury_rates.csv')

if __name__ == "__main__":
    main()
# Out:
# ERROR:yfinance:404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ATVI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ATVI&crumb=UIZDKdv788j
# ERROR:yfinance:404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/FLT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=FLT&crumb=UIZDKdv788j
# ERROR:yfinance:404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/WRK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=WRK&crumb=UIZDKdv788j
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/TSN?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=TSN&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/CMS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=CMS&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/PWR?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=PWR&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/CTVA?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=CTVA&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/C?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=C&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ABT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ABT&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ARE?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ARE&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ETR?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ETR&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SYF?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SYF&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/D?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=D&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/FOX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=FOX&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/TPR?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=TPR&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SBUX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SBUX&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/IDXX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=IDXX&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ZBH?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ZBH&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/APA?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=APA&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/FTV?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=FTV&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/TXN?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=TXN&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MNST?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MNST&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ABC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ABC&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/CAG?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=CAG&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MOS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MOS&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/BIO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=BIO&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/TTWO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=TTWO&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/CHTR?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=CHTR&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/UNH?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=UNH&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/COF?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=COF&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/FOXA?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=FOXA&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ISRG?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ISRG&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/CINF?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=CINF&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/PARA?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=PARA&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/TECH?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=TECH&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/WFC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=WFC&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SWK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SWK&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ZM?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ZM&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/APTV?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=APTV&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/PFE?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=PFE&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/CCI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=CCI&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/PH?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=PH&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NDSN?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NDSN&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LCID?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LCID&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NWS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NWS&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LYB?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LYB&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ALL?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ALL&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LRCX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LRCX&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/BLK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=BLK&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ANSS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ANSS&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/HON?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=HON&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ADM?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ADM&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/CPT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=CPT&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/GPN?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=GPN&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/CZR?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=CZR&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/A?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=A&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SDY?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SDY&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/TROW?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=TROW&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AES?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AES&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/GE?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=GE&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/PAYX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=PAYX&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AMT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AMT&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/DFS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=DFS&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MET?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MET&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/GRMN?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=GRMN&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LH?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LH&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LNC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LNC&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/PKG?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=PKG&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ZS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ZS&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/HUBB?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=HUBB&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NVR?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NVR&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SHW?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SHW&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AAPL?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AAPL&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ABNB?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ABNB&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/QQQ?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=QQQ&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/EOG?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=EOG&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AME?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AME&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NOW?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NOW&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/TFC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=TFC&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/GOOG?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=GOOG&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/HBAN?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=HBAN&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SBAC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SBAC&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/DG?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=DG&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/IEX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=IEX&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/KEYS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=KEYS&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/DOV?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=DOV&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/JCI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=JCI&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LYV?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LYV&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ALGN?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ALGN&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/UPS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=UPS&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/DXC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=DXC&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/HIG?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=HIG&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/VRTX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=VRTX&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/HOLX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=HOLX&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ROK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ROK&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/BXP?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=BXP&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/GOOGL?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=GOOGL&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/CRWD?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=CRWD&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AMP?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AMP&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MCO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MCO&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/META?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=META&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/CTAS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=CTAS&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/PSX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=PSX&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SNPS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SNPS&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/FISV?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=FISV&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LMT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LMT&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/WHR?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=WHR&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/IP?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=IP&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/PNR?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=PNR&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/DTE?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=DTE&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NVDA?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NVDA&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/TDY?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=TDY&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/PLD?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=PLD&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/PG?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=PG&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MSFT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MSFT&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/GNRC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=GNRC&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/VGT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=VGT&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/KMB?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=KMB&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AMZN?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AMZN&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/PEP?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=PEP&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/EIX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=EIX&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SPY?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SPY&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/UHS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=UHS&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/XLF?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=XLF&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/VRSN?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=VRSN&crumb=Edge%3A+Too+Many+Requests
# Analysis Metadata:
# {
#   "constituent_lists_last_updated": "2024-01-10",
#   "analysis_run_date": "2025-01-10",
#   "total_tickers_analyzed": 571,
#   "indices_included": [
#     "S&P 500",
#     "Dow 30",
#     "S&P 100",
#     "NASDAQ 100",
#     "Top 50 ETFs"
#   ],
#   "treasury_rates_included": [
#     "13-Week Treasury Bill",
#     "5-Year Treasury Note",
#     "10-Year Treasury Note",
#     "30-Year Treasury Bond"
#   ]
# }
#
# Treasury Rates:
# {
#   "13-Week Treasury Bill": null,
#   "5-Year Treasury Note": null,
#   "10-Year Treasury Note": null,
#   "30-Year Treasury Bond": null
# }
#
# Security Analysis:
# {
#   "ATVI": {
#     "security_type": "Stock",
#     "name": null,
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": null,
#     "market_cap": null,
#     "avg_volume": null,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": null,
#     "52_week_low": null,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "PTC": {
#     "security_type": "Stock",
#     "name": "PTC Inc.",
#     "gics_sector": "Technology",
#     "sub_industry": "Software - Application",
#     "exchange": "NMS",
#     "market_cap": 22188832768,
#     "avg_volume": 759486,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": 26.690641,
#     "beta": 1.174,
#     "52_week_high": 203.09,
#     "52_week_low": 163.3,
#     "analyst_rating": 1.8,
#     "price_to_book": 6.8891296,
#     "profit_margins": 0.16373,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "SEDG": {
#     "security_type": "Stock",
#     "name": "SolarEdge Technologies, Inc.",
#     "gics_sector": "Technology",
#     "sub_industry": "Solar",
#     "exchange": "NMS",
#     "market_cap": 868672000,
#     "avg_volume": 5437437,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": -5.7921395,
#     "beta": 1.585,
#     "52_week_high": 87.98,
#     "52_week_low": 10.24,
#     "analyst_rating": 3.14706,
#     "price_to_book": 0.89626306,
#     "profit_margins": -1.5818801,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "FMC": {
#     "security_type": "Stock",
#     "name": "FMC Corporation",
#     "gics_sector": "Basic Materials",
#     "sub_industry": "Agricultural Inputs",
#     "exchange": "NYQ",
#     "market_cap": 6280499200,
#     "avg_volume": 1342129,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0461,
#     "pe_ratio": 10.850835,
#     "beta": 0.853,
#     "52_week_high": 68.72,
#     "52_week_low": 47.71,
#     "analyst_rating": 2.26316,
#     "price_to_book": 1.3630084,
#     "profit_margins": 0.34931,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "NRG": {
#     "security_type": "Stock",
#     "name": "NRG Energy, Inc.",
#     "gics_sector": "Utilities",
#     "sub_industry": "Utilities - Independent Power Producers",
#     "exchange": "NYQ",
#     "market_cap": 19960854528,
#     "avg_volume": 2639078,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0165,
#     "pe_ratio": 13.584229,
#     "beta": 1.088,
#     "52_week_high": 103.14,
#     "52_week_low": 50.24,
#     "analyst_rating": null,
#     "price_to_book": 10.798904,
#     "profit_margins": 0.03428,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "UNP": {
#     "security_type": "Stock",
#     "name": "Union Pacific Corporation",
#     "gics_sector": "Industrials",
#     "sub_industry": "Railroads",
#     "exchange": "NYQ",
#     "market_cap": 140542509056,
#     "avg_volume": 2589765,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": true,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0231,
#     "pe_ratio": 19.097944,
#     "beta": 1.056,
#     "52_week_high": 258.66,
#     "52_week_low": 218.55,
#     "analyst_rating": 2.06667,
#     "price_to_book": 8.483806,
#     "profit_margins": 0.27326,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "DGRO": {
#     "security_type": "ETF",
#     "name": "iShares Core Dividend Growth ETF",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 1819280,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 65.08,
#     "52_week_low": 53.114,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": 30097102848,
#     "etf_category": "Large Value"
#   },
#   "CE": {
#     "security_type": "Stock",
#     "name": "Celanese Corporation",
#     "gics_sector": "Basic Materials",
#     "sub_industry": "Chemicals",
#     "exchange": "NYQ",
#     "market_cap": 7098721792,
#     "avg_volume": 2443619,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0424,
#     "pe_ratio": 7.232302,
#     "beta": 1.304,
#     "52_week_high": 172.16,
#     "52_week_low": 64.36,
#     "analyst_rating": 3.0,
#     "price_to_book": 0.97549987,
#     "profit_margins": 0.10402001,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "KMI": {
#     "security_type": "Stock",
#     "name": "Kinder Morgan, Inc.",
#     "gics_sector": "Energy",
#     "sub_industry": "Oil & Gas Midstream",
#     "exchange": "NYQ",
#     "market_cap": 62850195456,
#     "avg_volume": 13492265,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.040700004,
#     "pe_ratio": 22.406322,
#     "beta": 0.907,
#     "52_week_high": 28.81,
#     "52_week_low": 16.47,
#     "analyst_rating": null,
#     "price_to_book": 2.067076,
#     "profit_margins": 0.16765,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "PODD": {
#     "security_type": "Stock",
#     "name": "Insulet Corporation",
#     "gics_sector": "Healthcare",
#     "sub_industry": "Medical Devices",
#     "exchange": "NMS",
#     "market_cap": 18964346880,
#     "avg_volume": 550240,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": 68.77551,
#     "beta": 1.219,
#     "52_week_high": 279.77,
#     "52_week_low": 160.19,
#     "analyst_rating": 1.56522,
#     "price_to_book": 16.962168,
#     "profit_margins": 0.21215999,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "WY": {
#     "security_type": "Stock",
#     "name": "Weyerhaeuser Company",
#     "gics_sector": "Real Estate",
#     "sub_industry": "REIT - Specialty",
#     "exchange": "NYQ",
#     "market_cap": 20111790080,
#     "avg_volume": 3404667,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.028900001,
#     "pe_ratio": 30.751797,
#     "beta": 1.428,
#     "52_week_high": 36.27,
#     "52_week_low": 26.73,
#     "analyst_rating": 2.0,
#     "price_to_book": 2.0265026,
#     "profit_margins": 0.07427,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "CSCO": {
#     "security_type": "Stock",
#     "name": "Cisco Systems, Inc.",
#     "gics_sector": "Technology",
#     "sub_industry": "Communication Equipment",
#     "exchange": "NMS",
#     "market_cap": 235779391488,
#     "avg_volume": 19087449,
#     "is_dow30": true,
#     "is_sp500": true,
#     "is_sp100": true,
#     "is_nasdaq100": true,
#     "is_top50_etf": false,
#     "dividend_yield": 0.027,
#     "pe_ratio": 15.0417595,
#     "beta": null,
#     "52_week_high": 60.23,
#     "52_week_low": 44.5,
#     "analyst_rating": 2.32143,
#     "price_to_book": 5.2167788,
#     "profit_margins": 0.17731,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "ETSY": {
#     "security_type": "Stock",
#     "name": "Etsy, Inc.",
#     "gics_sector": "Consumer Cyclical",
#     "sub_industry": "Internet Retail",
#     "exchange": "NMS",
#     "market_cap": 6009322496,
#     "avg_volume": 3750703,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": 10.881433,
#     "beta": 1.992,
#     "52_week_high": 80.3,
#     "52_week_low": 47.1,
#     "analyst_rating": 2.71875,
#     "price_to_book": null,
#     "profit_margins": 0.091709994,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "DVN": {
#     "security_type": "Stock",
#     "name": "Devon Energy Corporation",
#     "gics_sector": "Energy",
#     "sub_industry": "Oil & Gas E&P",
#     "exchange": "NYQ",
#     "market_cap": 23090034688,
#     "avg_volume": 9780731,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.041300002,
#     "pe_ratio": 7.4587126,
#     "beta": 2.071,
#     "52_week_high": 55.09,
#     "52_week_low": 30.39,
#     "analyst_rating": 2.03226,
#     "price_to_book": 1.6199651,
#     "profit_margins": 0.23429,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "GLD": {
#     "security_type": "ETF",
#     "name": "SPDR Gold Shares",
#     "gics_sector": null,
#     "sub_industry": null,
#     "exchange": "PCX",
#     "market_cap": null,
#     "avg_volume": 6409852,
#     "is_dow30": false,
#     "is_sp500": false,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": null,
#     "pe_ratio": null,
#     "beta": null,
#     "52_week_high": 257.71,
#     "52_week_low": 183.78,
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": 73215074304,
#     "etf_category": "Commodities Focused"
#   },
#   "CDW": {
#     "security_type": "Stock",
#     "name": "CDW Corporation",
# ...
#     "analyst_rating": null,
#     "price_to_book": null,
#     "profit_margins": null,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": 13674561536,
#     "etf_category": "Inflation-Protected Bond"
#   },
#   "AMAT": {
#     "security_type": "Stock",
#     "name": "Applied Materials, Inc.",
#     "gics_sector": "Technology",
#     "sub_industry": "Semiconductor Equipment & Materials",
#     "exchange": "NMS",
#     "market_cap": 144014114816,
#     "avg_volume": 6789368,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": true,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0086,
#     "pe_ratio": 16.883076,
#     "beta": 1.551,
#     "52_week_high": 255.89,
#     "52_week_low": 149.84,
#     "analyst_rating": 1.89474,
#     "price_to_book": 7.744716,
#     "profit_margins": 0.27743,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "LVS": {
#     "security_type": "Stock",
#     "name": "Las Vegas Sands Corp.",
#     "gics_sector": "Consumer Cyclical",
#     "sub_industry": "Resorts & Casinos",
#     "exchange": "NYQ",
#     "market_cap": 35635027968,
#     "avg_volume": 4711818,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0163,
#     "pe_ratio": 17.561539,
#     "beta": 1.117,
#     "52_week_high": 56.61,
#     "52_week_low": 36.62,
#     "analyst_rating": 1.55,
#     "price_to_book": 10.399916,
#     "profit_margins": 0.1329,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "HAL": {
#     "security_type": "Stock",
#     "name": "Halliburton Company",
#     "gics_sector": "Energy",
#     "sub_industry": "Oil & Gas Equipment & Services",
#     "exchange": "NYQ",
#     "market_cap": 23745910784,
#     "avg_volume": 9189968,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0252,
#     "pe_ratio": 8.776943,
#     "beta": 1.905,
#     "52_week_high": 41.56,
#     "52_week_low": 25.51,
#     "analyst_rating": 1.73333,
#     "price_to_book": 2.3049374,
#     "profit_margins": 0.11038999,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "IFF": {
#     "security_type": "Stock",
#     "name": "International Flavors & Fragrances Inc.",
#     "gics_sector": "Basic Materials",
#     "sub_industry": "Specialty Chemicals",
#     "exchange": "NYQ",
#     "market_cap": 20983822336,
#     "avg_volume": 1461540,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0195,
#     "pe_ratio": 17.446075,
#     "beta": 1.238,
#     "52_week_high": 106.77,
#     "52_week_low": 72.94,
#     "analyst_rating": 1.86364,
#     "price_to_book": 1.420314,
#     "profit_margins": -0.20331,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "KIM": {
#     "security_type": "Stock",
#     "name": "Kimco Realty Corporation",
#     "gics_sector": "Real Estate",
#     "sub_industry": "REIT - Retail",
#     "exchange": "NYQ",
#     "market_cap": 14856745984,
#     "avg_volume": 3962836,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.0454,
#     "pe_ratio": 29.741985,
#     "beta": 1.485,
#     "52_week_high": 25.83,
#     "52_week_low": 17.57,
#     "analyst_rating": 2.34783,
#     "price_to_book": 1.4118251,
#     "profit_margins": 0.1958,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "PPG": {
#     "security_type": "Stock",
#     "name": "PPG Industries, Inc.",
#     "gics_sector": "Basic Materials",
#     "sub_industry": "Specialty Chemicals",
#     "exchange": "NYQ",
#     "market_cap": 26840080384,
#     "avg_volume": 1777119,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": false,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.023,
#     "pe_ratio": 13.260845,
#     "beta": 1.254,
#     "52_week_high": 147.7,
#     "52_week_low": 113.49,
#     "analyst_rating": 2.14815,
#     "price_to_book": 3.4463344,
#     "profit_margins": 0.08242,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "T": {
#     "security_type": "Stock",
#     "name": "AT&T Inc.",
#     "gics_sector": "Communication Services",
#     "sub_industry": "Telecom Services",
#     "exchange": "NYQ",
#     "market_cap": 159147933696,
#     "avg_volume": 34339944,
#     "is_dow30": false,
#     "is_sp500": true,
#     "is_sp100": true,
#     "is_nasdaq100": false,
#     "is_top50_etf": false,
#     "dividend_yield": 0.05,
#     "pe_ratio": 10.180289,
#     "beta": 0.73,
#     "52_week_high": 24.03,
#     "52_week_low": 15.94,
#     "analyst_rating": 2.10714,
#     "price_to_book": 1.5547456,
#     "profit_margins": 0.07419,
#     "expense_ratio": null,
#     "fund_family": null,
#     "fund_aum": null,
#     "etf_category": null
#   },
#   "NTAP": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "TSN": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "CMS": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "PWR": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "CTVA": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "C": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "ABT": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "ARE": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "ETR": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "SYF": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "D": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "FOX": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "TPR": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "SBUX": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "IDXX": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "ZBH": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "APA": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "FTV": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "TXN": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "MNST": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "ABC": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "CAG": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "MOS": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "BIO": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "TTWO": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "CHTR": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "UNH": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "COF": "Error analyzing ticker: Response ended prematurely",
#   "FOXA": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "ISRG": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "CINF": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "PARA": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "TECH": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "WFC": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "SWK": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "ZM": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "APTV": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "PFE": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "CCI": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "PH": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "NDSN": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "LCID": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "NWS": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "LYB": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "ALL": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "LRCX": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "BLK": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "ANSS": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "HON": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "ADM": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "CPT": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "GPN": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "CZR": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "A": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "SDY": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "TROW": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "AES": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "GE": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "PAYX": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "AMT": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "DFS": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "MET": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "GRMN": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "LH": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "LNC": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "PKG": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "ZS": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "HUBB": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "NVR": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "SHW": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "AAPL": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "ABNB": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "QQQ": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "EOG": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "AME": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "NOW": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "TFC": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "GOOG": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "HBAN": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "SBAC": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "DG": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "IEX": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "KEYS": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "DOV": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "JCI": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "LYV": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "ALGN": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "UPS": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "DXC": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "HIG": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "VRTX": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "HOLX": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "ROK": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "BXP": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "GOOGL": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "CRWD": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "AMP": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "MCO": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "META": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "CTAS": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "PSX": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "SNPS": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "FISV": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "LMT": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "WHR": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "IP": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "PNR": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "DTE": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "NVDA": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "TDY": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "PLD": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "PG": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "MSFT": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "GNRC": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "VGT": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "KMB": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "AMZN": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "PEP": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "EIX": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "SPY": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "UHS": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "XLF": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)",
#   "VRSN": "Error analyzing ticker: Expecting value: line 1 column 1 (char 0)"
# }
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-0abe493ff5b8> in <cell line: 302>()
#     301
#     302 if __name__ == "__main__":
# --> 303     main()
#
# <ipython-input-9-0abe493ff5b8> in main()
#     284
#     285     # Save to CSV with metadata
# --> 286     df = pd.DataFrame.from_dict({k: v for k, v in results.items() if k != 'TREASURY_RATES'}, orient='index')
#     287
#     288     # Add metadata as additional rows at the top of the CSV
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype, columns)
#    1899                 # TODO speed up Series case
#    1900                 if isinstance(next(iter(data.values())), (Series, dict)):
# -> 1901                     data = _from_nested_dict(data)
#    1902                 else:
#    1903                     index = list(data.keys())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _from_nested_dict(data)
#   12668     new_data: collections.defaultdict = collections.defaultdict(dict)
#   12669     for index, s in data.items():
# > 12670         for col, v in s.items():
#   12671             new_data[col][index] = v
#   12672     return new_data
#
# AttributeError: 'str' object has no attribute 'items'

# %%
import yfinance as yf
import pandas as pd
from typing import List, Dict, Set
import json
from datetime import datetime

class TickerAnalyzer:
    # Treasury rate symbols
    TREASURY_TICKERS = {
        "^IRX": "13-Week Treasury Bill",
        "^FVX": "5-Year Treasury Note",
        "^TNX": "10-Year Treasury Note",
        "^TYX": "30-Year Treasury Bond"
    }

    # Last update date for constituent lists
    LAST_UPDATED = "2024-01-10"  # Update this date when constituent lists change

    def __init__(self):
        # Initialize index constituent caches
        self.dow30_tickers = self._get_dow30_tickers()
        self.sp500_tickers = self._get_sp500_tickers()
        self.sp100_tickers = self._get_sp100_tickers()
        self.nasdaq100_tickers = self._get_nasdaq100_tickers()
        self.top50_etfs = self._get_top50_etfs()

        # Build consolidated ticker list
        self.all_tickers = self._build_consolidated_list()

        # Get current treasury rates
        self.treasury_rates = self._get_treasury_rates()

    def _build_consolidated_list(self) -> Set[str]:
        """Build consolidated list of all unique tickers to analyze."""
        all_tickers = set()

        # Add all index constituents
        all_tickers.update(self.dow30_tickers)
        all_tickers.update(self.sp500_tickers)
        all_tickers.update(self.sp100_tickers)
        all_tickers.update(self.nasdaq100_tickers)

        # Add top ETFs (extract just the tickers from the dictionaries)
        all_tickers.update(etf['ticker'] for etf in self.top50_etfs)

        return all_tickers

    def _get_treasury_rates(self) -> Dict[str, float]:
        """Fetch current treasury rates."""
        rates = {}
        for symbol, name in self.TREASURY_TICKERS.items():
            try:
                ticker = yf.Ticker(symbol)
                current_rate = ticker.info.get('regularMarketPrice', None)
                rates[name] = current_rate
            except Exception as e:
                rates[name] = f"Error: {str(e)}"
        return rates

    def analyze_tickers(self) -> Dict:
        """Analyze all tickers in the consolidated list with rate limiting."""
        results = {}

        # Add rate limiting
        import time
        from tenacity import retry, stop_after_attempt, wait_exponential

        @retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
        def fetch_ticker_info(ticker: str) -> Dict:
            """Fetch ticker info with retry logic."""
            ticker_obj = yf.Ticker(ticker)
            info = ticker_obj.info
            if not info:
                raise ValueError(f"No data received for {ticker}")
            return info

        for ticker in self.all_tickers:
            try:
                # Add delay between requests to avoid rate limiting
                time.sleep(0.5)  # 500ms delay between requests

                info = fetch_ticker_info(ticker)

                # Determine if it's an ETF or stock
                security_type = "ETF" if info.get('quoteType') == 'ETF' else "Stock"

                results[ticker] = {
                    'security_type': security_type,
                    'name': info.get('longName'),
                    'gics_sector': info.get('sector'),
                    'sub_industry': info.get('industry'),
                    'exchange': info.get('exchange'),
                    'market_cap': info.get('marketCap'),
                    'avg_volume': info.get('averageVolume'),
                    'is_dow30': ticker in self.dow30_tickers,
                    'is_sp500': ticker in self.sp500_tickers,
                    'is_sp100': ticker in self.sp100_tickers,
                    'is_nasdaq100': ticker in self.nasdaq100_tickers,
                    'is_top50_etf': ticker in self.top50_etfs,
                    'dividend_yield': info.get('dividendYield'),

                    # Additional datapoints
                    'pe_ratio': info.get('forwardPE'),
                    'beta': info.get('beta'),
                    '52_week_high': info.get('fiftyTwoWeekHigh'),
                    '52_week_low': info.get('fiftyTwoWeekLow'),
                    'analyst_rating': info.get('recommendationMean'),
                    'price_to_book': info.get('priceToBook'),
                    'profit_margins': info.get('profitMargins'),

                    # ETF specific fields (will be None for stocks)
                    'expense_ratio': info.get('expense_ratio'),
                    'fund_family': info.get('fund_family'),
                    'fund_aum': info.get('totalAssets'),
                    'etf_category': info.get('category')
                }

            except Exception as e:
                results[ticker] = f"Error analyzing ticker: {str(e)}"

        # Add treasury rates section
        results['TREASURY_RATES'] = self.treasury_rates

        return results

    def _get_dow30_tickers(self) -> List[str]:
        """Current Dow 30 constituents."""
        return [
            "AAPL", "AMGN", "AXP", "BA", "CAT", "CRM", "CSCO", "CVX", "DIS", "DOW",
            "GS", "HD", "HON", "IBM", "INTC", "JNJ", "JPM", "KO", "MCD", "MMM",
            "MRK", "MSFT", "NKE", "PG", "TRV", "UNH", "V", "VZ", "WBA", "WMT"
        ]

    def _get_sp100_tickers(self) -> List[str]:
        """Current S&P 100 constituents."""
        return [
            "AAPL", "ABBV", "ABT", "ACN", "ADBE", "AIG", "AMD", "AMGN", "AMT", "AMZN",
            "AVGO", "AXP", "BA", "BAC", "BK", "BKNG", "BLK", "BMY", "BRK.B", "C",
            "CAT", "CHTR", "CL", "CMCSA", "COF", "COP", "COST", "CRM", "CSCO", "CVS",
            "CVX", "DE", "DHR", "DIS", "DOW", "DUK", "EMR", "EXC", "F", "FDX",
            "GD", "GE", "GILD", "GM", "GOOG", "GOOGL", "GS", "HD", "HON", "IBM",
            "INTC", "JNJ", "JPM", "KHC", "KO", "LIN", "LLY", "LMT", "LOW", "MA",
            "MCD", "MDLZ", "MDT", "MET", "META", "MMM", "MO", "MRK", "MS", "MSFT",
            "NEE", "NFLX", "NKE", "NVDA", "ORCL", "PEP", "PFE", "PG", "PM", "PYPL",
            "QCOM", "RTX", "SBUX", "SCHW", "SO", "SPG", "T", "TGT", "TMO", "TMUS",
            "TXN", "UNH", "UNP", "UPS", "USB", "V", "VZ", "WBA", "WFC", "WMT", "XOM"
        ]

    def _get_nasdaq100_tickers(self) -> List[str]:
        """Current NASDAQ 100 constituents."""
        return [
            "AAPL", "ABNB", "ADBE", "ADI", "ADP", "ADSK", "AEP", "ALGN", "AMAT", "AMD",
            "AMGN", "AMZN", "ANSS", "ASML", "AVGO", "AZN", "BIIB", "BKNG", "BKR", "CDNS",
            "CEG", "CHTR", "CMCSA", "COST", "CPRT", "CRWD", "CSCO", "CSGP", "CSX", "CTAS",
            "CTSH", "DDOG", "DLTR", "DOCU", "DXCM", "EA", "EBAY", "ENPH", "EXC", "FANG",
            "FAST", "FISV", "FTNT", "GILD", "GOOG", "GOOGL", "HON", "IDXX", "ILMN", "INTC",
            "INTU", "ISRG", "JD", "KDP", "KHC", "KLAC", "LCID", "LRCX", "LULU", "MAR",
            "MCHP", "MDLZ", "MELI", "META", "MNST", "MRNA", "MRVL", "MSFT", "MTCH", "MU",
            "NFLX", "NVDA", "NXPI", "ODFL", "ORLY", "PANW", "PAYX", "PCAR", "PDD", "PEP",
            "PYPL", "QCOM", "REGN", "ROST", "SBUX", "SGEN", "SIRI", "SNPS", "TEAM", "TMUS",
            "TSLA", "TXN", "VRSK", "VRTX", "WBA", "WDAY", "XEL", "ZM", "ZS"
        ]

    def _get_sp500_tickers(self) -> List[str]:
        """Current S&P 500 constituents."""
        return [
            "A", "AAL", "AAP", "AAPL", "ABBV", "ABC", "ABT", "ACGL", "ACN", "ADBE",
            "ADI", "ADM", "ADP", "ADSK", "AEE", "AEP", "AES", "AFL", "AIG", "AIZ",
            "AJG", "AKAM", "ALB", "ALGN", "ALK", "ALL", "ALLE", "AMAT", "AMCR", "AMD",
            "AME", "AMGN", "AMP", "AMT", "AMZN", "ANET", "ANSS", "AON", "AOS", "APA",
            "APD", "APH", "APTV", "ARE", "ATO", "ATVI", "AVB", "AVGO", "AVY", "AWK",
            "AXP", "AZO", "BA", "BAC", "BALL", "BAX", "BBWI", "BBY", "BDX", "BEN",
            "BF.B", "BIIB", "BIO", "BK", "BKNG", "BKR", "BLK", "BMY", "BR", "BRK.B",
            "BRO", "BSX", "BWA", "BXP", "C", "CAG", "CAH", "CARR", "CAT", "CB",
            "CBOE", "CBRE", "CCI", "CCL",             "CDNS", "CDW", "CE", "CEG", "CF",
            "CFG", "CHD", "CHRW", "CHTR", "CI", "CINF", "CL", "CLX", "CMA", "CMCSA",
            "CME", "CMG", "CMI", "CMS", "CNC", "CNP", "COF", "COO", "COP", "COST",
            "CPB", "CPRT", "CPT", "CRL", "CRM", "CSCO", "CSGP", "CSX", "CTAS", "CTLT",
            "CTRA", "CTSH", "CTVA", "CVS", "CVX", "CZR", "D", "DAL", "DD", "DE",
            "DFS", "DG", "DGX", "DHI", "DHR", "DIS", "DLR", "DLTR", "DOV", "DOW",
            "DPZ", "DRI", "DTE", "DUK", "DVA", "DVN", "DXC", "DXCM", "EA", "EBAY",
            "ECL", "ED", "EFX", "EG", "EIX", "EL", "ELV", "EMN", "EMR", "ENPH",
            "EOG", "EPAM", "EQIX", "EQR", "EQT", "ES", "ESS", "ETN", "ETR", "ETSY",
            "EVRG", "EW", "EXC", "EXPD", "EXPE", "EXR", "F", "FANG", "FAST", "FCX",
            "FDS", "FDX", "FE", "FFIV", "FI", "FICO", "FIS", "FITB", "FLT", "FMC",
            "FOX", "FOXA", "FRT", "FSLR", "FTNT", "FTV", "GD", "GE", "GEHC", "GEN",
            "GILD", "GIS", "GL", "GLW", "GM", "GNRC", "GOOG", "GOOGL", "GPC", "GPN",
            "GRMN", "GS", "GWW", "HAL", "HAS", "HBAN", "HCA", "HD", "HES", "HIG",
            "HII", "HLT", "HOLX", "HON", "HPE", "HPQ", "HRL", "HSIC", "HST", "HSY",
            "HTZ", "HUBB", "HUM", "HWM", "IBM", "ICE", "IDXX", "IEX", "IFF", "ILMN",
            "INCY", "INTC", "INTU", "INVH", "IP", "IPG", "IQV", "IR", "IRM", "ISRG",
            "IT", "ITW", "IVZ", "J", "JBHT", "JCI", "JKHY", "JNJ", "JNPR", "JPM",
            "K", "KDP", "KEY", "KEYS", "KHC", "KIM", "KLAC", "KMB", "KMI", "KMX",
            "KO", "KR", "L", "LDOS", "LEN", "LH", "LHX", "LIN", "LKQ", "LLY",
            "LMT", "LNC", "LNT", "LOW", "LRCX", "LULU", "LUV", "LVS", "LW", "LYB",
            "LYV", "MA", "MAA", "MAR", "MAS", "MCD", "MCHP", "MCK", "MCO", "MDLZ",
            "MDT", "MET", "META", "MGM", "MHK", "MKC", "MKTX", "MLM", "MMC", "MMM",
            "MNST", "MO", "MOH", "MOS", "MPC", "MPWR", "MRK", "MRNA", "MRO", "MS",
            "MSCI", "MSFT", "MSI", "MTB", "MTCH", "MTD", "MU", "NCLH", "NDAQ", "NDSN",
            "NEE", "NEM", "NFLX", "NI", "NKE", "NOC", "NOW", "NRG", "NSC", "NTAP",
            "NTRS", "NUE", "NVDA", "NVR", "NWS", "NWSA", "NXPI", "O", "ODFL", "OGN",
            "OKE", "OMC", "ON", "ORCL", "ORLY", "OTIS", "OXY", "PARA", "PAYC", "PAYX",
            "PCAR", "PCG", "PEG", "PEP", "PFE", "PFG", "PG", "PGR", "PH", "PHM",
            "PKG", "PKI", "PLD", "PM", "PNC", "PNR", "PNW", "POOL", "PPG", "PPL",
            "PRU", "PSA", "PSX",             "PTC", "PWR", "PYPL", "QCOM", "QRVO", "RCL",
            "REG", "REGN", "RF", "RHI", "RJF", "RL", "RMD", "ROK", "ROL", "ROP",
            "ROST", "RSG", "RTX", "RVTY", "SBAC", "SBUX", "SCHW", "SEDG", "SEE", "SHW",
            "SJM", "SLB", "SNA", "SNPS", "SO", "SPG", "SPGI", "SRE", "STE", "STT",
            "STX", "STZ", "SWK", "SWKS", "SYF", "SYK", "SYY", "T", "TAP", "TDG",
            "TDY", "TECH", "TEL", "TER", "TFC", "TFX", "TGT", "TJX", "TMO", "TMUS",
            "TPR", "TRGP", "TRMB", "TROW", "TRV", "TSCO", "TSLA", "TSN", "TT", "TTWO",
            "TXN", "TXT", "TYL", "UAL", "UDR", "UHS", "ULTA", "UNH", "UNP", "UPS",
            "URI", "USB", "V", "VFC", "VICI", "VLO", "VMC", "VRSK", "VRSN", "VRTX",
            "VTR", "VTRS", "VZ", "WAB", "WAT", "WBA", "WBD", "WDC", "WEC", "WELL",
            "WFC", "WHR", "WM", "WMB", "WMT", "WRB", "WRK", "WST", "WTW", "WY",
            "WYNN", "XEL", "XOM", "XRAY", "XYL", "YUM", "ZBH", "ZBRA", "ZION", "ZTS",
            # Recent Additions
            "JBHT", "PODD", "JHG", "MCK", "UBER", "KVUE", "BRO", "GWW"
        ]

    def _get_top50_etfs(self) -> List[Dict]:
        """Return list of top 50 ETFs by AUM with categorization."""
        return [
            {"ticker": "SPY", "category": "Equity-US-Large-Cap", "sub_category": "S&P 500 Tracking"},
            {"ticker": "IVV", "category": "Equity-US-Large-Cap", "sub_category": "S&P 500 Tracking"},
            {"ticker": "VOO", "category": "Equity-US-Large-Cap", "sub_category": "S&P 500 Tracking"},
            {"ticker": "VTI", "category": "Equity-US-Total-Market", "sub_category": "Broad Market"},
            {"ticker": "QQQ", "category": "Equity-US-Large-Cap", "sub_category": "NASDAQ 100 Tracking"},
            {"ticker": "VEA", "category": "Equity-International", "sub_category": "Developed Markets"},
            {"ticker": "BND", "category": "Fixed-Income", "sub_category": "Total Bond Market"},
            {"ticker": "IEFA", "category": "Equity-International", "sub_category": "Developed Markets"},
            {"ticker": "AGG", "category": "Fixed-Income", "sub_category": "Total Bond Market"},
            {"ticker": "VWO", "category": "Equity-International", "sub_category": "Emerging Markets"},
            {"ticker": "JEPI", "category": "Equity-US-Large-Cap", "sub_category": "Income Strategy"},
            {"ticker": "LQD", "category": "Fixed-Income", "sub_category": "Corporate Bond"},
            {"ticker": "VCIT", "category": "Fixed-Income", "sub_category": "Corporate Bond"},
            {"ticker": "IEMG", "category": "Equity-International", "sub_category": "Emerging Markets"},
            {"ticker": "VIG", "category": "Equity-US-Large-Cap", "sub_category": "Dividend Growth"},
            {"ticker": "VXUS", "category": "Equity-International", "sub_category": "Total Market"},
            {"ticker": "VUG", "category": "Equity-US-Large-Cap", "sub_category": "Growth"},
            {"ticker": "VO", "category": "Equity-US-Mid-Cap", "sub_category": "Blend"},
            {"ticker": "VYM", "category": "Equity-US-Large-Cap", "sub_category": "High Dividend"},
            {"ticker": "VCSH", "category": "Fixed-Income", "sub_category": "Short-Term Corporate"},
            {"ticker": "VTV", "category": "Equity-US-Large-Cap", "sub_category": "Value"},
            {"ticker": "BSV", "category": "Fixed-Income", "sub_category": "Short-Term Bond"},
            {"ticker": "VB", "category": "Equity-US-Small-Cap", "sub_category": "Blend"},
            {"ticker": "SCHD", "category": "Equity-US-Large-Cap", "sub_category": "Dividend"},
            {"ticker": "HYG", "category": "Fixed-Income", "sub_category": "High Yield Corporate"},
            {"ticker": "RSP", "category": "Equity-US-Large-Cap", "sub_category": "Equal Weight"},
            {"ticker": "GOVT", "category": "Fixed-Income", "sub_category": "Government"},
            {"ticker": "TIP", "category": "Fixed-Income", "sub_category": "TIPS"},
            {"ticker": "IWF", "category": "Equity-US-Large-Cap", "sub_category": "Growth"},
            {"ticker": "MUB", "category": "Fixed-Income", "sub_category": "Municipal"},
            {"ticker": "IJH", "category": "Equity-US-Mid-Cap", "sub_category": "Blend"},
            {"ticker": "IWM", "category": "Equity-US-Small-Cap", "sub_category": "Russell 2000"},
            {"ticker": "DVY", "category": "Equity-US-Large-Cap", "sub_category": "Dividend"},
            {"ticker": "XLF", "category": "Equity-US-Sector", "sub_category": "Financials"},
            {"ticker": "XLK", "category": "Equity-US-Sector", "sub_category": "Technology"},
            {"ticker": "XLE", "category": "Equity-US-Sector", "sub_category": "Energy"},
            {"ticker": "USMV", "category": "Equity-US-Large-Cap", "sub_category": "Min Volatility"},
            {"ticker": "DGRO", "category": "Equity-US-Large-Cap", "sub_category": "Dividend Growth"},
            {"ticker": "XLV", "category": "Equity-US-Sector", "sub_category": "Healthcare"},
            {"ticker": "VGT", "category": "Equity-US-Sector", "sub_category": "Technology"},
            {"ticker": "SDY", "category": "Equity-US-Large-Cap", "sub_category": "Dividend"},
            {"ticker": "IWD", "category": "Equity-US-Large-Cap", "sub_category": "Value"},
            {"ticker": "GLD", "category": "Commodities", "sub_category": "Gold"},
            {"ticker": "XLI", "category": "Equity-US-Sector", "sub_category": "Industrials"},
            {"ticker": "VTIP", "category": "Fixed-Income", "sub_category": "Short-Term TIPS"},
            {"ticker": "VNQ", "category": "Real-Estate", "sub_category": "US REIT"},
            {"ticker": "XLP", "category": "Equity-US-Sector", "sub_category": "Consumer Staples"},
            {"ticker": "QUAL", "category": "Equity-US-Large-Cap", "sub_category": "Quality Factor"},
            {"ticker": "IVW", "category": "Equity-US-Large-Cap", "sub_category": "Growth"},
            {"ticker": "XLU", "category": "Equity-US-Sector", "sub_category": "Utilities"}
        ]

def main():
    # Create analyzer and run analysis
    analyzer = TickerAnalyzer()
    results = analyzer.analyze_tickers()

    # Add metadata about the analysis
    metadata = {
        'constituent_lists_last_updated': TickerAnalyzer.LAST_UPDATED,
        'analysis_run_date': datetime.now().strftime('%Y-%m-%d'),
        'total_tickers_analyzed': len(results) - 1,  # Subtract 1 for TREASURY_RATES
        'indices_included': ['S&P 500', 'Dow 30', 'S&P 100', 'NASDAQ 100', 'Top 50 ETFs'],
        'treasury_rates_included': list(TickerAnalyzer.TREASURY_TICKERS.values())
    }

    # Output results
    print("\nAnalysis Metadata:")
    print(json.dumps(metadata, indent=2))

    print("\nTreasury Rates:")
    print(json.dumps(results['TREASURY_RATES'], indent=2))

    print("\nSecurity Analysis:")
    print(json.dumps({k: v for k, v in results.items() if k != 'TREASURY_RATES'}, indent=2))

    # Save to CSV with metadata
    df = pd.DataFrame.from_dict({k: v for k, v in results.items() if k != 'TREASURY_RATES'}, orient='index')

    # Add metadata as additional rows at the top of the CSV
    with open('ticker_analysis_results.csv', 'w') as f:
        f.write('# Analysis Metadata\n')
        for key, value in metadata.items():
            f.write(f'# {key}: {value}\n')
        f.write('#\n')  # Empty line after metadata

    # Append the main data
    df.to_csv('ticker_analysis_results.csv', mode='a')

    # Save treasury rates separately
    df_treasury = pd.DataFrame.from_dict(results['TREASURY_RATES'], orient='index', columns=['Rate'])
    df_treasury.to_csv('treasury_rates.csv')

if __name__ == "__main__":
    main()

# %%
import yfinance as yf
import pandas as pd
from typing import List, Dict, Set
import json
from datetime import datetime

class TickerAnalyzer:
    # Treasury rate symbols
    TREASURY_TICKERS = {
        "^IRX": "13-Week Treasury Bill",
        "^FVX": "5-Year Treasury Note",
        "^TNX": "10-Year Treasury Note",
        "^TYX": "30-Year Treasury Bond"
    }

    # Last update date for constituent lists
    LAST_UPDATED = "2024-01-10"  # Update this date when constituent lists change

    def __init__(self):
        # Initialize index constituent caches
        self.dow30_tickers = self._get_dow30_tickers()
        self.sp500_tickers = self._get_sp500_tickers()
        self.sp100_tickers = self._get_sp100_tickers()
        self.nasdaq100_tickers = self._get_nasdaq100_tickers()
        self.top50_etfs = self._get_top50_etfs()

        # Build consolidated ticker list
        self.all_tickers = self._build_consolidated_list()

        # Get current treasury rates
        self.treasury_rates = self._get_treasury_rates()

    def _build_consolidated_list(self) -> Set[str]:
        """Build consolidated list of all unique tickers to analyze."""
        all_tickers = set()

        # Add all index constituents
        all_tickers.update(self.dow30_tickers)
        all_tickers.update(self.sp500_tickers)
        all_tickers.update(self.sp100_tickers)
        all_tickers.update(self.nasdaq100_tickers)

        # Add top ETFs (extract just the tickers from the dictionaries)
        all_tickers.update(etf['ticker'] for etf in self.top50_etfs)

        return all_tickers

    def _get_treasury_rates(self) -> Dict[str, float]:
        """Fetch current treasury rates."""
        rates = {}
        for symbol, name in self.TREASURY_TICKERS.items():
            try:
                ticker = yf.Ticker(symbol)
                current_rate = ticker.info.get('regularMarketPrice', None)
                rates[name] = current_rate
            except Exception as e:
                rates[name] = f"Error: {str(e)}"
        return rates

    def analyze_tickers(self) -> Dict:
        """Analyze all tickers in the consolidated list with rate limiting."""
        results = {}

        # Add rate limiting
        import time
        from tenacity import retry, stop_after_attempt, wait_exponential

        @retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
        def fetch_ticker_info(ticker: str) -> Dict:
            """Fetch ticker info with retry logic."""
            ticker_obj = yf.Ticker(ticker)
            info = ticker_obj.info
            if not info:
                raise ValueError(f"No data received for {ticker}")
            return info

        for ticker in self.all_tickers:
            try:
                # Add delay between requests to avoid rate limiting
                time.sleep(0.5)  # 500ms delay between requests

                info = fetch_ticker_info(ticker)

                # Determine if it's an ETF or stock
                security_type = "ETF" if info.get('quoteType') == 'ETF' else "Stock"

                results[ticker] = {
                    'security_type': security_type,
                    'name': info.get('longName'),
                    'gics_sector': info.get('sector'),
                    'sub_industry': info.get('industry'),
                    'exchange': info.get('exchange'),
                    'market_cap': info.get('marketCap'),
                    'avg_volume': info.get('averageVolume'),
                    'is_dow30': ticker in self.dow30_tickers,
                    'is_sp500': ticker in self.sp500_tickers,
                    'is_sp100': ticker in self.sp100_tickers,
                    'is_nasdaq100': ticker in self.nasdaq100_tickers,
                    'is_top50_etf': ticker in self.top50_etfs,
                    'dividend_yield': info.get('dividendYield'),

                    # Additional datapoints
                    'pe_ratio': info.get('forwardPE'),
                    'beta': info.get('beta'),
                    '52_week_high': info.get('fiftyTwoWeekHigh'),
                    '52_week_low': info.get('fiftyTwoWeekLow'),
                    'analyst_rating': info.get('recommendationMean'),
                    'price_to_book': info.get('priceToBook'),
                    'profit_margins': info.get('profitMargins'),

                    # ETF specific fields (will be None for stocks)
                    'expense_ratio': info.get('expense_ratio'),
                    'fund_family': info.get('fund_family'),
                    'fund_aum': info.get('totalAssets'),
                    'etf_category': info.get('category')
                }

            except Exception as e:
                results[ticker] = f"Error analyzing ticker: {str(e)}"

        # Add treasury rates section
        results['TREASURY_RATES'] = self.treasury_rates

        return results

    def _get_dow30_tickers(self) -> List[str]:
        """Current Dow 30 constituents."""
        return [
            "AAPL", "AMGN", "AXP", "BA", "CAT", "CRM", "CSCO", "CVX", "DIS", "DOW",
            "GS", "HD", "HON", "IBM", "INTC", "JNJ", "JPM", "KO", "MCD", "MMM",
            "MRK", "MSFT", "NKE", "PG", "TRV", "UNH", "V", "VZ", "WBA", "WMT"
        ]

    def _get_sp100_tickers(self) -> List[str]:
        """Current S&P 100 constituents."""
        return [
            "AAPL", "ABBV", "ABT", "ACN", "ADBE", "AIG", "AMD", "AMGN", "AMT", "AMZN",
            "AVGO", "AXP", "BA", "BAC", "BK", "BKNG", "BLK", "BMY", "BRK.B", "C",
            "CAT", "CHTR", "CL", "CMCSA", "COF", "COP", "COST", "CRM", "CSCO", "CVS",
            "CVX", "DE", "DHR", "DIS", "DOW", "DUK", "EMR", "EXC", "F", "FDX",
            "GD", "GE", "GILD", "GM", "GOOG", "GOOGL", "GS", "HD", "HON", "IBM",
            "INTC", "JNJ", "JPM", "KHC", "KO", "LIN", "LLY", "LMT", "LOW", "MA",
            "MCD", "MDLZ", "MDT", "MET", "META", "MMM", "MO", "MRK", "MS", "MSFT",
            "NEE", "NFLX", "NKE", "NVDA", "ORCL", "PEP", "PFE", "PG", "PM", "PYPL",
            "QCOM", "RTX", "SBUX", "SCHW", "SO", "SPG", "T", "TGT", "TMO", "TMUS",
            "TXN", "UNH", "UNP", "UPS", "USB", "V", "VZ", "WBA", "WFC", "WMT", "XOM"
        ]

    def _get_nasdaq100_tickers(self) -> List[str]:
        """Current NASDAQ 100 constituents."""
        return [
            "AAPL", "ABNB", "ADBE", "ADI", "ADP", "ADSK", "AEP", "ALGN", "AMAT", "AMD",
            "AMGN", "AMZN", "ANSS", "ASML", "AVGO", "AZN", "BIIB", "BKNG", "BKR", "CDNS",
            "CEG", "CHTR", "CMCSA", "COST", "CPRT", "CRWD", "CSCO", "CSGP", "CSX", "CTAS",
            "CTSH", "DDOG", "DLTR", "DOCU", "DXCM", "EA", "EBAY", "ENPH", "EXC", "FANG",
            "FAST", "FISV", "FTNT", "GILD", "GOOG", "GOOGL", "HON", "IDXX", "ILMN", "INTC",
            "INTU", "ISRG", "JD", "KDP", "KHC", "KLAC", "LCID", "LRCX", "LULU", "MAR",
            "MCHP", "MDLZ", "MELI", "META", "MNST", "MRNA", "MRVL", "MSFT", "MTCH", "MU",
            "NFLX", "NVDA", "NXPI", "ODFL", "ORLY", "PANW", "PAYX", "PCAR", "PDD", "PEP",
            "PYPL", "QCOM", "REGN", "ROST", "SBUX", "SGEN", "SIRI", "SNPS", "TEAM", "TMUS",
            "TSLA", "TXN", "VRSK", "VRTX", "WBA", "WDAY", "XEL", "ZM", "ZS"
        ]

    def _get_sp500_tickers(self) -> List[str]:
        """Current S&P 500 constituents."""
        return [
            "A", "AAL", "AAP", "AAPL", "ABBV", "ABC", "ABT", "ACGL", "ACN", "ADBE",
            "ADI", "ADM", "ADP", "ADSK", "AEE", "AEP", "AES", "AFL", "AIG", "AIZ",
            "AJG", "AKAM", "ALB", "ALGN", "ALK", "ALL", "ALLE", "AMAT", "AMCR", "AMD",
            "AME", "AMGN", "AMP", "AMT", "AMZN", "ANET", "ANSS", "AON", "AOS", "APA",
            "APD", "APH", "APTV", "ARE", "ATO", "ATVI", "AVB", "AVGO", "AVY", "AWK",
            "AXP", "AZO", "BA", "BAC", "BALL", "BAX", "BBWI", "BBY", "BDX", "BEN",
            "BF.B", "BIIB", "BIO", "BK", "BKNG", "BKR", "BLK", "BMY", "BR", "BRK.B",
            "BRO", "BSX", "BWA", "BXP", "C", "CAG", "CAH", "CARR", "CAT", "CB",
            "CBOE", "CBRE", "CCI", "CCL",             "CDNS", "CDW", "CE", "CEG", "CF",
            "CFG", "CHD", "CHRW", "CHTR", "CI", "CINF", "CL", "CLX", "CMA", "CMCSA",
            "CME", "CMG", "CMI", "CMS", "CNC", "CNP", "COF", "COO", "COP", "COST",
            "CPB", "CPRT", "CPT", "CRL", "CRM", "CSCO", "CSGP", "CSX", "CTAS", "CTLT",
            "CTRA", "CTSH", "CTVA", "CVS", "CVX", "CZR", "D", "DAL", "DD", "DE",
            "DFS", "DG", "DGX", "DHI", "DHR", "DIS", "DLR", "DLTR", "DOV", "DOW",
            "DPZ", "DRI", "DTE", "DUK", "DVA", "DVN", "DXC", "DXCM", "EA", "EBAY",
            "ECL", "ED", "EFX", "EG", "EIX", "EL", "ELV", "EMN", "EMR", "ENPH",
            "EOG", "EPAM", "EQIX", "EQR", "EQT", "ES", "ESS", "ETN", "ETR", "ETSY",
            "EVRG", "EW", "EXC", "EXPD", "EXPE", "EXR", "F", "FANG", "FAST", "FCX",
            "FDS", "FDX", "FE", "FFIV", "FI", "FICO", "FIS", "FITB", "FLT", "FMC",
            "FOX", "FOXA", "FRT", "FSLR", "FTNT", "FTV", "GD", "GE", "GEHC", "GEN",
            "GILD", "GIS", "GL", "GLW", "GM", "GNRC", "GOOG", "GOOGL", "GPC", "GPN",
            "GRMN", "GS", "GWW", "HAL", "HAS", "HBAN", "HCA", "HD", "HES", "HIG",
            "HII", "HLT", "HOLX", "HON", "HPE", "HPQ", "HRL", "HSIC", "HST", "HSY",
            "HTZ", "HUBB", "HUM", "HWM", "IBM", "ICE", "IDXX", "IEX", "IFF", "ILMN",
            "INCY", "INTC", "INTU", "INVH", "IP", "IPG", "IQV", "IR", "IRM", "ISRG",
            "IT", "ITW", "IVZ", "J", "JBHT", "JCI", "JKHY", "JNJ", "JNPR", "JPM",
            "K", "KDP", "KEY", "KEYS", "KHC", "KIM", "KLAC", "KMB", "KMI", "KMX",
            "KO", "KR", "L", "LDOS", "LEN", "LH", "LHX", "LIN", "LKQ", "LLY",
            "LMT", "LNC", "LNT", "LOW", "LRCX", "LULU", "LUV", "LVS", "LW", "LYB",
            "LYV", "MA", "MAA", "MAR", "MAS", "MCD", "MCHP", "MCK", "MCO", "MDLZ",
            "MDT", "MET", "META", "MGM", "MHK", "MKC", "MKTX", "MLM", "MMC", "MMM",
            "MNST", "MO", "MOH", "MOS", "MPC", "MPWR", "MRK", "MRNA", "MRO", "MS",
            "MSCI", "MSFT", "MSI", "MTB", "MTCH", "MTD", "MU", "NCLH", "NDAQ", "NDSN",
            "NEE", "NEM", "NFLX", "NI", "NKE", "NOC", "NOW", "NRG", "NSC", "NTAP",
            "NTRS", "NUE", "NVDA", "NVR", "NWS", "NWSA", "NXPI", "O", "ODFL", "OGN",
            "OKE", "OMC", "ON", "ORCL", "ORLY", "OTIS", "OXY", "PARA", "PAYC", "PAYX",
            "PCAR", "PCG", "PEG", "PEP", "PFE", "PFG", "PG", "PGR", "PH", "PHM",
            "PKG", "PKI", "PLD", "PM", "PNC", "PNR", "PNW", "POOL", "PPG", "PPL",
            "PRU", "PSA", "PSX",             "PTC", "PWR", "PYPL", "QCOM", "QRVO", "RCL",
            "REG", "REGN", "RF", "RHI", "RJF", "RL", "RMD", "ROK", "ROL", "ROP",
            "ROST", "RSG", "RTX", "RVTY", "SBAC", "SBUX", "SCHW", "SEDG", "SEE", "SHW",
            "SJM", "SLB", "SNA", "SNPS", "SO", "SPG", "SPGI", "SRE", "STE", "STT",
            "STX", "STZ", "SWK", "SWKS", "SYF", "SYK", "SYY", "T", "TAP", "TDG",
            "TDY", "TECH", "TEL", "TER", "TFC", "TFX", "TGT", "TJX", "TMO", "TMUS",
            "TPR", "TRGP", "TRMB", "TROW", "TRV", "TSCO", "TSLA", "TSN", "TT", "TTWO",
            "TXN", "TXT", "TYL", "UAL", "UDR", "UHS", "ULTA", "UNH", "UNP", "UPS",
            "URI", "USB", "V", "VFC", "VICI", "VLO", "VMC", "VRSK", "VRSN", "VRTX",
            "VTR", "VTRS", "VZ", "WAB", "WAT", "WBA", "WBD", "WDC", "WEC", "WELL",
            "WFC", "WHR", "WM", "WMB", "WMT", "WRB", "WRK", "WST", "WTW", "WY",
            "WYNN", "XEL", "XOM", "XRAY", "XYL", "YUM", "ZBH", "ZBRA", "ZION", "ZTS",
            # Recent Additions
            "JBHT", "PODD", "JHG", "MCK", "UBER", "KVUE", "BRO", "GWW"
        ]

    def _get_top50_etfs(self) -> List[Dict]:
        """Return list of top 50 ETFs by AUM with categorization."""
        return [
            {"ticker": "SPY", "category": "Equity-US-Large-Cap", "sub_category": "S&P 500 Tracking"},
            {"ticker": "IVV", "category": "Equity-US-Large-Cap", "sub_category": "S&P 500 Tracking"},
            {"ticker": "VOO", "category": "Equity-US-Large-Cap", "sub_category": "S&P 500 Tracking"},
            {"ticker": "VTI", "category": "Equity-US-Total-Market", "sub_category": "Broad Market"},
            {"ticker": "QQQ", "category": "Equity-US-Large-Cap", "sub_category": "NASDAQ 100 Tracking"},
            {"ticker": "VEA", "category": "Equity-International", "sub_category": "Developed Markets"},
            {"ticker": "BND", "category": "Fixed-Income", "sub_category": "Total Bond Market"},
            {"ticker": "IEFA", "category": "Equity-International", "sub_category": "Developed Markets"},
            {"ticker": "AGG", "category": "Fixed-Income", "sub_category": "Total Bond Market"},
            {"ticker": "VWO", "category": "Equity-International", "sub_category": "Emerging Markets"},
            {"ticker": "JEPI", "category": "Equity-US-Large-Cap", "sub_category": "Income Strategy"},
            {"ticker": "LQD", "category": "Fixed-Income", "sub_category": "Corporate Bond"},
            {"ticker": "VCIT", "category": "Fixed-Income", "sub_category": "Corporate Bond"},
            {"ticker": "IEMG", "category": "Equity-International", "sub_category": "Emerging Markets"},
            {"ticker": "VIG", "category": "Equity-US-Large-Cap", "sub_category": "Dividend Growth"},
            {"ticker": "VXUS", "category": "Equity-International", "sub_category": "Total Market"},
            {"ticker": "VUG", "category": "Equity-US-Large-Cap", "sub_category": "Growth"},
            {"ticker": "VO", "category": "Equity-US-Mid-Cap", "sub_category": "Blend"},
            {"ticker": "VYM", "category": "Equity-US-Large-Cap", "sub_category": "High Dividend"},
            {"ticker": "VCSH", "category": "Fixed-Income", "sub_category": "Short-Term Corporate"},
            {"ticker": "VTV", "category": "Equity-US-Large-Cap", "sub_category": "Value"},
            {"ticker": "BSV", "category": "Fixed-Income", "sub_category": "Short-Term Bond"},
            {"ticker": "VB", "category": "Equity-US-Small-Cap", "sub_category": "Blend"},
            {"ticker": "SCHD", "category": "Equity-US-Large-Cap", "sub_category": "Dividend"},
            {"ticker": "HYG", "category": "Fixed-Income", "sub_category": "High Yield Corporate"},
            {"ticker": "RSP", "category": "Equity-US-Large-Cap", "sub_category": "Equal Weight"},
            {"ticker": "GOVT", "category": "Fixed-Income", "sub_category": "Government"},
            {"ticker": "TIP", "category": "Fixed-Income", "sub_category": "TIPS"},
            {"ticker": "IWF", "category": "Equity-US-Large-Cap", "sub_category": "Growth"},
            {"ticker": "MUB", "category": "Fixed-Income", "sub_category": "Municipal"},
            {"ticker": "IJH", "category": "Equity-US-Mid-Cap", "sub_category": "Blend"},
            {"ticker": "IWM", "category": "Equity-US-Small-Cap", "sub_category": "Russell 2000"},
            {"ticker": "DVY", "category": "Equity-US-Large-Cap", "sub_category": "Dividend"},
            {"ticker": "XLF", "category": "Equity-US-Sector", "sub_category": "Financials"},
            {"ticker": "XLK", "category": "Equity-US-Sector", "sub_category": "Technology"},
            {"ticker": "XLE", "category": "Equity-US-Sector", "sub_category": "Energy"},
            {"ticker": "USMV", "category": "Equity-US-Large-Cap", "sub_category": "Min Volatility"},
            {"ticker": "DGRO", "category": "Equity-US-Large-Cap", "sub_category": "Dividend Growth"},
            {"ticker": "XLV", "category": "Equity-US-Sector", "sub_category": "Healthcare"},
            {"ticker": "VGT", "category": "Equity-US-Sector", "sub_category": "Technology"},
            {"ticker": "SDY", "category": "Equity-US-Large-Cap", "sub_category": "Dividend"},
            {"ticker": "IWD", "category": "Equity-US-Large-Cap", "sub_category": "Value"},
            {"ticker": "GLD", "category": "Commodities", "sub_category": "Gold"},
            {"ticker": "XLI", "category": "Equity-US-Sector", "sub_category": "Industrials"},
            {"ticker": "VTIP", "category": "Fixed-Income", "sub_category": "Short-Term TIPS"},
            {"ticker": "VNQ", "category": "Real-Estate", "sub_category": "US REIT"},
            {"ticker": "XLP", "category": "Equity-US-Sector", "sub_category": "Consumer Staples"},
            {"ticker": "QUAL", "category": "Equity-US-Large-Cap", "sub_category": "Quality Factor"},
            {"ticker": "IVW", "category": "Equity-US-Large-Cap", "sub_category": "Growth"},
            {"ticker": "XLU", "category": "Equity-US-Sector", "sub_category": "Utilities"}
        ]

def main():
    # Create analyzer and run analysis
    analyzer = TickerAnalyzer()
    results = analyzer.analyze_tickers()

    # Add metadata about the analysis
    metadata = {
        'constituent_lists_last_updated': TickerAnalyzer.LAST_UPDATED,
        'analysis_run_date': datetime.now().strftime('%Y-%m-%d'),
        'total_tickers_analyzed': len([k for k in results.keys() if k != 'TREASURY_RATES']),
        'indices_included': ['S&P 500', 'Dow 30', 'S&P 100', 'NASDAQ 100', 'Top 50 ETFs'],
        'treasury_rates_included': list(TickerAnalyzer.TREASURY_TICKERS.values())
    }

    # Output results
    print("\nAnalysis Metadata:")
    print(json.dumps(metadata, indent=2))

    print("\nTreasury Rates:")
    print(json.dumps(results.get('TREASURY_RATES', {}), indent=2))

    # Filter out error messages and treasury rates for the main DataFrame
    valid_results = {
        k: v for k, v in results.items()
        if k != 'TREASURY_RATES' and isinstance(v, dict)
    }

    # Create separate error log
    error_results = {
        k: v for k, v in results.items()
        if k != 'TREASURY_RATES' and isinstance(v, str)
    }

    print("\nProcessing Summary:")
    print(f"Successfully processed: {len(valid_results)} tickers")
    print(f"Errors encountered: {len(error_results)} tickers")

    if error_results:
        print("\nError Log:")
        for ticker, error in error_results.items():
            print(f"{ticker}: {error}")

    # Save successful results to CSV
    if valid_results:
        df = pd.DataFrame.from_dict(valid_results, orient='index')

        # Add metadata as comments at the top of the CSV
        with open('ticker_analysis_results.csv', 'w') as f:
            f.write('# Analysis Metadata\n')
            for key, value in metadata.items():
                f.write(f'# {key}: {value}\n')
            f.write('#\n')  # Empty line after metadata

        # Append the main data
        df.to_csv('ticker_analysis_results.csv', mode='a')

    # Save errors to separate CSV
    if error_results:
        error_df = pd.DataFrame.from_dict(error_results, orient='index', columns=['error'])
        error_df.to_csv('ticker_analysis_errors.csv')

    # Save treasury rates
    if 'TREASURY_RATES' in results:
        df_treasury = pd.DataFrame.from_dict(results['TREASURY_RATES'], orient='index', columns=['Rate'])
        df_treasury.to_csv('treasury_rates.csv')

if __name__ == "__main__":
    main()

# %%
import yfinance as yf
import pandas as pd
from typing import List, Dict, Set
import json
from datetime import datetime
import time
from tenacity import retry, stop_after_attempt, wait_exponential

class TickerAnalyzer:
    # Treasury rate symbols
    TREASURY_TICKERS = {
        "^IRX": "13-Week Treasury Bill",
        "^FVX": "5-Year Treasury Note",
        "^TNX": "10-Year Treasury Note",
        "^TYX": "30-Year Treasury Bond"
    }

    # Last update date for constituent lists
    LAST_UPDATED = "2024-01-10"  # Update this date when constituent lists change

    def __init__(self):
        # Initialize index constituent caches
        self.dow30_tickers = self._get_dow30_tickers()
        self.sp500_tickers = self._get_sp500_tickers()
        self.sp100_tickers = self._get_sp100_tickers()
        self.nasdaq100_tickers = self._get_nasdaq100_tickers()
        self.top50_etfs = self._get_top50_etfs()

        # Build consolidated ticker list
        self.all_tickers = self._build_consolidated_list()

        # Get current treasury rates
        self.treasury_rates = self._get_treasury_rates()

    def _build_consolidated_list(self) -> Set[str]:
        """Build consolidated list of all unique tickers to analyze."""
        all_tickers = set()

        # Add all index constituents
        all_tickers.update(self.dow30_tickers)
        all_tickers.update(self.sp500_tickers)
        all_tickers.update(self.sp100_tickers)
        all_tickers.update(self.nasdaq100_tickers)

        # Add top ETFs (extract just the tickers from the dictionaries)
        all_tickers.update(etf['ticker'] for etf in self.top50_etfs)

        return all_tickers

    def _get_treasury_rates(self) -> Dict[str, float]:
        """Fetch current treasury rates."""
        rates = {}
        for symbol, name in self.TREASURY_TICKERS.items():
            try:
                ticker = yf.Ticker(symbol)
                current_rate = ticker.info.get('regularMarketPrice', None)
                rates[name] = current_rate
            except Exception as e:
                rates[name] = f"Error: {str(e)}"
        return rates

    def analyze_tickers(self) -> Dict:
        """Analyze all tickers in the consolidated list with rate limiting."""
        results = {}

        # Add rate limiting
        import time
        from tenacity import retry, stop_after_attempt, wait_exponential

        @retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
        def fetch_ticker_info(ticker: str) -> Dict:
            """Fetch ticker info with retry logic."""
            ticker_obj = yf.Ticker(ticker)
            info = ticker_obj.info
            if not info:
                raise ValueError(f"No data received for {ticker}")
            return info

        for ticker in self.all_tickers:
            try:
                # Add delay between requests to avoid rate limiting
                time.sleep(0.5)  # 500ms delay between requests

                info = fetch_ticker_info(ticker)

                # Determine if it's an ETF or stock
                security_type = "ETF" if info.get('quoteType') == 'ETF' else "Stock"

                results[ticker] = {
                    'security_type': security_type,
                    'name': info.get('longName'),
                    'gics_sector': info.get('sector'),
                    'sub_industry': info.get('industry'),
                    'exchange': info.get('exchange'),
                    'market_cap': info.get('marketCap'),
                    'avg_volume': info.get('averageVolume'),
                    'is_dow30': ticker in self.dow30_tickers,
                    'is_sp500': ticker in self.sp500_tickers,
                    'is_sp100': ticker in self.sp100_tickers,
                    'is_nasdaq100': ticker in self.nasdaq100_tickers,
                    'is_top50_etf': ticker in self.top50_etfs,
                    'dividend_yield': info.get('dividendYield'),

                    # Additional datapoints
                    'pe_ratio': info.get('forwardPE'),
                    'beta': info.get('beta'),
                    '52_week_high': info.get('fiftyTwoWeekHigh'),
                    '52_week_low': info.get('fiftyTwoWeekLow'),
                    'analyst_rating': info.get('recommendationMean'),
                    'price_to_book': info.get('priceToBook'),
                    'profit_margins': info.get('profitMargins'),

                    # ETF specific fields (will be None for stocks)
                    'expense_ratio': info.get('expense_ratio'),
                    'fund_family': info.get('fund_family'),
                    'fund_aum': info.get('totalAssets'),
                    'etf_category': info.get('category')
                }

            except Exception as e:
                results[ticker] = f"Error analyzing ticker: {str(e)}"

        # Add treasury rates section
        results['TREASURY_RATES'] = self.treasury_rates

        return results

    def _get_dow30_tickers(self) -> List[str]:
        """Current Dow 30 constituents."""
        return [
            "AAPL", "AMGN", "AXP", "BA", "CAT", "CRM", "CSCO", "CVX", "DIS", "DOW",
            "GS", "HD", "HON", "IBM", "INTC", "JNJ", "JPM", "KO", "MCD", "MMM",
            "MRK", "MSFT", "NKE", "PG", "TRV", "UNH", "V", "VZ", "WBA", "WMT"
        ]

    def _get_sp100_tickers(self) -> List[str]:
        """Current S&P 100 constituents."""
        return [
            "AAPL", "ABBV", "ABT", "ACN", "ADBE", "AIG", "AMD", "AMGN", "AMT", "AMZN",
            "AVGO", "AXP", "BA", "BAC", "BK", "BKNG", "BLK", "BMY", "BRK.B", "C",
            "CAT", "CHTR", "CL", "CMCSA", "COF", "COP", "COST", "CRM", "CSCO", "CVS",
            "CVX", "DE", "DHR", "DIS", "DOW", "DUK", "EMR", "EXC", "F", "FDX",
            "GD", "GE", "GILD", "GM", "GOOG", "GOOGL", "GS", "HD", "HON", "IBM",
            "INTC", "JNJ", "JPM", "KHC", "KO", "LIN", "LLY", "LMT", "LOW", "MA",
            "MCD", "MDLZ", "MDT", "MET", "META", "MMM", "MO", "MRK", "MS", "MSFT",
            "NEE", "NFLX", "NKE", "NVDA", "ORCL", "PEP", "PFE", "PG", "PM", "PYPL",
            "QCOM", "RTX", "SBUX", "SCHW", "SO", "SPG", "T", "TGT", "TMO", "TMUS",
            "TXN", "UNH", "UNP", "UPS", "USB", "V", "VZ", "WBA", "WFC", "WMT", "XOM"
        ]

    def _get_nasdaq100_tickers(self) -> List[str]:
        """Current NASDAQ 100 constituents."""
        return [
            "AAPL", "ABNB", "ADBE", "ADI", "ADP", "ADSK", "AEP", "ALGN", "AMAT", "AMD",
            "AMGN", "AMZN", "ANSS", "ASML", "AVGO", "AZN", "BIIB", "BKNG", "BKR", "CDNS",
            "CEG", "CHTR", "CMCSA", "COST", "CPRT", "CRWD", "CSCO", "CSGP", "CSX", "CTAS",
            "CTSH", "DDOG", "DLTR", "DOCU", "DXCM", "EA", "EBAY", "ENPH", "EXC", "FANG",
            "FAST", "FTNT", "GILD", "GOOG", "GOOGL", "HON", "IDXX", "ILMN", "INTC",
            "INTU", "ISRG", "JD", "KDP", "KHC", "KLAC", "LCID", "LRCX", "LULU", "MAR",
            "MCHP", "MDLZ", "MELI", "META", "MNST", "MRNA", "MRVL", "MSFT", "MTCH", "MU",
            "NFLX", "NVDA", "NXPI", "ODFL", "ORLY", "PANW", "PAYX", "PCAR", "PDD", "PEP",
            "PYPL", "QCOM", "REGN", "ROST", "SBUX", "SIRI", "SNPS", "TEAM", "TMUS",
            "TSLA", "TXN", "VRSK", "VRTX", "WBA", "WDAY", "XEL", "ZM", "ZS"
        ]

    def _get_sp500_tickers(self) -> List[str]:
        """Current S&P 500 constituents."""
        return [
            "A", "AAL", "AAP", "AAPL", "ABBV", "ABT", "ACGL", "ACN", "ADBE",
            "ADI", "ADM", "ADP", "ADSK", "AEE", "AEP", "AES", "AFL", "AIG", "AIZ",
            "AJG", "AKAM", "ALB", "ALGN", "ALK", "ALL", "ALLE", "AMAT", "AMCR", "AMD",
            "AME", "AMGN", "AMP", "AMT", "AMZN", "ANET", "ANSS", "AON", "AOS", "APA",
            "APD", "APH", "APTV", "ARE", "ATO", "AVB", "AVGO", "AVY", "AWK",
            "AXP", "AZO", "BA", "BAC", "BALL", "BAX", "BBWI", "BBY", "BDX", "BEN",
            "BF.B", "BIIB", "BIO", "BK", "BKNG", "BKR", "BLK", "BMY",
            "BRO", "BSX", "BWA", "BXP", "C", "CAG", "CAH", "CARR", "CAT", "CB",
            "CBOE", "CBRE", "CCI", "CCL", "CDNS", "CDW", "CE", "CEG", "CF",
            "CFG", "CHD", "CHRW", "CHTR", "CI", "CINF", "CL", "CLX", "CMA", "CMCSA",
            "CME", "CMG", "CMI", "CMS", "CNC", "CNP", "COF", "COO", "COP", "COST",
            "CPB", "CPRT", "CPT", "CRL", "CRM", "CSCO", "CSGP", "CSX", "CTAS", "CTLT",
            "CTRA", "CTSH", "CTVA", "CVS", "CVX", "CZR", "D", "DAL", "DD", "DE",
            "DFS", "DG", "DGX", "DHI", "DHR", "DIS", "DLR", "DLTR", "DOV", "DOW",
            "DPZ", "DRI", "DTE", "DUK", "DVA", "DVN", "DXC", "DXCM", "EA", "EBAY",
            "ECL", "ED", "EFX", "EG", "EIX", "EL", "ELV", "EMN", "EMR", "ENPH",
            "EOG", "EPAM", "EQIX", "EQR", "EQT", "ES", "ESS", "ETN", "ETR", "ETSY",
            "EVRG", "EW", "EXC", "EXPD", "EXPE", "EXR", "F", "FANG", "FAST", "FCX",
            "FDS", "FDX", "FE", "FFIV", "FI", "FICO", "FIS", "FITB", "FMC",
            "FOX", "FOXA", "FRT", "FSLR", "FTNT", "FTV", "GD", "GE", "GEHC", "GEN",
            "GILD", "GIS", "GL", "GLW", "GM", "GNRC", "GOOG", "GOOGL", "GPC", "GPN",
            "GRMN", "GS", "GWW", "HAL", "HAS", "HBAN", "HCA", "HD", "HES", "HIG",
            "HII", "HLT", "HOLX", "HON", "HPE", "HPQ", "HRL", "HSIC", "HST", "HSY",
            "HTZ", "HUBB", "HUM", "HWM", "IBM", "ICE", "IDXX", "IEX", "IFF", "ILMN",
            "INCY", "INTC", "INTU", "INVH", "IP", "IPG", "IQV", "IR", "IRM", "ISRG",
            "IT", "ITW", "IVZ", "J", "JBHT", "JCI", "JKHY", "JNJ", "JNPR", "JPM",
            "K", "KDP", "KEY", "KEYS", "KHC", "KIM", "KLAC", "KMB", "KMI", "KMX",
            "KO", "KR", "L", "LDOS", "LEN", "LH", "LHX", "LIN", "LKQ", "LLY",
            "LMT", "LNC", "LNT", "LOW", "LRCX", "LULU", "LUV", "LVS", "LW", "LYB",
            "LYV", "MA", "MAA", "MAR", "MAS", "MCD", "MCHP", "MCK", "MCO", "MDLZ",
            "MDT", "MET", "META", "MGM", "MHK", "MKC", "MKTX", "MLM", "MMC", "MMM",
            "MNST", "MO", "MOH", "MOS", "MPC", "MPWR", "MRK", "MRNA", "MRO", "MS",
            "MSCI", "MSFT", "MSI", "MTB", "MTCH", "MTD", "MU", "NCLH", "NDAQ", "NDSN",
            "NEE", "NEM", "NFLX", "NI", "NKE", "NOC", "NOW", "NRG", "NSC", "NTAP",
            "NTRS", "NUE", "NVDA", "NVR", "NWS", "NWSA", "NXPI", "O", "ODFL", "OGN",
            "OKE", "OMC", "ON", "ORCL", "ORLY", "OTIS", "OXY", "PARA", "PAYC", "PAYX",
            "PCAR", "PCG", "PEG", "PEP", "PFE", "PFG", "PG", "PGR", "PH", "PHM",
            "PKG", "PLD", "PM", "PNC", "PNR", "PNW", "POOL", "PPG", "PPL",
            "PRU", "PSA", "PSX", "PTC", "PWR", "PYPL", "QCOM", "QRVO", "RCL",
            "REG", "REGN", "RF", "RHI", "RJF", "RL", "RMD", "ROK", "ROL", "ROP",
            "ROST", "RSG", "RTX", "RVTY", "SBAC", "SBUX", "SCHW", "SEDG", "SEE", "SHW",
            "SJM", "SLB", "SNA", "SNPS", "SO", "SPG", "SPGI", "SRE", "STE", "STT",
            "STX", "STZ", "SWK", "SWKS", "SYF", "SYK", "SYY", "T", "TAP", "TDG",
            "TDY", "TECH", "TEL", "TER", "TFC", "TFX", "TGT", "TJX", "TMO", "TMUS",
            "TPR", "TRGP", "TRMB", "TROW", "TRV", "TSCO", "TSLA", "TSN", "TT", "TTWO",
            "TXN", "TXT", "TYL", "UAL", "UDR", "UHS", "ULTA", "UNH", "UNP", "UPS",
            "URI", "USB", "V", "VFC", "VICI", "VLO", "VMC", "VRSK", "VRSN", "VRTX",
            "VTR", "VTRS", "VZ", "WAB", "WAT", "WBA", "WBD", "WDC", "WEC", "WELL",
            "WFC", "WHR", "WM", "WMB", "WMT", "WRB", "WST", "WTW", "WY",
            "WYNN", "XEL", "XOM", "XRAY", "XYL", "YUM", "ZBH", "ZBRA", "ZION", "ZTS",
            # Recent Additions
            "JBHT", "PODD", "JHG", "MCK", "UBER", "KVUE", "BRO", "GWW"
        ]

    def _get_top50_etfs(self) -> List[Dict]:
        """Return list of top 50 ETFs by AUM with categorization."""
        return [
            {"ticker": "SPY", "category": "Equity-US-Large-Cap", "sub_category": "S&P 500 Tracking"},
            {"ticker": "IVV", "category": "Equity-US-Large-Cap", "sub_category": "S&P 500 Tracking"},
            {"ticker": "VOO", "category": "Equity-US-Large-Cap", "sub_category": "S&P 500 Tracking"},
            {"ticker": "VTI", "category": "Equity-US-Total-Market", "sub_category": "Broad Market"},
            {"ticker": "QQQ", "category": "Equity-US-Large-Cap", "sub_category": "NASDAQ 100 Tracking"},
            {"ticker": "VEA", "category": "Equity-International", "sub_category": "Developed Markets"},
            {"ticker": "BND", "category": "Fixed-Income", "sub_category": "Total Bond Market"},
            {"ticker": "IEFA", "category": "Equity-International", "sub_category": "Developed Markets"},
            {"ticker": "AGG", "category": "Fixed-Income", "sub_category": "Total Bond Market"},
            {"ticker": "VWO", "category": "Equity-International", "sub_category": "Emerging Markets"},
            {"ticker": "JEPI", "category": "Equity-US-Large-Cap", "sub_category": "Income Strategy"},
            {"ticker": "LQD", "category": "Fixed-Income", "sub_category": "Corporate Bond"},
            {"ticker": "VCIT", "category": "Fixed-Income", "sub_category": "Corporate Bond"},
            {"ticker": "IEMG", "category": "Equity-International", "sub_category": "Emerging Markets"},
            {"ticker": "VIG", "category": "Equity-US-Large-Cap", "sub_category": "Dividend Growth"},
            {"ticker": "VXUS", "category": "Equity-International", "sub_category": "Total Market"},
            {"ticker": "VUG", "category": "Equity-US-Large-Cap", "sub_category": "Growth"},
            {"ticker": "VO", "category": "Equity-US-Mid-Cap", "sub_category": "Blend"},
            {"ticker": "VYM", "category": "Equity-US-Large-Cap", "sub_category": "High Dividend"},
            {"ticker": "VCSH", "category": "Fixed-Income", "sub_category": "Short-Term Corporate"},
            {"ticker": "VTV", "category": "Equity-US-Large-Cap", "sub_category": "Value"},
            {"ticker": "BSV", "category": "Fixed-Income", "sub_category": "Short-Term Bond"},
            {"ticker": "VB", "category": "Equity-US-Small-Cap", "sub_category": "Blend"},
            {"ticker": "SCHD", "category": "Equity-US-Large-Cap", "sub_category": "Dividend"},
            {"ticker": "HYG", "category": "Fixed-Income", "sub_category": "High Yield Corporate"},
            {"ticker": "RSP", "category": "Equity-US-Large-Cap", "sub_category": "Equal Weight"},
            {"ticker": "GOVT", "category": "Fixed-Income", "sub_category": "Government"},
            {"ticker": "TIP", "category": "Fixed-Income", "sub_category": "TIPS"},
            {"ticker": "IWF", "category": "Equity-US-Large-Cap", "sub_category": "Growth"},
            {"ticker": "MUB", "category": "Fixed-Income", "sub_category": "Municipal"},
            {"ticker": "IJH", "category": "Equity-US-Mid-Cap", "sub_category": "Blend"},
            {"ticker": "IWM", "category": "Equity-US-Small-Cap", "sub_category": "Russell 2000"},
            {"ticker": "DVY", "category": "Equity-US-Large-Cap", "sub_category": "Dividend"},
            {"ticker": "XLF", "category": "Equity-US-Sector", "sub_category": "Financials"},
            {"ticker": "XLK", "category": "Equity-US-Sector", "sub_category": "Technology"},
            {"ticker": "XLE", "category": "Equity-US-Sector", "sub_category": "Energy"},
            {"ticker": "USMV", "category": "Equity-US-Large-Cap", "sub_category": "Min Volatility"},
            {"ticker": "DGRO", "category": "Equity-US-Large-Cap", "sub_category": "Dividend Growth"},
            {"ticker": "XLV", "category": "Equity-US-Sector", "sub_category": "Healthcare"},
            {"ticker": "VGT", "category": "Equity-US-Sector", "sub_category": "Technology"},
            {"ticker": "SDY", "category": "Equity-US-Large-Cap", "sub_category": "Dividend"},
            {"ticker": "IWD", "category": "Equity-US-Large-Cap", "sub_category": "Value"},
            {"ticker": "GLD", "category": "Commodities", "sub_category": "Gold"},
            {"ticker": "XLI", "category": "Equity-US-Sector", "sub_category": "Industrials"},
            {"ticker": "VTIP", "category": "Fixed-Income", "sub_category": "Short-Term TIPS"},
            {"ticker": "VNQ", "category": "Real-Estate", "sub_category": "US REIT"},
            {"ticker": "XLP", "category": "Equity-US-Sector", "sub_category": "Consumer Staples"},
            {"ticker": "QUAL", "category": "Equity-US-Large-Cap", "sub_category": "Quality Factor"},
            {"ticker": "IVW", "category": "Equity-US-Large-Cap", "sub_category": "Growth"},
            {"ticker": "XLU", "category": "Equity-US-Sector", "sub_category": "Utilities"}
        ]

def main():
    # Create analyzer and run analysis
    analyzer = TickerAnalyzer()
    results = analyzer.analyze_tickers()

    # Add metadata about the analysis
    metadata = {
        'constituent_lists_last_updated': TickerAnalyzer.LAST_UPDATED,
        'analysis_run_date': datetime.now().strftime('%Y-%m-%d'),
        'total_tickers_analyzed': len([k for k in results.keys() if k != 'TREASURY_RATES']),
        'indices_included': ['S&P 500', 'Dow 30', 'S&P 100', 'NASDAQ 100', 'Top 50 ETFs'],
        'treasury_rates_included': list(TickerAnalyzer.TREASURY_TICKERS.values())
    }

    # Output results
    print("\nAnalysis Metadata:")
    print(json.dumps(metadata, indent=2))

    print("\nTreasury Rates:")
    print(json.dumps(results.get('TREASURY_RATES', {}), indent=2))

    # Filter out error messages and treasury rates for the main DataFrame
    valid_results = {
        k: v for k, v in results.items()
        if k != 'TREASURY_RATES' and isinstance(v, dict)
    }

    # Create separate error log
    error_results = {
        k: v for k, v in results.items()
        if k != 'TREASURY_RATES' and isinstance(v, str)
    }

    print("\nProcessing Summary:")
    print(f"Successfully processed: {len(valid_results)} tickers")
    print(f"Errors encountered: {len(error_results)} tickers")

    if error_results:
        print("\nError Log:")
        for ticker, error in error_results.items():
            print(f"{ticker}: {error}")

    # Save successful results to CSV
    if valid_results:
        df = pd.DataFrame.from_dict(valid_results, orient='index')

        # Add metadata as comments at the top of the CSV
        with open('ticker_analysis_results.csv', 'w') as f:
            f.write('# Analysis Metadata\n')
            for key, value in metadata.items():
                f.write(f'# {key}: {value}\n')
            f.write('#\n')  # Empty line after metadata

        # Append the main data
        df.to_csv('ticker_analysis_results.csv', mode='a')

    # Save errors to separate CSV
    if error_results:
        error_df = pd.DataFrame.from_dict(error_results, orient='index', columns=['error'])
        error_df.to_csv('ticker_analysis_errors.csv')

    # Save treasury rates
    if 'TREASURY_RATES' in results:
        df_treasury = pd.DataFrame.from_dict(results['TREASURY_RATES'], orient='index', columns=['Rate'])
        df_treasury.to_csv('treasury_rates.csv')

if __name__ == "__main__":
    main()
# Out:
# ERROR:yfinance:404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ATVI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ATVI&crumb=UIZDKdv788j
# ERROR:yfinance:404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/FLT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=FLT&crumb=UIZDKdv788j
# ERROR:yfinance:404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/WRK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=WRK&crumb=UIZDKdv788j
# ERROR:yfinance:404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ABC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ABC&crumb=UIZDKdv788j
# Analysis Metadata:
# {
#   "constituent_lists_last_updated": "2024-01-10",
#   "analysis_run_date": "2025-01-10",
#   "total_tickers_analyzed": 571,
#   "indices_included": [
#     "S&P 500",
#     "Dow 30",
#     "S&P 100",
#     "NASDAQ 100",
#     "Top 50 ETFs"
#   ],
#   "treasury_rates_included": [
#     "13-Week Treasury Bill",
#     "5-Year Treasury Note",
#     "10-Year Treasury Note",
#     "30-Year Treasury Bond"
#   ]
# }
#
# Treasury Rates:
# {
#   "13-Week Treasury Bill": null,
#   "5-Year Treasury Note": null,
#   "10-Year Treasury Note": null,
#   "30-Year Treasury Bond": null
# }
#
# Processing Summary:
# Successfully processed: 571 tickers
# Errors encountered: 0 tickers
