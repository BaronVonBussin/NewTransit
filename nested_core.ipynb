# %% [markdown]
# <a href="https://colab.research.google.com/github/BaronVonBussin/NewTransit/blob/main/nested_core.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SCROLL TO BOTTOM CELL FOR BEST

# %%
NONONONONONOONONONON
import pandas as pd
import os

class ConnectTemporalTimeframes:
    def __init__(self, lower_period="D", higher_period="ME"):
        self.lower_period = lower_period
        self.higher_period = higher_period

    def read_csv_files(self, folder_path):
        """
        Reads all CSV files in the specified folder, skipping the second row.
        Assumes the files are named with the ticker (e.g., AAPL.csv).
        """
        data = {}
        for file in os.listdir(folder_path):
            if file.endswith(".csv"):
                ticker = os.path.splitext(file)[0]
                df = pd.read_csv(
                    os.path.join(folder_path, file),
                    #skiprows=[1],  # Skip the second row
                    parse_dates=["date"]
                )
                data[ticker] = df
        return data

    def process_ticker_data(self, df):
        """
        Processes data for a single ticker to calculate the requested metrics.
        """
        # Add fields for intra-period calculations
        df["intra_period_count"] = 0
        df["intra_period_high"] = 0
        df["intra_period_low"] = 0
        df["intra_period_bar_of_h"] = 0
        df["intra_period_bar_of_l"] = 0
        df["intra_period_rpc_direction"] = "N"
        df["intra_period_rpc"] = 0
        df["intra_period_reu"] = 0
        df["intra_period_red"] = 0
        df["bar_rpc_direction"] = "N"
        df["bar_rpc"] = 0

        # Group by higher period
        grouped = df.groupby(pd.Grouper(key="date", freq=self.higher_period))
        results = []

        for group_name, group in grouped:
            group = group.sort_values(by="date").reset_index(drop=True)
            intra_period_high = group.iloc[0]["high"]
            intra_period_low = group.iloc[0]["low"]
            intra_period_bar = 1
            intra_period_rpc = 0
            intra_period_rpc_direction = "N"
            higher_period_rpc_count = 0
            intra_period_bar_of_h = 0
            intra_period_bar_of_l = 0

            for idx, row in group.iterrows():
                if idx == 0:
                    # Initialize for the first row in the group
                    row["intra_period_rpc_direction"] = "N"
                    row["intra_period_rpc"] = 0
                else:
                    # Update intra-period high/low
                    intra_period_high = max(intra_period_high, row["high"])
                    intra_period_low = min(intra_period_low, row["low"])

                    # Check for range expansions
                    if row["high"] > intra_period_high:
                        row["intra_period_reu"] = row["high"] - intra_period_high
                        intra_period_high = row["high"]
                        intra_period_bar_of_h = intra_period_bar
                    else:
                        row["intra_period_reu"] = 0

                    if row["low"] < intra_period_low:
                        row["intra_period_red"] = intra_period_low - row["low"]
                        intra_period_low = row["low"]
                        intra_period_bar_of_l = intra_period_bar
                    else:
                        row["intra_period_red"] = 0

                    # Update bar_rpc and rpc_direction
                    if row["intra_period_reu"] > 0 and row["intra_period_red"] > 0:
                        row["bar_rpc"] = 2
                        row["bar_rpc_direction"] = "U" if (row["close"] - row["low"]) / (row["high"] - row["low"]) >= 0.5 else "D"
                    elif row["intra_period_reu"] > 0:
                        row["bar_rpc"] = 1
                        row["bar_rpc_direction"] = "U"
                    elif row["intra_period_red"] > 0:
                        row["bar_rpc"] = 1
                        row["bar_rpc_direction"] = "D"
                    else:
                        row["bar_rpc"] = 0
                        row["bar_rpc_direction"] = intra_period_rpc_direction

                    # Update higher period rpc
                    if row["bar_rpc"] > 0:
                        if row["bar_rpc_direction"] != intra_period_rpc_direction:
                            higher_period_rpc_count += 1
                        intra_period_rpc_direction = row["bar_rpc_direction"]

                # Increment the intra-period bar count
                row["intra_period_count"] = intra_period_bar
                intra_period_bar += 1

                # Append to results
                results.append(row)

        return pd.DataFrame(results)

    def generate_report(self, data, output_folder):
        """
        Generates a summary report for each ticker and writes the processed data to CSV.
        """
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)

        summary = []
        for ticker, df in data.items():
            processed_data = self.process_ticker_data(df)
            processed_data.to_csv(os.path.join(output_folder, f"{ticker}_processed.csv"), index=False)

            # Generate summary stats
            grouped = processed_data.groupby(pd.Grouper(key="date", freq=self.higher_period))
            for group_name, group in grouped:
                summary.append({
                    "Ticker": ticker,
                    "Higher_Period": group_name,
                    "Duration": group["intra_period_count"].max(),
                    "Number_Of_Directions": group["intra_period_rpc"].max(),
                    "Max_intra_period_bar_of_h": group["intra_period_bar_of_h"].max(),
                    "Max_intra_period_bar_of_l": group["intra_period_bar_of_l"].max(),
                    "Number_of_intra_period_expansions": group["bar_rpc"].sum()
                })

        # Save summary
        summary_df = pd.DataFrame(summary)
        summary_df.to_csv(os.path.join(output_folder, "summary_report.csv"), index=False)

# Example Usage
folder_path = "/content/input"  # Replace with your folder path
output_folder = "processed_output"
connector = ConnectTemporalTimeframes()
data = connector.read_csv_files(folder_path)
connector.generate_report(data, output_folder)

# %%
import pandas as pd
import os


class ConnectTemporalTimeframes:
    def __init__(self, lower_period="D", higher_period="ME"):
        self.lower_period = lower_period
        self.higher_period = higher_period

    def read_csv_files(self, folder_path):
        """
        Reads all CSV files in the specified folder, skipping the second row.
        Assumes the files are named with the ticker (e.g., AAPL.csv).
        """
        data = {}
        for file in os.listdir(folder_path):
            if file.endswith(".csv"):
                ticker = os.path.splitext(file)[0]
                df = pd.read_csv(
                    os.path.join(folder_path, file),
                    skiprows=[1],  # Skip the second row
                    parse_dates=["date"]
                )
                data[ticker] = df
        return data

    def process_ticker_data(self, df):
        """
        Processes data for a single ticker to calculate the requested metrics.
        """
        # Add fields for intra-period calculations
        df["intra_period_count"] = 0
        df["intra_period_high"] = 0
        df["intra_period_low"] = 0
        df["intra_period_bar_of_h"] = 0
        df["intra_period_bar_of_l"] = 0
        df["intra_period_rpc_direction"] = "N"
        df["intra_period_rpc"] = 0
        df["intra_period_reu"] = 0
        df["intra_period_red"] = 0
        df["bar_rpc_direction"] = "N"
        df["bar_rpc"] = 0

        # Group by higher period
        grouped = df.groupby(pd.Grouper(key="date", freq=self.higher_period))
        results = []

        for group_name, group in grouped:
            group = group.sort_values(by="date").reset_index(drop=True)
            intra_period_high = group.iloc[0]["high"]
            intra_period_low = group.iloc[0]["low"]
            intra_period_bar = 1
            intra_period_rpc = 0
            intra_period_rpc_direction = "N"
            higher_period_rpc_count = 0
            intra_period_bar_of_h = 0
            intra_period_bar_of_l = 0

            for idx, row in group.iterrows():
                if idx == 0:
                    # Initialize for the first row in the group
                    row["intra_period_high"] = row["high"]
                    row["intra_period_low"] = row["low"]
                    row["intra_period_rpc_direction"] = "N"
                    row["intra_period_rpc"] = 0
                else:
                    # Calculate intra-period high and low
                    prior_high = intra_period_high
                    prior_low = intra_period_low
                    intra_period_high = max(row["high"], prior_high)
                    intra_period_low = min(row["low"], prior_low)

                    # Check for range expansions
                    if row["high"] > prior_high:
                        row["intra_period_reu"] = row["high"] - prior_high
                        intra_period_bar_of_h = intra_period_bar
                    else:
                        row["intra_period_reu"] = 0

                    if row["low"] < prior_low:
                        row["intra_period_red"] = prior_low - row["low"]
                        intra_period_bar_of_l = intra_period_bar
                    else:
                        row["intra_period_red"] = 0

                    # Update bar_rpc and rpc_direction
                    if row["intra_period_reu"] > 0 and row["intra_period_red"] > 0:
                        row["bar_rpc"] = 2
                        row["bar_rpc_direction"] = "U" if (row["close"] - row["low"]) / (row["high"] - row["low"]) >= 0.5 else "D"
                    elif row["intra_period_reu"] > 0:
                        row["bar_rpc"] = 1
                        row["bar_rpc_direction"] = "U"
                    elif row["intra_period_red"] > 0:
                        row["bar_rpc"] = 1
                        row["bar_rpc_direction"] = "D"
                    else:
                        row["bar_rpc"] = 0
                        row["bar_rpc_direction"] = intra_period_rpc_direction

                    # Update higher period rpc
                    if row["bar_rpc"] > 0:
                        if row["bar_rpc_direction"] != intra_period_rpc_direction:
                            higher_period_rpc_count += 1
                        intra_period_rpc_direction = row["bar_rpc_direction"]

                # Increment the intra-period bar count
                row["intra_period_count"] = intra_period_bar
                intra_period_bar += 1

                # Append to results
                results.append(row)

        return pd.DataFrame(results)

    def generate_report(self, data, output_folder):
        """
        Generates a summary report for each ticker and writes the processed data to CSV.
        """
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)

        summary = []
        for ticker, df in data.items():
            processed_data = self.process_ticker_data(df)
            processed_data.to_csv(os.path.join(output_folder, f"{ticker}_processed.csv"), index=False)

            # Generate summary stats
            grouped = processed_data.groupby(pd.Grouper(key="date", freq=self.higher_period))
            for group_name, group in grouped:
                summary.append({
                    "Ticker": ticker,
                    "Higher_Period": group_name,
                    "Duration": group["intra_period_count"].max(),
                    "Number_Of_Directions": group["intra_period_rpc"].max(),
                    "Max_intra_period_bar_of_h": group["intra_period_bar_of_h"].max(),
                    "Max_intra_period_bar_of_l": group["intra_period_bar_of_l"].max(),
                    "Number_of_intra_period_expansions": group["bar_rpc"].sum()
                })

        # Save summary
        summary_df = pd.DataFrame(summary)
        summary_df.to_csv(os.path.join(output_folder, "summary_report.csv"), index=False)


# Example Usage
folder_path = "input"  # Replace with your folder path
output_folder = "processed_output"
connector = ConnectTemporalTimeframes()
data = connector.read_csv_files(folder_path)
connector.generate_report(data, output_folder)

# %%
import pandas as pd
import os


class ConnectTemporalTimeframes:
    def __init__(self, lower_period="D", higher_period="ME"):
        self.lower_period = lower_period
        self.higher_period = higher_period

    def read_csv_files(self, folder_path):
        """
        Reads all CSV files in the specified folder, skipping the second row.
        Assumes the files are named with the ticker (e.g., AAPL.csv).
        """
        data = {}
        for file in os.listdir(folder_path):
            if file.endswith(".csv"):
                ticker = os.path.splitext(file)[0]
                df = pd.read_csv(
                    os.path.join(folder_path, file),
                    skiprows=[1],  # Skip the second row
                    parse_dates=["date"]
                )
                data[ticker] = df
        return data

    def process_ticker_data(self, df):
        """
        Processes data for a single ticker to calculate the requested metrics.
        """
        # Add fields for intra-period calculations
        df["intra_period_count"] = 0
        df["intra_period_high"] = 0
        df["intra_period_low"] = 0
        df["intra_period_bar_of_h"] = 0
        df["intra_period_bar_of_l"] = 0
        df["intra_period_rpc_direction"] = "N"
        df["intra_period_rpc"] = 0
        df["intra_period_reu"] = 0
        df["intra_period_red"] = 0
        df["bar_rpc_direction"] = "N"
        df["bar_rpc"] = 0

        # Group by higher period
        grouped = df.groupby(pd.Grouper(key="date", freq=self.higher_period))
        results = []

        for group_name, group in grouped:
            group = group.sort_values(by="date").reset_index(drop=True)
            intra_period_high = group.iloc[0]["high"]
            intra_period_low = group.iloc[0]["low"]
            intra_period_bar = 1
            intra_period_rpc = 0
            intra_period_rpc_direction = "N"
            higher_period_rpc_count = 0
            intra_period_bar_of_h = 0
            intra_period_bar_of_l = 0
            prior_intra_period_high = 0
            prior_intra_period_low = 0

            for idx, row in group.iterrows():
                if idx == 0:
                    # Initialize for the first row in the group
                    row["intra_period_high"] = row["high"]
                    row["intra_period_low"] = row["low"]
                    row["intra_period_rpc_direction"] = "N"
                    row["intra_period_rpc"] = 0
                    prior_intra_period_high = row["high"]
                    prior_intra_period_low = row["low"]
                else:
                    # Calculate intra-period high and low
                    prior_high = prior_intra_period_high
                    prior_low = prior_intra_period_low
                    intra_period_high = max(row["high"], prior_high)
                    intra_period_low = min(row["low"], prior_low)

                    # Check for range expansions
                    if row["high"] > prior_high:
                        row["intra_period_reu"] = row["high"] - prior_high
                        intra_period_bar_of_h = intra_period_bar
                    else:
                        row["intra_period_reu"] = 0

                    if row["low"] < prior_low:
                        row["intra_period_red"] = prior_low - row["low"]
                        intra_period_bar_of_l = intra_period_bar
                    else:
                        row["intra_period_red"] = 0

                    # Update bar_rpc and rpc_direction
                    if row["intra_period_reu"] > 0 and row["intra_period_red"] > 0:
                        row["bar_rpc"] = 2
                        row["bar_rpc_direction"] = "U" if (row["close"] - row["low"]) / (row["high"] - row["low"]) >= 0.5 else "D"
                    elif row["intra_period_reu"] > 0:
                        row["bar_rpc"] = 1
                        row["bar_rpc_direction"] = "U"
                    elif row["intra_period_red"] > 0:
                        row["bar_rpc"] = 1
                        row["bar_rpc_direction"] = "D"
                    else:
                        row["bar_rpc"] = 0
                        row["bar_rpc_direction"] = intra_period_rpc_direction

                    # Update higher period rpc
                    if row["bar_rpc"] > 0:
                        if row["bar_rpc_direction"] != intra_period_rpc_direction:
                            higher_period_rpc_count += 1
                        intra_period_rpc_direction = row["bar_rpc_direction"]

                # Store current intra_period_high and low for next iteration
                prior_intra_period_high = intra_period_high
                prior_intra_period_low = intra_period_low

                # Increment the intra-period bar count
                row["intra_period_count"] = intra_period_bar
                intra_period_bar += 1

                # Append to results
                results.append(row)

        return pd.DataFrame(results)

    def generate_report(self, data, output_folder):
        """
        Generates a summary report for each ticker and writes the processed data to CSV.
        """
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)

        summary = []
        for ticker, df in data.items():
            processed_data = self.process_ticker_data(df)
            processed_data.to_csv(os.path.join(output_folder, f"{ticker}_processed.csv"), index=False)

            # Generate summary stats
            grouped = processed_data.groupby(pd.Grouper(key="date", freq=self.higher_period))
            for group_name, group in grouped:
                summary.append({
                    "Ticker": ticker,
                    "Higher_Period": group_name,
                    "Duration": group["intra_period_count"].max(),
                    "Number_Of_Directions": group["intra_period_rpc"].max(),
                    "Max_intra_period_bar_of_h": group["intra_period_bar_of_h"].max(),
                    "Max_intra_period_bar_of_l": group["intra_period_bar_of_l"].max(),
                    "Number_of_intra_period_expansions": group["bar_rpc"].sum()
                })

        # Save summary
        summary_df = pd.DataFrame(summary)
        summary_df.to_csv(os.path.join(output_folder, "summary_report.csv"), index=False)


# Example Usage
folder_path = "input"  # Replace with your folder path
output_folder = "processed_output"
connector = ConnectTemporalTimeframes()
data = connector.read_csv_files(folder_path)
connector.generate_report(data, output_folder)

# %%
import pandas as pd
import os


class ConnectTemporalTimeframes:
    def __init__(self, lower_period="D", higher_period="ME"):
        self.lower_period = lower_period
        self.higher_period = higher_period

    def read_csv_files(self, folder_path):
        """
        Reads all CSV files in the specified folder, skipping the second row.
        Assumes the files are named with the ticker (e.g., AAPL.csv).
        """
        data = {}
        for file in os.listdir(folder_path):
            if file.endswith(".csv"):
                ticker = os.path.splitext(file)[0]
                df = pd.read_csv(
                    os.path.join(folder_path, file),
                    skiprows=[1],  # Skip the second row
                    parse_dates=["date"]
                )
                data[ticker] = df
        return data

    def process_ticker_data(self, df):
        """
        Processes data for a single ticker to calculate the requested metrics.
        """
        # Initialize fields for processing
        df["intra_period_count"] = 0
        df["intra_period_high"] = 0
        df["intra_period_low"] = 0
        df["intra_period_bar_of_h"] = 0
        df["intra_period_bar_of_l"] = 0
        df["intra_period_rpc_direction"] = "N"
        df["intra_period_rpc"] = 0
        df["intra_period_reu"] = 0
        df["intra_period_red"] = 0
        df["bar_rpc_direction"] = "N"
        df["bar_rpc"] = 0

        # Group data by higher_period
        grouped = df.groupby(pd.Grouper(key="date", freq=self.higher_period))
        results = []

        for group_name, group in grouped:
            group = group.sort_values(by="date").reset_index(drop=True)

            # Calculate higher_period high and low
            higher_period_high = group["high"].max()
            higher_period_low = group["low"].min()

            # Initialize variables for intra-period processing
            intra_period_high = group["high"].iloc[0]
            intra_period_low = group["low"].iloc[0]
            intra_period_bar = 1
            intra_period_rpc_direction = "N"
            higher_period_rpc_count = 0

            # Run through the rows in the group
            for idx, row in group.iterrows():
                if idx == 0:
                    # Initialize first row in group
                    group.loc[idx, "intra_period_high"] = row["high"]
                    group.loc[idx, "intra_period_low"] = row["low"]
                else:
                    # Update intra-period high and low
                    group.loc[idx, "intra_period_high"] = max(row["high"], group["intra_period_high"].shift(1).iloc[idx])
                    group.loc[idx, "intra_period_low"] = min(row["low"], group["intra_period_low"].shift(1).iloc[idx])

                    # Check for range expansions
                    if row["high"] > group["intra_period_high"].shift(1).iloc[idx]:
                        group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
                    else:
                        group.loc[idx, "intra_period_reu"] = 0

                    if row["low"] < group["intra_period_low"].shift(1).iloc[idx]:
                        group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
                    else:
                        group.loc[idx, "intra_period_red"] = 0

                # Check for matches with higher_period high/low
                if row["high"] == higher_period_high:
                    group.loc[idx, "intra_period_bar_of_h"] = intra_period_bar
                if row["low"] == higher_period_low:
                    group.loc[idx, "intra_period_bar_of_l"] = intra_period_bar

                # Update intra-period bar count
                group.loc[idx, "intra_period_count"] = intra_period_bar
                intra_period_bar += 1

            results.append(group)

        return pd.concat(results)

    def generate_report(self, data, output_folder):
        """
        Generates a summary report for each ticker and writes the processed data to CSV.
        """
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)

        summary = []
        for ticker, df in data.items():
            processed_data = self.process_ticker_data(df)
            processed_data.to_csv(os.path.join(output_folder, f"{ticker}_processed.csv"), index=False)

            # Generate summary stats
            grouped = processed_data.groupby(pd.Grouper(key="date", freq=self.higher_period))
            for group_name, group in grouped:
                summary.append({
                    "Ticker": ticker,
                    "Higher_Period": group_name,
                    "Duration": group["intra_period_count"].max(),
                    "Number_Of_Directions": group["intra_period_rpc"].max(),
                    "Max_intra_period_bar_of_h": group["intra_period_bar_of_h"].max(),
                    "Max_intra_period_bar_of_l": group["intra_period_bar_of_l"].max(),
                    "Number_of_intra_period_expansions": group["bar_rpc"].sum()
                })

        # Save summary
        summary_df = pd.DataFrame(summary)
        summary_df.to_csv(os.path.join(output_folder, "summary_report.csv"), index=False)


# Example Usage
folder_path = "input"  # Replace with your folder path
output_folder = "processed_output"
connector = ConnectTemporalTimeframes()
data = connector.read_csv_files(folder_path)
connector.generate_report(data, output_folder)
# Out:
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '123.3277588' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '121.7474899' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.831100400000011' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3929748000000046' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '125.2424774' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '123.8294296' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.714042599999999' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.558525099999997' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '133.5284271' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '131.7809296' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.15049750000000017' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '140.2508392' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '137.7842865' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.11706540000000132' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.20903020000000083' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '140.8862915' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '139.5819397' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.23411559999999554' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.4598694000000023' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '141.2458191' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '139.7073517' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3879546999999945' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.4096984999999904' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '147.2240753' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '146.2458191' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.170562799999999' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4297637999999893' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '149.2809296' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '148.0601959' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.06689449999998942' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '150.6438141' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '149.4983215' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1036835000000167' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.642135599999989' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '147.115387' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '145.819397' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.6755829000000233' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '138.6371307' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '136.9983215' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.4682160000000124' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '144.4314423' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '143.3528442' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7943115000000205' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.30101009999998496' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '150.5016785' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '148.1772614' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.27592469999999025' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '146.9899597' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '145.7357788' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6270751999999788' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3344573999999909' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '159.3143768' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '157.1989899' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5852967000000149' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '160.6772614' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '158.8210754' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.14215080000002445' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.20903010000000677' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '163.6538391' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '162.6003265' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6688995000000091' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7775878999999861' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '171.3210754' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '170.3010101' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.0819396999999924' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '175.8695679' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '174.5401306' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7190551999999855' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.170562700000005' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '169.9916382' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '168.6956482' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9147185999999863' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.35952760000000694' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '171.3294373' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '169.9247437' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.2742462999999873' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.011703400000016' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '177.9180603' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '175.6103668' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5133819999999787' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '193.7792664' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '191.5635376' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8695677999999987' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7223968999999784' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '203.70401' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '199.9581909' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.501678499999997' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5351105000000018' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '198.2190704' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '194.657196' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.981597899999997' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '209.1053467' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '205.8361206' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0869597999999883' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '198.0184021' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '191.9147186' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.675582899999995' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7190551999999855' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '182.8762512' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '175.1421356' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.329437299999995' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.518386800000002' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '163.4949799' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '160.07' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7250200999999947' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '167.5752563' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '165.7859497' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0618743999999936' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8559496999999965' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '163.7876282' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '161.7976532' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.5585327000000007' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.4581909000000053' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '176.4715729' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '172.9682312' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.5250853999999947' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.025085399999994706' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '176.2123718' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '173.5367889' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9699096999999881' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.16722100000001205' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '178.4281006' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '176.680603' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.0401305999999977' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.20903009999997835' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '161.5468292' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '158.9381256' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0534973000000036' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '177.2157135' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '173.1187286' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.147155699999985' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '159.6906281' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '156.1036835' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.1856231999999807' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8277740000000051' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '168.70401' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '165.7943115' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7043114999999887' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0953216999999995' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '175.384613' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '172.9933167' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# ...
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '55.59000015' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '54.20249939' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.8450012200000003' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '46.23500061' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '45.30250168' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2350006100000002' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '39.71250153' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '38.55749893' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.0574989300000013' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.8249969400000055' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '42.24499893' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '41.48249817' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6700019899999958' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '43.78749847' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '43.22249985' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6500015299999973' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.21749877999999967' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '47.91999817' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '47.09500122' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6950035099999994' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '53.82749939' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '52.30749893' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.27499771000000095' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '44.47999954' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '42.56750107' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.4775009199999971' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '51.12250137' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '50.16249847' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.1474990899999966' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5599975500000056' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '54.50749969' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '51.68500137' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2775001500000016' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '51.74499893' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '51.05500031' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.625' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '57.05500031' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '56.04999924' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5675010699999987' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.42749786000000256' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '63.98249817' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '62.29000092' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.48000335999999777' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]
# <ipython-input-11-a70320b7f33c>:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '67.0625' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_high"] = row["high"]
# <ipython-input-11-a70320b7f33c>:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '65.86250305' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_low"] = row["low"]
# <ipython-input-11-a70320b7f33c>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7900009100000034' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_red"] = group["intra_period_low"].shift(1).iloc[idx] - row["low"]
# <ipython-input-11-a70320b7f33c>:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6875' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group.loc[idx, "intra_period_reu"] = row["high"] - group["intra_period_high"].shift(1).iloc[idx]

# %%
import pandas as pd
import os

class ConnectTemporalPeriods:
    def __init__(self, child_period="D", parent_period="ME"):
        self.child_period = child_period
        self.parent_period = parent_period

    def read_csv_files(self, input_folder):
        """
        Reads all CSV files in the specified folder. Assumes files are named TICKER.csv
        and contain the columns: date, open, high, low, close.
        """
        data = {}
        for file in os.listdir(input_folder):
            if file.endswith(".csv"):
                ticker = os.path.splitext(file)[0]
                df = pd.read_csv(
                    os.path.join(input_folder, file),
                    parse_dates=["date"]
                )
                data[ticker] = df
        return data

    def group_by_parent_period(self, df):
        """
        Groups the data by the parent_period and calculates parent stats.
        Returns a DataFrame with one row per parent group and the calculated fields.
        """
        grouped = df.groupby(pd.Grouper(key="date", freq=self.parent_period))
        summary = []
        for name, group in grouped:
            summary.append({
                "date": name,
                "num_rows": len(group),
                "parent_high": group["high"].max(),
                "parent_low": group["low"].min()
            })
        return pd.DataFrame(summary)

    def process_child_period(self, df, parent_stats):
        """
        Processes the child-period data to calculate intra-period fields and parent-to-date stats.
        """
        df = df.sort_values(by="date").reset_index(drop=True)
        parent_stats = parent_stats.set_index("date")

        # Initialize new fields
        df["intra_period_count"] = 0
        df["intra_period_high"] = 0
        df["intra_period_low"] = 0
        df["intra_period_bar_of_h"] = 0
        df["intra_period_bar_of_l"] = 0
        df["rpc_direction"] = "N"
        df["bar_rpc"] = 0
        df["intra_period_reu"] = 0
        df["intra_period_red"] = 0
        df["intra_period_cumulative_rpc"] = 0

        # Iterate through the rows and update fields
        for i, row in df.iterrows():
            parent_date = row["date"].floor(self.parent_period)
            parent = parent_stats.loc[parent_date]

            # Intra-period high/low calculations
            if i == 0:
                df.loc[i, "intra_period_high"] = row["high"]
                df.loc[i, "intra_period_low"] = row["low"]
            else:
                df.loc[i, "intra_period_high"] = max(row["high"], df.loc[i - 1, "intra_period_high"])
                df.loc[i, "intra_period_low"] = min(row["low"], df.loc[i - 1, "intra_period_low"])

            # Range expansions
            prior_high = df.loc[i - 1, "intra_period_high"] if i > 0 else row["high"]
            prior_low = df.loc[i - 1, "intra_period_low"] if i > 0 else row["low"]

            if row["high"] > prior_high:
                df.loc[i, "intra_period_reu"] = row["high"] - prior_high
            if row["low"] < prior_low:
                df.loc[i, "intra_period_red"] = prior_low - row["low"]

            # Parent range expansion
            if row["high"] == parent["parent_high"]:
                df.loc[i, "intra_period_bar_of_h"] = i + 1
            if row["low"] == parent["parent_low"]:
                df.loc[i, "intra_period_bar_of_l"] = i + 1

            # RPC logic
            if i > 0:
                if row["high"] > prior_high and row["low"] < prior_low:
                    df.loc[i, "bar_rpc"] = 2
                    df.loc[i, "rpc_direction"] = "U" if (row["close"] - row["low"]) / (row["high"] - row["low"]) >= 0.5 else "D"
                elif row["high"] > prior_high:
                    df.loc[i, "bar_rpc"] = 1
                    df.loc[i, "rpc_direction"] = "U"
                elif row["low"] < prior_low:
                    df.loc[i, "bar_rpc"] = 1
                    df.loc[i, "rpc_direction"] = "D"
                else:
                    df.loc[i, "rpc_direction"] = df.loc[i - 1, "rpc_direction"]

            # Update cumulative RPC
            if i > 0:
                if df.loc[i, "rpc_direction"] != df.loc[i - 1, "rpc_direction"]:
                    df.loc[i, "intra_period_cumulative_rpc"] = df.loc[i - 1, "intra_period_cumulative_rpc"] + 1
                else:
                    df.loc[i, "intra_period_cumulative_rpc"] = df.loc[i - 1, "intra_period_cumulative_rpc"]

        return df

    def generate_reports(self, data, parent_output_folder, processed_output_folder):
        """
        Processes all tickers, generates parent and processed data, and writes to CSVs.
        """
        if not os.path.exists(parent_output_folder):
            os.makedirs(parent_output_folder)
        if not os.path.exists(processed_output_folder):
            os.makedirs(processed_output_folder)

        for ticker, df in data.items():
            print(f"Processing {ticker}...")

            # Generate parent stats
            parent_stats = self.group_by_parent_period(df)
            parent_stats.to_csv(os.path.join(parent_output_folder, f"{ticker}_parent.csv"), index=False)

            # Process child period data
            processed_data = self.process_child_period(df, parent_stats)
            processed_data.to_csv(os.path.join(processed_output_folder, f"{ticker}_processed.csv"), index=False)

            print(f"{ticker} processing complete.")

# Example Usage
input_folder = "input"
parent_output_folder = "parent_output"
processed_output_folder = "processed_output"

connector = ConnectTemporalPeriods()
data = connector.read_csv_files(input_folder)
connector.generate_reports(data, parent_output_folder, processed_output_folder)
# Out:
# Processing MMM...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-f615a9da3e68> in <cell line: 140>()
#     138 connector = ConnectTemporalPeriods()
#     139 data = connector.read_csv_files(input_folder)
# --> 140 connector.generate_reports(data, parent_output_folder, processed_output_folder)
#
# <ipython-input-12-f615a9da3e68> in generate_reports(self, data, parent_output_folder, processed_output_folder)
#     126
#     127             # Process child period data
# --> 128             processed_data = self.process_child_period(df, parent_stats)
#     129             processed_data.to_csv(os.path.join(processed_output_folder, f"{ticker}_processed.csv"), index=False)
#     130
#
# <ipython-input-12-f615a9da3e68> in process_child_period(self, df, parent_stats)
#      60         # Iterate through the rows and update fields
#      61         for i, row in df.iterrows():
# ---> 62             parent_date = row["date"].floor(self.parent_period)
#      63             parent = parent_stats.loc[parent_date]
#      64
#
# timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.floor()
#
# timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp._round()
#
# timedeltas.pyx in pandas._libs.tslibs.timedeltas.get_unit_for_round()
#
# offsets.pyx in pandas._libs.tslibs.offsets.BaseOffset.nanos.__get__()
#
# ValueError: <MonthEnd> is a non-fixed frequency

# %%
def process_child_period(self, df, parent_stats):
    """
    Processes the child-period data to calculate intra-period fields and parent-to-date stats.
    """
    df = df.sort_values(by="date").reset_index(drop=True)
    parent_stats = parent_stats.set_index("date")

    # Initialize new fields
    df["intra_period_count"] = 0
    df["intra_period_high"] = 0
    df["intra_period_low"] = 0
    df["intra_period_bar_of_h"] = 0
    df["intra_period_bar_of_l"] = 0
    df["rpc_direction"] = "N"
    df["bar_rpc"] = 0
    df["intra_period_reu"] = 0
    df["intra_period_red"] = 0
    df["intra_period_cumulative_rpc"] = 0

    # Iterate through the rows and update fields
    for i, row in df.iterrows():
        # Adjust the date to match the parent period (MonthEnd)
        parent_date = row["date"] + MonthEnd(0)
        parent = parent_stats.loc[parent_date]

        # Intra-period high/low calculations
        if i == 0:
            df.loc[i, "intra_period_high"] = row["high"]
            df.loc[i, "intra_period_low"] = row["low"]
        else:
            df.loc[i, "intra_period_high"] = max(row["high"], df.loc[i - 1, "intra_period_high"])
            df.loc[i, "intra_period_low"] = min(row["low"], df.loc[i - 1, "intra_period_low"])

        # Range expansions
        prior_high = df.loc[i - 1, "intra_period_high"] if i > 0 else row["high"]
        prior_low = df.loc[i - 1, "intra_period_low"] if i > 0 else row["low"]

        if row["high"] > prior_high:
            df.loc[i, "intra_period_reu"] = row["high"] - prior_high
        if row["low"] < prior_low:
            df.loc[i, "intra_period_red"] = prior_low - row["low"]

        # Parent range expansion
        if row["high"] == parent["parent_high"]:
            df.loc[i, "intra_period_bar_of_h"] = i + 1
        if row["low"] == parent["parent_low"]:
            df.loc[i, "intra_period_bar_of_l"] = i + 1

        # RPC logic
        if i > 0:
            if row["high"] > prior_high and row["low"] < prior_low:
                df.loc[i, "bar_rpc"] = 2
                df.loc[i, "rpc_direction"] = "U" if (row["close"] - row["low"]) / (row["high"] - row["low"]) >= 0.5 else "D"
            elif row["high"] > prior_high:
                df.loc[i, "bar_rpc"] = 1
                df.loc[i, "rpc_direction"] = "U"
            elif row["low"] < prior_low:
                df.loc[i, "bar_rpc"] = 1
                df.loc[i, "rpc_direction"] = "D"
            else:
                df.loc[i, "rpc_direction"] = df.loc[i - 1, "rpc_direction"]

        # Update cumulative RPC
        if i > 0:
            if df.loc[i, "rpc_direction"] != df.loc[i - 1, "rpc_direction"]:
                df.loc[i, "intra_period_cumulative_rpc"] = df.loc[i - 1, "intra_period_cumulative_rpc"] + 1
            else:
                df.loc[i, "intra_period_cumulative_rpc"] = df.loc[i - 1, "intra_period_cumulative_rpc"]

    return df

# %%
import pandas as pd
import os
from pandas.tseries.offsets import MonthEnd

class ConnectTemporalPeriods:
    def __init__(self, child_period="D", parent_period="ME"):
        self.child_period = child_period
        self.parent_period = parent_period

    def read_csv_files(self, input_folder):
        """
        Reads all CSV files in the specified folder. Assumes files are named TICKER.csv
        and contain the columns: date, open, high, low, close.
        """
        data = {}
        for file in os.listdir(input_folder):
            if file.endswith(".csv"):
                ticker = os.path.splitext(file)[0]
                df = pd.read_csv(
                    os.path.join(input_folder, file),
                    parse_dates=["date"]
                )
                data[ticker] = df
        return data

    def group_by_parent_period(self, df):
        """
        Groups the data by the parent_period and calculates parent stats.
        Returns a DataFrame with one row per parent group and the calculated fields.
        """
        grouped = df.groupby(pd.Grouper(key="date", freq=self.parent_period))
        summary = []
        for name, group in grouped:
            summary.append({
                "date": name,
                "num_rows": len(group),
                "parent_high": group["high"].max(),
                "parent_low": group["low"].min()
            })
        return pd.DataFrame(summary)

    def process_child_period(self, df, parent_stats):
        """
        Processes the child-period data to calculate intra-period fields and parent-to-date stats.
        """
        df = df.sort_values(by="date").reset_index(drop=True)
        parent_stats = parent_stats.set_index("date")

        # Initialize new fields
        df["intra_period_count"] = 0
        df["intra_period_high"] = 0
        df["intra_period_low"] = 0
        df["intra_period_bar_of_h"] = 0
        df["intra_period_bar_of_l"] = 0
        df["rpc_direction"] = "N"
        df["bar_rpc"] = 0
        df["intra_period_reu"] = 0
        df["intra_period_red"] = 0
        df["intra_period_cumulative_rpc"] = 0

        # Iterate through the rows and update fields
        for i, row in df.iterrows():
            # Adjust the date to match the parent period (MonthEnd)
            parent_date = row["date"] + MonthEnd(0)
            parent = parent_stats.loc[parent_date]

            # Intra-period high/low calculations
            if i == 0:
                df.loc[i, "intra_period_high"] = row["high"]
                df.loc[i, "intra_period_low"] = row["low"]
            else:
                df.loc[i, "intra_period_high"] = max(row["high"], df.loc[i - 1, "intra_period_high"])
                df.loc[i, "intra_period_low"] = min(row["low"], df.loc[i - 1, "intra_period_low"])

            # Range expansions
            prior_high = df.loc[i - 1, "intra_period_high"] if i > 0 else row["high"]
            prior_low = df.loc[i - 1, "intra_period_low"] if i > 0 else row["low"]

            if row["high"] > prior_high:
                df.loc[i, "intra_period_reu"] = row["high"] - prior_high
            if row["low"] < prior_low:
                df.loc[i, "intra_period_red"] = prior_low - row["low"]

            # Parent range expansion
            if row["high"] == parent["parent_high"]:
                df.loc[i, "intra_period_bar_of_h"] = i + 1
            if row["low"] == parent["parent_low"]:
                df.loc[i, "intra_period_bar_of_l"] = i + 1

            # RPC logic
            if i > 0:
                if row["high"] > prior_high and row["low"] < prior_low:
                    df.loc[i, "bar_rpc"] = 2
                    df.loc[i, "rpc_direction"] = "U" if (row["close"] - row["low"]) / (row["high"] - row["low"]) >= 0.5 else "D"
                elif row["high"] > prior_high:
                    df.loc[i, "bar_rpc"] = 1
                    df.loc[i, "rpc_direction"] = "U"
                elif row["low"] < prior_low:
                    df.loc[i, "bar_rpc"] = 1
                    df.loc[i, "rpc_direction"] = "D"
                else:
                    df.loc[i, "rpc_direction"] = df.loc[i - 1, "rpc_direction"]

            # Update cumulative RPC
            if i > 0:
                if df.loc[i, "rpc_direction"] != df.loc[i - 1, "rpc_direction"]:
                    df.loc[i, "intra_period_cumulative_rpc"] = df.loc[i - 1, "intra_period_cumulative_rpc"] + 1
                else:
                    df.loc[i, "intra_period_cumulative_rpc"] = df.loc[i - 1, "intra_period_cumulative_rpc"]

        return df

    def generate_reports(self, data, parent_output_folder, processed_output_folder):
        """
        Processes all tickers, generates parent and processed data, and writes to CSVs.
        """
        if not os.path.exists(parent_output_folder):
            os.makedirs(parent_output_folder)
        if not os.path.exists(processed_output_folder):
            os.makedirs(processed_output_folder)

        for ticker, df in data.items():
            print(f"Processing {ticker}...")

            # Generate parent stats
            parent_stats = self.group_by_parent_period(df)
            parent_stats.to_csv(os.path.join(parent_output_folder, f"{ticker}_parent.csv"), index=False)

            # Process child period data
            processed_data = self.process_child_period(df, parent_stats)
            processed_data.to_csv(os.path.join(processed_output_folder, f"{ticker}_processed.csv"), index=False)

            print(f"{ticker} processing complete.")

# Example Usage
input_folder = "input"
parent_output_folder = "parent_output"
processed_output_folder = "processed_output"

connector = ConnectTemporalPeriods()
data = connector.read_csv_files(input_folder)
connector.generate_reports(data, parent_output_folder, processed_output_folder)
# Out:
# Processing MMM...
# <ipython-input-14-78a924b76101>:69: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '124.0133743' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, "intra_period_high"] = row["high"]
# <ipython-input-14-78a924b76101>:70: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '121.571907' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, "intra_period_low"] = row["low"]
# <ipython-input-14-78a924b76101>:82: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.655517500000002' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, "intra_period_red"] = prior_low - row["low"]
# <ipython-input-14-78a924b76101>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.240806599999999' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, "intra_period_reu"] = row["high"] - prior_high
# MMM processing complete.
# Processing AFL...
# <ipython-input-14-78a924b76101>:69: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '29.59000015' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, "intra_period_high"] = row["high"]
# <ipython-input-14-78a924b76101>:70: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '29.10000038' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, "intra_period_low"] = row["low"]
# <ipython-input-14-78a924b76101>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.22500037999999734' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, "intra_period_reu"] = row["high"] - prior_high
# <ipython-input-14-78a924b76101>:82: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.125' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, "intra_period_red"] = prior_low - row["low"]
# AFL processing complete.
# Processing AAPL...
# <ipython-input-14-78a924b76101>:69: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '26.34250069' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, "intra_period_high"] = row["high"]
# <ipython-input-14-78a924b76101>:70: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '25.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, "intra_period_low"] = row["low"]
# <ipython-input-14-78a924b76101>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.11999892999999773' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, "intra_period_reu"] = row["high"] - prior_high
# <ipython-input-14-78a924b76101>:82: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5324993099999986' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, "intra_period_red"] = prior_low - row["low"]
# AAPL processing complete.
